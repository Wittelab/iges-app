# %%
# %matplotlib inline

# %% [markdown]
# # Using frequency
#
# Using a dictionary of word frequency.

# %%
import multidict as multidict

import numpy as np

import os
import re
from PIL import Image
from os import path
from wordcloud import WordCloud
import matplotlib.pyplot as plt


def getFrequencyDictForText(sentence):
    fullTermsDict = multidict.MultiDict()
    tmpDict = {}

    # making dict for counting frequencies
    for text in sentence.split(" "):
        if re.match("a|the|an|the|to|in|for|of|or|by|with|is|on|that|be", text):
            continue
        val = tmpDict.get(text, 0)
        tmpDict[text.lower()] = val + 1
    for key in tmpDict:
        fullTermsDict.add(key, tmpDict[key])
    return fullTermsDict


def makeImage(text):
    alice_mask = np.array(Image.open("../data/alice_mask.png"))

    wc = WordCloud(background_color="white", max_words=1000, mask=alice_mask)
    # generate word cloud
    wc.generate_from_frequencies(text)

    # show
    plt.imshow(wc, interpolation="bilinear")
    plt.axis("off")
    plt.show()


# get data directory (using getcwd() is needed to support running example in generated IPython notebook)
d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

text = open(path.join(d, '../data/alice.txt'), encoding='utf-8')
text = text.read()
makeImage(getFrequencyDictForText(text))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 46
#      44 text = open(path.join(d, '../data/alice.txt'), encoding='utf-8')
#      45 text = text.read()
# ---> 46 makeImage(getFrequencyDictForText(text))
#
# Cell In[2], line 33, in makeImage(text)
#      31 wc = WordCloud(background_color="white", max_words=1000, mask=alice_mask)
#      32 # generate word cloud
# ---> 33 wc.generate_from_frequencies(text)
#      35 # show
#      36 plt.imshow(wc, interpolation="bilinear")
#
# File ~/micromamba/lib/python3.11/site-packages/wordcloud/wordcloud.py:508, in WordCloud.generate_from_frequencies(self, frequencies, max_font_size)
#     505 transposed_font = ImageFont.TransposedFont(
#     506     font, orientation=orientation)
#     507 # get size of resulting text
# --> 508 box_size = draw.textbbox((0, 0), word, font=transposed_font, anchor="lt")
#     509 # find possible places using integral image:
#     510 result = occupancy.sample_position(box_size[3] + self.margin,
#     511                                    box_size[2] + self.margin,
#     512                                    random_state)
#
# File ~/micromamba/lib/python3.11/site-packages/PIL/ImageDraw.py:703, in ImageDraw.textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color, font_size)
#     700     font = self._getfont(font_size)
#     702 if self._multiline_check(text):
# --> 703     return self.multiline_textbbox(
#     704         xy,
#     705         text,
#     706         font,
#     707         anchor,
#     708         spacing,
#     709         align,
#     710         direction,
#     711         features,
#     712         language,
#     713         stroke_width,
#     714         embedded_color,
#     715     )
#     717 mode = "RGBA" if embedded_color else self.fontmode
#     718 bbox = font.getbbox(
#     719     text, mode, direction, features, language, stroke_width, anchor
#     720 )
#
# File ~/micromamba/lib/python3.11/site-packages/PIL/ImageDraw.py:750, in ImageDraw.multiline_textbbox(self, xy, text, font, anchor, spacing, align, direction, features, language, stroke_width, embedded_color, font_size)
#     748 elif anchor[1] in "tb":
#     749     msg = "anchor not supported for multiline text"
# --> 750     raise ValueError(msg)
#     752 if font is None:
#     753     font = self._getfont(font_size)
#
# ValueError: anchor not supported for multiline text

# %%
a = getFrequencyDictForText(text)

# %%
print(a)
# Out:
# <MultiDict('﻿project': 1, 'gutenberg's': 1, 'alice's': 1, 'adventures': 1, 'wonderland,': 1, 'lewis': 1, 'carroll
#
# this': 1, 'ebook': 1, 'use': 14, 'no': 8, 'cost': 1, 'restrictions': 1, 'whatsoever.': 1, '': 881, 'you': 8, 'may': 9, 'copy': 1, 'it,': 35, 'give': 9, 'it': 4, 'under': 14, 'terms': 2, 'project': 1, 'gutenberg': 1, 'license': 1, 'this': 1, 'www.gutenberg.org
#
#
# title:': 1, 'wonderland
#
# author:': 1, 'carroll
#
# posting': 1, 'date:': 1, 'june': 1, '25,': 1, '2008': 1, '[ebook': 1, '#11]
# release': 1, 'march,': 1, '1994
# [last': 1, 'updated:': 1, 'december': 1, '20,': 1, '2011]
#
# language:': 1, 'english
#
#
# ***': 1, 'start': 1, 'of': 1, 'in': 1, 'wonderland': 1, '***
#
#
#
#
#
#
#
#
#
#
# alice's': 1, 'wonderland
#
# lewis': 1, 'carroll
#
# the': 1, 'millennium': 1, 'fulcrum': 1, 'edition': 1, '3.0
#
#
#
#
# chapter': 1, 'i.': 1, 'down': 70, 'rabbit-hole
#
# alice': 1, 'was': 2, 'get': 37, 'very': 15, 'tired': 5, 'sitting': 7, 'her': 22, 'sister': 5, 'having': 9, 'nothing': 19, 'do:': 1, 'twice': 1, 'she': 24, 'had': 157, 'peeped': 3, 'reading,': 1, 'but': 6, 'pictures': 2, 'conversations': 1, ''and': 20, 'what': 3, 'book,'': 2, 'thought': 56, 'alice': 1, ''without': 1, 'considering': 3, 'own': 9, 'mind': 4, '(as': 1, 'well': 26, 'could,': 7, 'day': 11, 'made': 26, 'feel': 7, 'sleepy': 3, 'stupid),': 1, 'whether': 8, 'pleasure
# of': 1, 'making': 7, 'daisy-chain': 1, 'would': 21, 'worth': 4, 'trouble': 3, 'getting': 20, 'up': 75, 'daisies,': 1, 'when': 6, 'suddenly': 9, 'white': 1, 'rabbit': 1, 'pink': 1, 'eyes': 15, 'ran
# close': 1, 'her.
#
# there': 1, 'so': 17, 'remarkable': 2, 'nor': 2, 'did': 47, 'think': 24, 'so
# very': 1, 'much': 37, 'out': 86, 'way': 34, 'hear': 13, 'say': 33, 'itself,': 3, ''oh': 1, 'dear!
# oh': 1, 'dear!': 8, 'i': 1, 'shall': 5, 'late!'': 1, '(when': 1, 'over': 27, 'it
# occurred': 1, 'ought': 13, 'have': 16, 'wondered': 1, 'this,': 17, 'time
# it': 1, 'seemed': 24, 'quite': 1, 'natural);': 1, 'took': 1, 'a': 1, 'watch
# out': 1, 'its': 46, 'waistcoat-pocket,': 2, 'looked': 40, 'hurried': 7, 'started': 2, 'feet,': 6, 'flashed': 1, 'had
# never': 1, 'seen': 11, 'either': 5, 'watch
# to': 1, 'take': 6, 'burning': 1, 'curiosity,': 2, 'ran': 11, 'field
# after': 1, 'just': 9, 'time': 16, 'see': 7, 'pop': 1, 'large
# rabbit-hole': 1, 'hedge.
#
# in': 1, 'moment': 17, 'went': 73, 'never': 11, 'how
# in': 1, 'world': 6, 'rabbit-hole': 1, 'straight': 2, 'like': 22, 'tunnel': 1, 'some': 39, 'way,': 5, 'down,': 11, 'not': 1, 'think
# about': 1, 'stopping': 1, 'herself': 34, 'found': 26, 'falling': 1, 'deep
# well.
#
# either': 1, 'deep,': 2, 'fell': 6, 'slowly,': 1, 'had
# plenty': 1, 'look': 23, 'wonder': 12, 'was
# going': 1, 'happen': 5, 'next.': 1, 'first,': 6, 'tried': 15, 'make': 23, 'what
# she': 1, 'coming': 3, 'dark': 3, 'she
# looked': 2, 'sides': 4, 'well,': 1, 'noticed': 6, 'were': 74, 'filled': 1, 'book-shelves;': 1, 'here': 11, 'saw': 12, 'maps': 1, 'pictures
# hung': 1, 'upon': 23, 'pegs.': 1, 'jar': 2, 'from': 2, 'shelves': 1, 'passed;': 1, 'labelled': 1, ''orange': 1, 'marmalade',': 1, 'great
# disappointment': 1, 'empty:': 1, 'drop': 1, 'fear
# of': 1, 'killing': 1, 'somebody,': 1, 'managed': 3, 'put': 27, 'cupboards': 1, 'past': 1, 'it.
#
# 'well!'': 1, 'herself,': 25, ''after': 1, 'such': 38, 'fall': 6, 'shall
# think': 1, 'tumbling': 2, 'stairs!': 1, 'how': 8, 'brave': 1, 'me': 43, 'why,': 2, 'wouldn't': 12, 'even': 6, 'if': 1, 'house!'': 1, '(which': 1, 'likely': 3, 'true.)
#
# down,': 1, 'down.': 2, 'come': 6, 'end!': 1, ''i': 1, 'how
# many': 1, 'miles': 3, 'i've': 1, 'fallen': 4, 'time?'': 1, 'said': 107, 'must': 3, 'getting
# somewhere': 1, 'near': 12, 'centre': 1, 'earth.': 2, 'let': 5, 'see:': 2, 'four
# thousand': 1, 'think--'': 2, '(for,': 1, 'see,': 11, 'learnt': 2, 'several
# things': 1, 'sort': 14, 'lessons': 3, 'schoolroom,': 1, 'though': 2, 'this
# was': 1, 'good': 21, 'opportunity': 8, 'showing': 2, 'knowledge,': 1, 'listen': 4, 'her,': 16, 'still': 12, 'practice': 1, 'over)
# '--yes,': 1, 'right': 13, 'distance--but': 1, 'latitude
# or': 1, 'longitude': 1, 'got': 41, '(alice': 1, 'idea': 12, 'latitude': 1, 'was,': 12, 'either,': 2, 'nice': 3, 'grand': 1, 'words': 11, 'say.)
#
# presently': 1, 'through': 10, 'funny': 2, 'it'll': 4, 'seem': 7, 'people': 9, 'walk': 4, 'heads': 5, 'downward!': 1, 'the': 1, 'antipathies,': 1, '(she': 6, 'rather': 21, 'glad
# there': 1, 'listening,': 2, 'time,': 5, 'didn't': 11, 'sound': 3, 'word)': 1, ''--but': 1, 'name': 6, 'country
# is,': 1, 'know.': 7, 'please,': 4, 'ma'am,': 1, 'new': 5, 'zealand': 1, 'australia?'': 1, '(and
# she': 1, 'curtsey': 1, 'spoke--fancy': 1, 'curtseying': 1, 'you're': 10, 'falling
# through': 1, 'do': 20, 'could': 3, 'manage': 6, 'it?)': 1, 'little': 51, 'girl': 3, 'she'll': 1, 'no,': 1, 'perhaps': 10, 'written': 6, 'somewhere.'
#
# down,': 1, 'there': 1, 'else': 8, 'do,': 7, 'soon': 22, ''dinah'll': 1, 'miss': 1, 'should': 24, 'think!'
# (dinah': 1, 'cat.)': 1, 'hope': 3, 'remember': 10, 'saucer': 1, 'milk': 1, 'dinah': 1, 'my': 2, 'wish': 20, 'me!': 3, 'no
# mice': 1, 'i'm': 1, 'might': 26, 'catch': 3, 'bat,': 1, 'very
# like': 1, 'mouse,': 1, 'cats': 9, 'eat': 16, 'bats,': 1, 'wonder?'': 3, 'and': 1, 'alice
# began': 1, 'sleepy,': 1, 'saying': 7, 'dreamy
# sort': 1, ''do': 1, 'bats?': 1, 'bats?'': 1, 'sometimes,': 1, ''do
# bats': 1, 'cats?'': 1, 'couldn't': 9, 'question,
# it': 1, 'matter': 6, 'which': 5, 'it.': 2, 'felt': 17, 'dozing
# off,': 1, 'dream': 3, 'walking': 3, 'hand': 9, 'earnestly,': 1, ''now,': 1, 'dinah,': 1, 'tell': 2, 'truth:
# did': 1, 'ever': 3, 'bat?'': 1, 'suddenly,': 1, 'thump!': 2, 'came': 30, 'upon
# a': 1, 'heap': 1, 'sticks': 1, 'dry': 5, 'leaves,': 2, 'over.
#
# alice': 1, 'bit': 7, 'hurt,': 1, 'jumped': 5, 'feet': 11, 'moment:
# she': 1, 'up,': 9, 'overhead;': 1, 'passage,': 2, 'sight,': 3, 'hurrying': 1, 'it.
# there': 1, 'lost:': 1, 'wind,': 1, 'say,': 5, 'turned': 13, 'corner,': 2, 'ears
# and': 1, 'whiskers,': 1, 'late': 3, 'it's': 3, 'getting!'': 1, 'close': 10, 'she
# turned': 2, 'longer': 2, 'seen:': 1, 'found
# herself': 1, 'long,': 1, 'low': 5, 'hall,': 5, 'lit': 1, 'row': 1, 'lamps': 1, 'hanging
# from': 1, 'roof.
#
# there': 1, 'doors': 2, 'round': 29, 'locked;': 1, 'when
# alice': 1, 'side': 11, 'other,': 3, 'trying': 8, 'every
# door,': 1, 'walked': 10, 'sadly': 1, 'middle,': 3, 'wondering': 5, 'three-legged': 2, 'table,': 5, 'solid
# glass;': 1, 'except': 3, 'tiny': 3, 'golden': 6, 'key,': 3, 'alice's
# first': 1, 'hall;
# but,': 1, 'locks': 1, 'large,': 1, 'key': 4, 'small,
# but': 1, 'rate': 4, 'open': 5, 'however,': 1, 'second
# time': 1, 'round,': 6, 'curtain': 1, 'door': 14, 'fifteen': 1, 'high:': 2, 'lock,': 1, 'great': 31, 'delight': 1, 'fitted!
#
# alice': 1, 'opened': 7, 'led': 3, 'small': 7, 'not
# much': 1, 'larger': 3, 'than': 2, 'rat-hole:': 1, 'knelt': 1, 'passage
# into': 1, 'loveliest': 1, 'garden': 4, 'saw.': 1, 'longed': 2, 'wander': 1, 'those': 3, 'bright': 7, 'flowers': 2, 'cool': 1, 'fountains,': 1, 'head': 26, 'go': 3, 'through,'': 1, 'poor': 24, 'alice,': 1, ''it
# would': 1, 'shoulders.': 1, 'oh,': 2, 'could
# shut': 1, 'telescope!': 1, 'know': 1, 'many': 8, 'out-of-the-way': 2, 'things': 15, 'happened': 3, 'lately,
# that': 1, 'few': 9, 'really
# impossible.
#
# there': 1, 'waiting': 3, 'door,': 5, 'went
# back': 1, 'half': 19, 'hoping': 3, 'find': 20, 'book': 2, 'rules': 3, 'shutting': 2, 'telescopes:': 1, 'this
# time': 1, 'bottle': 6, '('which': 1, 'certainly': 7, 'here
# before,'': 1, 'alice,)': 1, 'neck': 5, 'paper
# label,': 1, ''drink': 1, 'me'': 1, 'printed': 1, 'large
# letters.
#
# it': 1, 'me,'': 3, 'wise': 1, 'was
# not': 2, 'going': 18, 'that': 1, 'hurry.': 1, ''no,': 1, 'i'll': 1, 'first,'': 2, 'said,': 23, ''and
# see': 1, 'marked': 5, '"poison"': 1, 'not';': 1, 'read': 7, 'several': 3, 'nice
# little': 1, 'histories': 1, 'children': 3, 'who': 10, 'burnt,': 1, 'eaten': 1, 'wild
# beasts': 1, 'other': 21, 'unpleasant': 1, 'things,': 2, 'remember
# the': 1, 'simple': 5, 'friends': 1, 'taught': 3, 'red-hot
# poker': 1, 'will': 5, 'burn': 2, 'hold': 6, 'long;': 1, 'cut': 5, 'your
# finger': 1, 'deeply': 1, 'knife,': 1, 'usually': 2, 'bleeds;': 1, 'never
# forgotten': 1, 'drink': 4, ''poison,'': 2, 'certain': 2, 'disagree': 1, 'you,': 22, 'sooner': 2, 'later.
#
# however,': 1, 'ventured': 3, 'taste
# it,': 1, 'finding': 3, 'nice,': 1, '(it': 2, 'had,': 1, 'fact,': 4, 'mixed': 2, 'flavour
# of': 1, 'cherry-tart,': 1, 'custard,': 1, 'pine-apple,': 1, 'roast': 1, 'turkey,': 1, 'hot
# buttered': 1, 'finished': 6, '*': 51, '*
#
# ': 6, '*
#
# 'what': 1, 'curious': 15, 'feeling!'': 1, 'alice;': 1, 'now': 4, 'ten': 5, 'high,': 3, 'face
# brightened': 1, 'size': 6, 'going
# through': 1, 'lovely': 2, 'garden.': 3, 'she
# waited': 1, 'minutes': 6, 'shrink': 1, 'further:
# she': 1, 'nervous': 3, 'this;': 2, ''for': 2, 'end,': 1, 'know,'': 7, 'said
# alice': 1, ''in': 3, 'candle.': 1, 'wonder
# what': 1, 'fancy': 3, 'flame': 1, 'candle': 1, 'blown': 1, 'out,': 13, 'remember
# ever': 1, 'thing.
#
# after': 1, 'while,': 4, 'more': 4, 'happened,': 2, 'decided': 2, 'going
# into': 1, 'but,': 1, 'alice!': 1, 'she
# went': 1, 'back': 25, 'table': 6, 'possibly': 2, 'reach
# it:': 1, 'plainly': 1, 'glass,': 1, 'her
# best': 1, 'climb': 1, 'legs': 3, 'slippery;
# and': 1, 'trying,': 1, 'thing
# sat': 1, 'cried.
#
# 'come,': 1, 'crying': 2, 'herself,
# rather': 1, 'sharply;': 1, 'leave': 1, 'minute!'': 1, 'generally
# gave': 1, '(though': 1, 'seldom': 1, 'followed': 8, 'it),
# and': 1, 'sometimes': 4, 'scolded': 1, 'severely': 3, 'bring': 2, 'tears': 3, 'eyes;': 1, 'remembered': 3, 'box': 3, 'ears': 3, 'having
# cheated': 1, 'game': 5, 'croquet': 2, 'playing': 2, 'herself,
# for': 1, 'child': 3, 'fond': 2, 'pretending': 1, 'two': 6, 'people.
# 'but': 1, 'now,'': 4, ''to': 4, 'pretend': 1, 'people!
# why,': 1, 'hardly': 11, 'enough': 8, 'left': 12, 'one': 1, 'respectable': 1, 'person!'
#
# soon': 1, 'eye': 4, 'glass': 3, 'lying': 7, 'table:
# she': 1, 'cake,': 2, 'words
# 'eat': 1, 'currants.': 1, ''well,': 1, 'it,'': 18, 'said
# alice,': 1, 'makes': 7, 'grow': 9, 'larger,': 3, 'can': 18, 'reach': 3, 'key;': 1, 'it
# makes': 1, 'smaller,': 3, 'creep': 1, 'door;': 1, 'i'll
# get': 1, 'garden,': 5, 'don't': 4, 'care': 4, 'happens!'
#
# she': 1, 'bit,': 2, ''which': 1, 'way?': 1, 'which
# way?',': 1, 'holding': 2, 'was
# growing,': 1, 'surprised': 5, 'remained': 2, 'same
# size:': 1, 'sure,': 2, 'generally': 3, 'happens': 2, 'eats': 1, 'alice
# had': 1, 'expecting': 3, 'out-of-the-way
# things': 1, 'happen,': 1, 'dull': 2, 'stupid': 1, 'life': 1, 'common': 1, 'way.
#
# so': 1, 'set': 12, 'work,': 1, 'cake.
#
# ': 1, '*
#
#
#
#
# chapter': 1, 'ii.': 1, 'pool': 7, 'tears
#
# 'curiouser': 1, 'curiouser!'': 1, 'cried': 17, 'surprised,': 1, 'speak': 8, 'english);': 1, ''now': 1, 'i'm
# opening': 1, 'largest': 1, 'telescope': 1, 'was!': 1, 'good-bye,': 1, 'feet!'
# (for': 1, 'far': 9, ''oh,': 1, 'wonder
# who': 1, 'your': 14, 'shoes': 5, 'stockings': 1, 'now,': 6, 'dears?': 1, 'sure
# _i_': 1, 'shan't': 3, 'deal': 10, 'trouble
# myself': 1, 'you:': 1, 'can;--but': 1, ''or': 3, 'won't': 19, 'want
# to': 1, 'go!': 1, 'pair': 5, 'boots': 2, 'every': 8, 'christmas.'
#
# and': 1, 'planning': 1, ''they': 1, 'must
# go': 1, 'carrier,'': 1, 'thought;': 1, 'seem,': 1, 'sending
# presents': 1, 'feet!': 1, 'odd': 1, 'directions': 1, 'look!
#
# ': 1, 'foot,': 3, 'esq.
# ': 1, 'hearthrug,
# ': 1, 'fender,
# ': 1, '(with': 2, 'love).
#
# oh': 1, 'dear,': 4, 'nonsense': 1, 'talking!'
#
# just': 1, 'struck': 2, 'roof': 4, 'hall:': 1, 'fact': 2, 'was
# now': 1, 'nine': 4, 'golden
# key': 1, 'door.
#
# poor': 1, 'side,': 3, 'eye;': 2, 'more
# hopeless': 1, 'ever:': 1, 'sat': 15, 'cry': 3, 'yourself,'': 1, ''a': 1, 'like
# you,'': 1, 'this),': 1, 'way!': 1, 'stop': 4, 'this
# moment,': 1, 'you!'': 2, 'same,': 2, 'shedding': 1, 'gallons': 1, 'until': 4, 'large': 24, 'four': 4, 'reaching': 1, 'hall.
#
# after': 1, 'heard': 25, 'pattering': 3, 'distance,': 3, 'hastily': 6, 'dried': 1, 'coming.': 1, 'white
# rabbit': 1, 'returning,': 1, 'splendidly': 1, 'dressed,': 1, 'kid': 5, 'gloves': 5, 'fan': 7, 'other:': 2, 'he': 7, 'trotting': 2, 'great
# hurry,': 1, 'muttering': 3, 'himself': 4, 'came,': 1, ''oh!': 1, 'duchess,': 1, 'duchess!
# oh!': 1, 'savage': 2, 'kept': 12, 'waiting!'': 1, 'so
# desperate': 1, 'ready': 7, 'help': 8, 'so,': 6, 'rabbit
# came': 1, 'low,': 6, 'timid': 3, 'voice,': 10, ''if': 4, 'sir--'
# the': 1, 'violently,': 1, 'dropped': 3, 'fan,
# and': 1, 'skurried': 1, 'darkness': 1, 'hard': 8, 'go.
#
# alice': 1, 'gloves,': 1, 'hall': 1, 'hot,': 1, 'she
# kept': 1, 'fanning': 1, 'talking:': 1, ''dear,': 1, 'how
# queer': 1, 'everything': 8, 'yesterday': 1, 'usual.
# i': 1, 'changed': 5, 'night?': 1, 'think:': 1, 'morning?': 1, 'feeling': 5, 'different.': 1, 'next': 8, 'question': 6, 'who
# in': 1, 'i?': 1, 'ah,': 1, 'that's': 1, 'puzzle!'': 1, 'thinking
# over': 1, 'knew': 10, 'same': 18, 'sure': 13, 'ada,'': 1, 'hair': 5, 'goes': 7, 'long
# ringlets,': 1, 'mine': 3, 'doesn't': 12, 'ringlets': 1, 'can't
# be': 1, 'mabel,': 1, 'sorts': 2, 'she,': 3, 'oh!': 2, 'knows': 2, 'little!': 1, 'besides,': 1, 'she's': 3, 'i,': 1, 'puzzling
# it': 1, 'try': 12, 'used': 12, 'me
# see:': 1, 'times': 6, 'five': 1, 'twelve,': 1, 'six': 2, 'thirteen,': 1, 'seven': 1, 'twenty': 1, 'rate!
# however,': 1, 'multiplication': 1, 'signify:': 1, 'let's': 3, 'geography.
# london': 1, 'capital': 4, 'paris,': 1, 'paris': 1, 'rome,': 1, 'wrong,': 1, 'certain!': 1, '"how': 1, 'doth': 1, 'little--"'': 1, 'crossed': 3, 'her
# hands': 1, 'lap': 2, 'lessons,': 1, 'repeat': 6, 'it,
# but': 1, 'voice': 7, 'sounded': 5, 'hoarse': 1, 'strange,': 1, 'do:--
#
# ': 1, ''how': 1, 'crocodile
# ': 1, 'improve': 1, 'his': 27, 'shining': 1, 'tail,
# ': 1, 'pour': 1, 'waters': 1, 'nile
# ': 1, 'on': 1, 'scale!
#
# ': 1, 'cheerfully': 1, 'seems': 3, 'grin,
# ': 1, 'neatly': 2, 'spread': 3, 'claws,
# ': 1, 'welcome': 1, 'fishes': 1, 'with': 1, 'gently': 3, 'smiling': 2, 'jaws!'
#
# 'i'm': 1, 'words,'': 1, 'eyes
# filled': 1, 'mabel': 1, 'live': 7, 'poky': 1, 'house,': 7, 'play': 7, 'learn!': 2, 'i've
# made': 1, 'it;': 9, 'stay': 4, 'here!': 2, 'no
# use': 1, 'putting': 2, '"come': 2, 'dear!"': 1, 'i
# shall': 1, '"who': 1, 'person,': 1, 'up:': 1, 'not,': 1, 'here
# till': 1, 'somebody': 3, 'else"--but,': 1, 'oh': 1, 'dear!'': 3, 'sudden': 3, 'burst
# of': 1, 'tears,': 2, 'down!': 1, 'tired
# of': 2, 'here!'
#
# as': 1, 'hands,': 4, 'see
# that': 1, 'rabbit's': 1, 'while
# she': 1, 'talking.': 1, 'done': 8, 'thought.': 2, 'must
# be': 1, 'growing': 4, 'measure
# herself': 1, 'nearly': 7, 'guess,': 1, 'now
# about': 1, 'shrinking': 4, 'rapidly:': 1, 'found
# out': 1, 'cause': 2, 'holding,': 1, 'dropped
# it': 1, 'hastily,': 3, 'narrow': 1, 'escape!'': 1, 'frightened': 5, 'change,': 2, 'glad': 9, 'existence;': 1, ''and
# now': 1, 'garden!'': 1, 'speed': 1, 'door:
# but,': 1, 'shut': 3, 'was
# lying': 1, 'worse': 2, 'ever,'
# thought': 1, 'child,': 1, 'never!
# and': 1, 'declare': 1, 'bad,': 1, 'foot': 5, 'slipped,': 1, 'moment,': 4, 'splash!
# she': 1, 'chin': 4, 'salt': 2, 'water.': 1, 'first': 25, 'she
# had': 1, 'somehow': 1, 'sea,': 2, 'case': 4, 'herself.': 3, 'seaside': 1, 'life,': 2, 'general': 3, 'conclusion,': 1, 'wherever': 2, 'go
# to': 1, 'english': 1, 'coast': 1, 'number': 1, 'bathing': 1, 'machines': 1, 'digging': 2, 'sand': 1, 'wooden': 1, 'spades,': 1, 'row
# of': 1, 'lodging': 1, 'houses,': 1, 'railway': 1, 'station.)': 1, 'soon
# made': 1, 'wept': 1, 'she
# was': 3, 'high.
#
# 'i': 1, 'hadn't': 6, 'much!'': 1, 'swam': 5, 'trying
# to': 2, 'out.': 2, 'punished': 1, 'suppose,': 1, 'drowned': 1, 'tears!': 1, 'queer': 6, 'thing,': 4, 'sure!
# however,': 1, 'something': 11, 'splashing': 2, 'way
# off,': 1, 'nearer': 3, 'was:': 2, 'thought
# it': 1, 'walrus': 1, 'hippopotamus,': 1, 'small
# she': 1, 'mouse': 1, 'had
# slipped': 1, 'herself.
#
# 'would': 1, 'use,': 2, 'mouse?
# everything': 1, 'here,': 6, 'very
# likely': 1, 'talk:': 1, 'rate,': 2, 'harm': 1, 'trying.'': 1, 'she
# began:': 1, ''o': 1, 'pool?': 1, 'swimming': 1, 'o': 1, 'mouse!'': 1, 'right
# way': 1, 'speaking': 1, 'mouse:': 1, 'thing': 30, 'but
# she': 1, 'brother's': 1, 'latin': 1, 'grammar,': 1, 'mouse--of
# a': 1, 'mouse--to': 1, 'mouse--a': 1, 'mouse--o': 1, 'mouse!')': 1, 'rather
# inquisitively,': 1, 'wink': 2, 'eyes,
# but': 1, 'nothing.
#
# 'perhaps': 1, 'understand': 4, 'english,'': 1, 'daresay': 1, 'it's
# a': 1, 'french': 1, 'william': 1, 'conqueror.'': 1, 'knowledge': 1, 'history,': 2, 'clear': 2, 'notion': 3, 'long': 22, 'happened.)': 1, ''ou': 1, 'est': 1, 'ma': 1, 'chatte?'': 1, 'which
# was': 1, 'sentence': 3, 'lesson-book.': 1, 'gave': 2, 'leap': 1, 'water,': 1, 'quiver': 1, 'fright.
# 'oh,': 1, 'pardon!'': 4, 'hurt
# the': 1, 'feelings.': 1, 'cats.'
#
# 'not': 1, 'cats!'': 1, 'shrill,': 2, 'passionate': 1, 'voice.': 4, ''would
# you': 1, 'me?'
#
# 'well,': 1, 'not,'': 6, 'soothing': 1, ''don't': 2, 'yet': 4, 'show': 3, 'our': 5, 'cat': 3, 'dinah:': 1, 'you'd
# take': 1, 'her.': 7, 'dear': 6, 'quiet
# thing,'': 1, 'lazily': 1, 'sits': 1, 'purring': 1, 'nicely': 2, 'fire,': 2, 'licking': 1, 'paws': 2, 'face--and': 1, 'soft': 1, 'nurse--and': 1, 'she's
# such': 1, 'catching': 2, 'mice--oh,': 1, 'cried
# alice': 1, 'bristling': 1, 'over,': 2, 'she
# felt': 3, 'really': 5, ''we': 4, 'talk': 9, 'you'd': 6, 'not.'
#
# 'we': 1, 'trembling': 5, 'end': 1, 'his
# tail.': 1, ''as': 5, 'subject!': 1, 'family': 1, 'hated
# cats:': 1, 'nasty,': 1, 'vulgar': 1, 'things!': 1, 'hurry': 4, 'change': 8, 'subject': 2, ''are': 2, 'you--are': 1, 'fond--of--of': 1, 'dogs?'': 1, 'not
# answer,': 1, 'eagerly:': 1, ''there': 1, 'dog': 2, 'near
# our': 1, 'house': 7, 'you!': 2, 'bright-eyed': 1, 'terrier,': 1, 'you
# know,': 1, 'curly': 1, 'brown': 1, 'hair!': 1, 'fetch': 4, 'when
# you': 1, 'throw': 3, 'sit': 2, 'dinner,': 1, 'sorts
# of': 1, 'things--i': 1, 'can't': 22, 'farmer,
# you': 1, 'know,': 5, 'says': 3, 'useful,': 2, 'hundred': 1, 'pounds!': 1, 'he
# says': 1, 'kills': 1, 'rats': 1, 'sorrowful
# tone,': 1, ''i'm': 1, 'for': 1, 'swimming
# away': 1, 'go,': 4, 'commotion': 1, 'went.
#
# so': 1, 'called': 10, 'softly': 1, ''mouse': 1, 'we
# won't': 1, 'dogs': 1, 'slowly': 4, 'her:': 3, 'its
# face': 1, 'pale': 2, 'passion,': 2, 'thought),': 1, 'low
# trembling': 1, ''let': 1, 'us': 7, 'shore,': 2, 'my
# history,': 1, 'you'll': 4, 'why': 5, 'hate': 1, 'dogs.'
#
# it': 1, 'high': 1, 'crowded': 4, 'it:': 7, 'duck': 2, 'dodo,
# a': 1, 'lory': 1, 'eaglet,': 1, 'creatures.': 1, 'whole': 11, 'party': 7, 'shore.
#
#
#
#
# chapter': 1, 'iii.': 1, 'caucus-race': 1, 'tale
#
# they': 1, 'queer-looking': 1, 'bank--the
# birds': 1, 'draggled': 1, 'feathers,': 1, 'fur': 2, 'clinging': 1, 'close
# to': 1, 'dripping': 1, 'wet,': 1, 'cross,': 1, 'uncomfortable.
#
# the': 1, 'course': 11, 'natural
# to': 1, 'talking': 10, 'familiarly': 1, 'had
# known': 1, 'life.': 1, 'indeed,': 1, 'last': 23, 'sulky,': 1, 'older': 2, 'than
# you,': 1, 'old': 12, 'positively': 1, 'refused': 1, 'its
# age,': 1, 'said.
#
# at': 1, 'person': 2, ''sit': 1, 'you
# dry': 1, 'enough!'': 1, 'they': 1, 'ring,': 2, 'mouse
# in': 1, 'middle.': 1, 'fixed': 1, 'felt
# sure': 1, 'bad': 1, 'cold': 1, 'soon.
#
# 'ahem!'': 1, 'important': 2, 'ready?': 1, 'this
# is': 1, 'driest': 1, 'silence': 4, 'please!': 1, '"william
# the': 1, 'conqueror,': 1, 'whose': 2, 'favoured': 1, 'pope,': 1, 'submitted
# to': 1, 'english,': 1, 'wanted': 4, 'leaders,': 1, 'much
# accustomed': 1, 'usurpation': 1, 'conquest.': 1, 'edwin': 1, 'morcar,': 1, 'earls': 2, 'northumbria--"'
#
# 'ugh!'': 1, 'lory,': 1, 'shiver.
#
# 'i': 1, 'frowning,': 1, 'politely:': 1, ''did
# you': 1, 'speak?'
#
# 'not': 1, 'i!'': 1, 'hastily.
#
# 'i': 1, 'did,'': 3, 'mouse.': 1, ''--i': 1, 'proceed.': 1, '"edwin': 1, 'morcar,
# the': 1, 'mercia': 1, 'northumbria,': 1, 'declared': 1, 'him:': 2, 'stigand,
# the': 1, 'patriotic': 1, 'canterbury,': 1, 'what?'': 2, 'duck.
#
# 'found': 1, 'replied': 14, 'crossly:': 1, ''of': 1, 'what
# "it"': 1, 'means.'
#
# 'i': 1, '"it"': 1, 'means': 2, 'enough,': 2, 'thing,'': 2, ''it's': 2, 'frog': 1, 'worm.': 1, 'find?'
#
# the': 1, 'notice': 4, 'question,': 2, 'hurriedly': 2, ''"--found
# it': 1, 'edgar': 1, 'atheling': 1, 'meet': 2, 'him': 1, 'william's': 1, 'conduct': 1, 'moderate.': 1, 'his
# normans--"': 1, 'dear?'': 1, 'continued,': 2, 'turning
# to': 1, 'spoke.
#
# 'as': 1, 'wet': 1, 'ever,'': 1, 'melancholy': 5, ''it': 1, 'case,'': 1, 'dodo': 1, 'solemnly,': 1, 'rising': 1, 'move
# that': 1, 'meeting': 1, 'immediate': 1, 'energetic
# remedies--'
#
# 'speak': 1, 'english!'': 1, 'eaglet.': 1, 'meaning': 6, 'half
# those': 1, 'words,': 1, 'what's': 2, 'more,': 4, 'either!'': 1, 'and
# the': 1, 'eaglet': 1, 'hide': 1, 'smile:': 1, 'birds
# tittered': 1, 'say,'': 4, ''was,': 1, 'caucus-race.'
#
# 'what': 1, 'is': 1, 'caucus-race?'': 1, 'know,
# but': 1, 'paused': 1, 'speak,
# and': 1, 'dodo,': 1, ''the': 1, 'explain': 7, 'it.'': 4, '(and,': 1, 'yourself,': 1, 'winter': 1, 'day,': 4, 'tell
# you': 1, 'it.)
#
# first': 1, 'race-course,': 1, 'circle,': 1, '('the': 1, 'exact
# shape': 1, 'matter,'': 1, 'said,)': 1, 'placed
# along': 1, 'course,': 5, ''one,': 1, 'two,': 4, 'three,': 1, 'running': 6, 'liked,': 1, 'easy': 2, 'race': 2, 'over.': 1, 'however,
# when': 1, 'hour': 2, 'over!'': 2, 'crowded
# round': 1, 'panting,': 2, ''but': 6, 'has': 3, 'won?'
#
# this': 1, 'thought,
# and': 1, 'finger': 2, 'pressed': 2, 'position': 2, 'shakespeare,': 1, 'pictures
# of': 1, 'him),': 1, 'while': 4, 'rest': 9, 'waited': 7, 'silence.': 2, 'at': 1, 'said,
# 'everybody': 1, 'won,': 1, 'prizes.'
#
# 'but': 1, 'prizes?'': 1, 'chorus': 2, 'voices': 1, 'course,'': 5, 'pointing': 3, 'finger;
# and': 1, 'calling': 1, 'confused
# way,': 1, ''prizes!': 1, 'prizes!'
#
# alice': 1, 'despair': 1, 'her
# pocket,': 1, 'pulled': 1, 'comfits,': 1, '(luckily': 1, 'water': 2, 'had
# not': 1, 'it),': 1, 'handed': 3, 'prizes.': 1, 'exactly': 1, 'round.
#
# 'but': 1, 'prize': 1, 'mouse.
#
# 'of': 1, 'gravely.': 1, ''what': 1, 'pocket?'': 1, 'turning': 10, 'alice.
#
# 'only': 1, 'thimble,'': 1, 'sadly.
#
# 'hand': 1, 'here,'': 5, 'dodo.
#
# then': 1, 'solemnly
# presented': 1, 'thimble,': 2, 'elegant
# thimble';': 1, 'short': 2, 'speech,': 1, 'cheered.
#
# alice': 1, 'grave
# that': 1, 'dare': 4, 'laugh;': 1, 'simply': 1, 'bowed,': 1, 'looking': 22, 'solemn': 3, 'she
# could.
#
# the': 1, 'comfits:': 1, 'caused': 2, 'noise': 2, 'birds': 2, 'complained': 1, 'taste
# theirs,': 1, 'choked': 2, 'patted': 1, 'back.
# however,': 1, 'last,': 5, 'more.
#
# 'you': 1, 'promised': 1, 'why
# it': 1, 'hate--c': 1, 'd,'': 1, 'whisper,': 1, 'it
# would': 1, 'sad': 2, 'tale!'': 1, 'tail,': 2, 'certainly,'': 3, 'mouse's': 1, 'tail;': 1, 'call': 5, 'sad?'': 1, 'puzzling
# about': 1, 'speaking,': 3, 'tale': 1, 'was
# something': 1, 'this:--
#
# ': 2, ''fury': 1, 'he
# ': 1, 'met': 3, 'house,
# ': 1, '"let': 1, 'us
# ': 1, 'both': 13, 'law:': 1, 'will
# ': 1, 'prosecute
# ': 1, 'you.--come,
# ': 1, 'no
# ': 1, 'denial;': 1, 'we
# ': 1, 'trial:': 1, 'for
# ': 1, 'this
# ': 1, 'morning': 1, 'i've
# ': 1, 'nothing
# ': 1, 'do."
# ': 1, 'cur,': 1, '"such
# ': 1, 'trial,
# ': 1, 'sir,
# ': 1, 'with
# ': 1, 'jury
# ': 1, 'judge,
# ': 1, 'wasting
# ': 1, 'our
# ': 1, 'breath."
# ': 1, '"i'll': 1, 'judge,': 2, 'i'll
# ': 1, 'jury,"
# ': 1, 'said
# ': 1, 'cunning
# ': 1, 'fury:
# ': 1, '"i'll
# ': 1, 'whole
# ': 1, 'cause,
# ': 1, 'condemn
# ': 1, 'you
# ': 1, 'death."'
#
#
# 'you': 1, 'severely.': 1, 'you
# thinking': 1, 'pardon,'': 1, 'humbly:': 1, ''you': 2, 'fifth
# bend,': 1, 'think?'
#
# 'i': 1, 'not!'': 2, 'sharply': 1, 'knot!'': 1, 'looking
# anxiously': 3, 'undo': 1, 'it!'
#
# 'i': 1, 'sort,'': 1, 'walking
# away.': 1, 'nonsense!'
#
# 'i': 1, 'mean': 7, 'it!'': 3, 'pleaded': 3, 'alice.': 1, 'easily': 2, 'know!'
#
# the': 1, 'growled': 1, 'reply.
#
# 'please': 1, 'finish': 4, 'story!'': 2, 'joined': 2, 'chorus,': 1, ''yes,': 1, 'please': 7, 'do!'': 3, 'shook
# its': 1, 'impatiently,': 2, 'quicker.
#
# 'what': 1, 'pity': 1, 'stay!'': 1, 'sighed': 5, 'quite
# out': 1, 'sight;': 1, 'crab': 1, 'her
# daughter': 1, ''ah,': 1, 'lesson': 1, 'lose
# your': 1, 'temper!'': 1, ''hold': 1, 'ma!'': 1, 'young': 5, 'crab,': 2, 'little
# snappishly.': 1, ''you're': 1, 'patience': 1, 'oyster!'
#
# 'i': 1, 'particular.': 1, ''she'd': 1, 'back!'
#
# 'and': 1, 'venture': 3, 'question?'': 1, 'eagerly,': 2, 'pet:
# 'dinah's': 1, 'cat.': 1, 'mice': 2, 'you
# can't': 1, 'think!': 1, 'birds!': 1, 'why,
# she'll': 1, 'bird': 1, 'it!'
#
# this': 1, 'speech': 1, 'sensation': 1, 'party.': 1, 'magpie': 1, 'wrapping': 1, 'itself': 7, 'very
# carefully,': 1, 'remarking,': 1, 'home;': 1, 'night-air
# doesn't': 1, 'suit': 2, 'throat!'': 1, 'canary': 1, 'children,': 3, ''come': 1, 'dears!': 1, 'various': 1, 'pretexts': 1, 'moved': 3, 'mentioned': 3, 'dinah!'': 1, 'melancholy
# tone.': 1, ''nobody': 1, 'world!': 1, 'dinah!': 1, 'you
# any': 1, 'more!'': 1, 'very
# lonely': 1, 'low-spirited.': 1, 'heard
# a': 2, 'footsteps': 1, 'up
# eagerly,': 1, 'mind,': 2, 'coming
# back': 1, 'story.
#
#
#
#
# chapter': 1, 'iv.': 1, 'sends': 1, 'bill
#
# it': 1, 'rabbit,': 1, 'went,': 1, 'lost': 1, 'something;': 1, 'heard
# it': 1, 'duchess!': 1, 'paws!': 1, 'oh
# my': 1, 'whiskers!': 1, 'executed,': 2, 'ferrets': 1, 'where': 5, 'guessed': 3, 'gloves,
# and': 2, 'good-naturedly': 1, 'hunting': 3, 'were
# nowhere': 1, 'seen--everything': 1, 'since': 4, 'swim': 1, 'pool,': 1, 'door,
# had': 1, 'vanished': 3, 'completely.
#
# very': 1, ''why,': 1, 'mary': 1, 'ann,': 1, 'are': 1, 'doing
# out': 1, 'here?': 2, 'run': 4, 'home': 1, 'fan!
# quick,': 1, 'now!'': 2, 'direction': 2, 'pointed': 1, 'mistake': 2, 'it
# had': 1, 'made.
#
# 'he': 1, 'housemaid,'': 1, 'ran.': 1, ''how
# surprised': 1, 'he'll': 1, 'finds': 1, 'i'd': 1, 'him
# his': 1, 'gloves--that': 1, 'as': 1, 'she
# came': 1, 'neat': 1, 'brass
# plate': 1, ''w.': 1, 'rabbit'': 1, 'engraved': 1, 'upstairs,': 1, 'fear': 2, 'lest': 1, 'gloves.
#
# 'how': 1, 'seems,'': 1, 'messages': 2, 'rabbit!': 1, 'suppose': 5, 'dinah'll': 1, 'sending': 1, 'next!'': 1, 'she
# began': 2, 'fancying': 1, 'happen:': 1, ''"miss': 1, 'come
# here': 1, 'directly,': 1, 'walk!"': 1, '"coming': 1, 'minute,
# nurse!': 1, 'out."': 1, 'only': 1, 'don't
# think,'': 1, ''that': 7, 'it
# began': 1, 'tidy': 1, 'room': 7, 'table
# in': 1, 'window,': 4, 'hoped)': 1, 'three': 21, 'pairs
# of': 1, 'gloves:': 1, 'room,': 1, 'little
# bottle': 1, 'stood': 7, 'looking-glass.': 1, 'label': 1, 'time
# with': 1, 'nevertheless': 1, 'uncorked': 1, 'it
# to': 1, 'lips.': 1, 'happen,'': 1, 'said
# to': 4, ''whenever': 1, 'what
# this': 1, 'does.': 1, 'really
# i'm': 1, 'thing!'
#
# it': 1, 'expected:': 1, 'had
# drunk': 1, 'bottle,': 2, 'pressing': 1, 'ceiling,
# and': 1, 'stoop': 1, 'save': 1, 'broken.': 1, 'put
# down': 3, ''that's': 1, 'enough--i': 1, 'shan't
# grow': 1, 'more--as': 1, 'door--i': 1, 'hadn't
# drunk': 1, 'much!'
#
# alas!': 1, 'growing,': 2, 'growing,
# and': 1, 'kneel': 1, 'floor:': 1, 'minute': 12, 'effect': 1, 'elbow': 2, 'curled': 2, 'head.
# still': 1, 'resource,': 1, 'out
# of': 1, 'chimney,': 2, 'i
# can': 1, 'whatever': 1, 'happens.': 1, 'me?'
#
# luckily': 1, 'magic': 1, 'full': 5, 'effect,
# and': 1, 'grew': 1, 'larger:': 1, 'uncomfortable,': 1, 'chance': 4, 'room
# again,': 1, 'unhappy.
#
# 'it': 1, 'pleasanter': 1, 'home,'': 1, ''when': 1, 'wasn't
# always': 1, 'gone': 8, 'rabbit-hole--and': 1, 'yet--and
# yet--it's': 1, 'curious,': 1, 'life!': 1, 'what
# can': 1, 'fairy-tales,': 1, 'fancied': 1, 'middle': 3, 'me,': 1, 'ought!': 1, 'i
# grow': 1, 'write': 5, 'grown': 7, 'sorrowful
# tone;': 1, ''at': 2, 'least': 7, 'here.'
#
# 'but': 1, ''shall': 1, 'that'll': 1, 'comfort,': 1, 'way--never': 1, 'woman--but
# then--always': 1, 'shouldn't': 4, 'that!'
#
# 'oh,': 1, 'foolish': 1, 'alice!'': 1, 'learn
# lessons': 1, 'lesson-books!'
#
# and': 1, 'taking': 5, 'making
# quite': 1, 'conversation': 3, 'outside,': 1, 'stopped': 2, 'listen.
#
# 'mary': 1, 'ann!': 1, 'ann!'': 1, ''fetch': 2, 'moment!'
# then': 1, 'stairs.': 1, 'was
# the': 1, 'trembled': 2, 'till': 15, 'shook': 8, 'thousand': 1, 'large
# as': 1, 'reason': 7, 'it.
#
# presently': 1, 'it,
# that': 1, 'proved': 2, 'failure.': 1, ''then': 1, 'i'll
# go': 1, 'window.'
#
# 'that': 1, 'won't'': 1, 'fancied
# she': 1, 'her
# hand,': 2, 'snatch': 2, 'shriek': 2, 'fall,': 1, 'crash': 1, 'broken': 5, 'glass,
# from': 1, 'concluded': 2, 'possible': 1, 'sort.
#
# next': 1, 'voice--the': 1, 'rabbit's--'pat!': 1, 'pat!': 1, 'you?'': 4, 'and
# then': 1, ''sure': 1, 'digging
# for': 1, 'yer': 4, 'honour!'
#
# 'digging': 1, ''here!': 1, 'this!'': 1, '(sounds': 1, 'glass.)
#
# 'now': 1, 'pat,': 1, 'window?'
#
# 'sure,': 1, 'honour!'': 1, '(he': 1, 'pronounced': 1, ''arrum.')
#
# 'an': 1, 'goose!': 1, 'size?': 1, 'fills': 1, 'whole
# window!'
#
# 'sure,': 1, 'does,': 1, 'honour:': 1, 'business': 1, 'rate:': 1, 'whispers
# now': 1, ''sure,': 1, 'honour,': 1, 'coward!'': 1, 'her
# hand': 1, 'were
# two': 1, 'shrieks,': 1, 'sounds': 2, 'glass.': 1, 'do
# next!': 1, 'pulling': 1, 'could!': 1, 'i'm
# sure': 1, 'want': 8, 'longer!'
#
# she': 1, 'hearing': 3, 'more:': 1, 'cartwheels,': 1, 'voices
# all': 1, 'words:': 1, ''where's': 1, 'other
# ladder?--why,': 1, 'bill's': 1, 'other--bill!
# fetch': 1, 'lad!--here,': 1, ''em': 2, 'corner--no,': 1, 'tie': 1, ''em
# together': 1, 'first--they': 1, 'yet--oh!': 1, 'enough;': 2, 'particular--here,': 1, 'bill!': 1, 'this
# rope--will': 1, 'loose': 1, 'slate--oh,': 1, 'coming
# down!': 1, '(a': 1, 'loud': 3, 'crash)--'now,': 1, 'bill,': 1, 'i
# fancy--who's': 1, 'chimney?--nay,': 1, 'shan't!': 1, 'it!--that': 1, 'i
# won't,': 1, 'down--here,': 1, 'master': 2, 'chimney!'
#
# 'oh!': 1, 'he?'': 1, ''shy,': 1, 'place': 5, 'deal:': 1, 'fireplace': 1, 'narrow,': 1, 'sure;': 1, 'but
# i': 1, 'kick': 2, 'little!'
#
# she': 1, 'drew': 5, 'chimney': 2, 'waited
# till': 1, 'guess': 2, 'was)
# scratching': 1, 'scrambling': 1, ''this': 2, 'bill,'': 1, 'sharp': 4, 'kick,': 1, 'next.
#
# the': 1, 'bill!'
# then': 1, 'him,': 1, 'hedge!'': 1, 'confusion': 3, 'voices--'hold': 1, 'head--brandy
# now--don't': 1, 'choke': 1, 'him--how': 1, 'fellow?': 1, 'you?': 1, 'tell
# us': 1, 'it!'
#
# last': 1, 'feeble,': 1, 'squeaking': 2, '('that's': 1, 'thought
# alice,)': 1, 'know--no': 1, 'thank': 1, 'ye;': 1, 'now--but': 1, 'i'm
# a': 1, 'flustered': 1, 'you--all': 1, 'comes': 1, 'me
# like': 1, 'jack-in-the-box,': 1, 'sky-rocket!'
#
# 'so': 1, 'did,': 3, 'fellow!'': 1, 'others.
#
# 'we': 1, 'down!'': 1, 'voice;': 2, 'called
# out': 2, 'do.': 1, 'you!'
#
# there': 1, 'dead': 3, ''i
# wonder': 1, 'next!': 1, 'sense,': 2, 'after': 1, 'moving': 3, 'barrowful': 2, 'doubt,
# for': 1, 'shower': 1, 'pebbles': 2, 'rattling': 1, 'hit': 2, 'face.': 1, ''i'll': 1, 'this,'
# she': 1, 'shouted': 8, ''you'd': 1, 'produced': 1, 'silence.
#
# alice': 1, 'surprise': 1, 'cakes': 1, 'lay': 4, 'floor,': 2, 'her
# head.': 1, 'cakes,'': 1, 'thought,': 5, 'make
# some': 1, 'size;': 1, 'must
# make': 1, 'suppose.'
#
# so': 1, 'swallowed': 1, 'cakes,': 1, 'delighted': 2, 'directly.': 1, 'through
# the': 1, 'crowd': 4, 'little
# animals': 1, 'outside.': 1, 'lizard,': 1, 'was
# in': 1, 'held': 3, 'guinea-pigs,': 1, 'giving': 2, 'it
# something': 1, 'bottle.': 1, 'rush': 2, 'she
# appeared;': 1, 'herself
# safe': 1, 'thick': 1, 'wood.
#
# 'the': 1, 'do,'': 4, 'wandered
# about': 1, 'wood,': 1, ''is': 1, 'second
# thing': 1, 'plan.'
#
# it': 1, 'excellent': 2, 'plan,': 1, 'doubt,': 1, 'simply
# arranged;': 1, 'difficulty': 3, 'smallest': 2, 'idea
# how': 1, 'peering': 1, 'trees,': 2, 'bark': 2, 'hurry.
#
# an': 1, 'enormous': 1, 'puppy': 5, 'eyes,': 3, 'stretching': 1, 'paw,': 2, ''poor': 1, 'thing!'
# said': 2, 'coaxing': 1, 'whistle': 1, 'terribly': 1, 'spite': 1, 'coaxing.
#
# hardly': 1, 'knowing': 1, 'picked': 2, 'stick,': 3, 'puppy;': 1, 'whereupon': 1, 'yelp': 1, 'delight,': 2, 'rushed': 1, 'stick,
# and': 1, 'worry': 1, 'dodged': 1, 'thistle,
# to': 1, 'keep': 8, 'over;': 1, 'tumbled': 1, 'head
# over': 1, 'heels': 1, 'thinking': 7, 'was
# very': 1, 'cart-horse,': 1, 'every
# moment': 1, 'trampled': 1, 'thistle': 1, 'series': 1, 'charges': 1, 'very
# little': 1, 'each': 6, 'back,': 4, 'barking': 1, 'hoarsely
# all': 1, 'hanging': 2, 'mouth,': 2, 'shut.
#
# this': 1, 'escape;': 1, 'she
# set': 2, 'breath,': 2, 'puppy's': 1, 'faint': 1, 'distance.
#
# 'and': 1, 'was!'': 1, 'leant
# against': 1, 'buttercup': 1, 'fanned': 1, 'liked': 3, 'teaching': 1, 'tricks': 1, 'much,': 2, 'if--if': 1, 'i'd
# only': 1, 'it!': 1, 'see--how': 1, 'managed?': 1, 'i
# suppose': 1, 'other;': 1, 'great
# question': 1, 'what?'
#
# the': 1, 'what?': 1, 'blades': 1, 'grass,': 2, 'circumstances.
# there': 1, 'mushroom': 4, 'height': 4, 'occurred': 1, 'what
# was': 1, 'it.
#
# she': 1, 'stretched': 1, 'tiptoe,': 1, 'edge': 3, 'immediately': 3, 'caterpillar,
# that': 1, 'folded,': 2, 'quietly': 4, 'smoking': 2, 'long
# hookah,': 1, 'else.
#
#
#
#
# chapter': 1, 'v.': 1, 'advice': 1, 'caterpillar
#
# the': 1, 'caterpillar': 1, 'silence:
# at': 1, 'hookah': 3, 'languid,': 1, 'voice.
#
# 'who': 1, 'caterpillar.
#
# this': 1, 'encouraging': 2, 'opening': 2, 'conversation.': 2, 'replied,
# rather': 1, 'shyly,': 1, ''i--i': 1, 'sir,': 3, 'present--at': 1, 'know
# who': 1, 'morning,': 2, 'sternly.': 1, ''explain
# yourself!'
#
# 'i': 1, 'myself,': 1, 'sir'': 1, ''because': 2, 'not
# myself,': 1, 'see.'
#
# 'i': 1, 'see,'': 1, 'caterpillar.
#
# 'i'm': 1, 'clearly,'': 1, 'politely,
# 'for': 1, 'myself': 1, 'many
# different': 1, 'sizes': 1, 'confusing.'
#
# 'it': 1, 'caterpillar.
#
# 'well,': 1, 'haven't': 5, 'yet,'': 3, 'you
# have': 1, 'turn': 6, 'chrysalis--you': 1, 'know--and': 1, 'butterfly,': 1, 'little
# queer,': 1, 'you?'
#
# 'not': 1, 'bit,'': 2, 'feelings': 1, 'different,'': 1, ''all': 1, 'know
# is,': 1, 'me.'
#
# 'you!'': 1, 'contemptuously.': 1, ''who': 1, 'you?'
#
# which': 1, 'brought': 3, 'conversation.
# alice': 1, 'irritated': 1, 'caterpillar's': 1, 'very
# short': 1, 'remarks,': 1, 'gravely,': 2, 'think,
# you': 1, 'first.'
#
# 'why?'': 1, 'caterpillar.
#
# here': 1, 'puzzling': 2, 'question;': 1, 'reason,': 1, 'unpleasant
# state': 1, 'back!'': 1, ''i've': 1, 'important
# to': 1, 'say!'
#
# this': 1, 'promising,': 1, 'certainly:': 2, 'temper,'': 1, 'caterpillar.
#
# 'is': 1, 'swallowing': 1, 'she
# could.
#
# 'no,'': 1, 'caterpillar.
#
# alice': 1, 'wait,': 1, 'hearing.': 1, 'some
# minutes': 1, 'puffed': 1, 'unfolded': 2, 'its
# arms,': 1, 'mouth': 5, ''so': 4, 'think
# you're': 1, 'changed,': 1, 'you?'
#
# 'i'm': 1, 'sir,'': 1, 'i
# used--and': 1, 'things?'': 1, 'busy': 2, 'bee,"': 1, 'came
# different!'': 1, 'voice.
#
# 'repeat,': 1, '"you': 1, 'old,': 1, 'father': 1, 'william,"'': 1, 'folded': 1, 'william,'': 1, 'man': 1, 'said,
# ': 1, 'white;
# ': 1, 'stand': 4, 'head--
# ': 1, 'think,': 1, 'right?'
#
# ': 1, 'youth,'': 3, 'son,
# ': 1, 'feared': 1, 'brain;
# ': 1, 'perfectly': 2, 'none,
# ': 1, 'old,'': 3, 'youth,': 3, 'most': 7, 'uncommonly': 1, 'fat;
# ': 1, 'back-somersault': 1, 'door--
# ': 1, 'pray,': 1, 'sage,': 1, 'grey': 1, 'locks,
# ': 1, 'limbs': 1, 'supple
# ': 1, 'by': 1, 'ointment--one': 1, 'shilling': 1, 'box--
# ': 1, 'allow': 1, 'sell': 1, 'couple?'
#
# ': 1, 'jaws': 1, 'weak
# ': 1, 'suet;
# ': 1, 'goose,': 1, 'bones': 1, 'pray': 1, 'it?'
#
# ': 1, 'father,': 1, 'law,
# ': 1, 'wife;
# ': 1, 'muscular': 1, 'strength,': 1, 'jaw,
# ': 1, 'lasted': 1, 'life.'
#
# ': 1, ''one': 1, 'suppose
# ': 1, 'steady': 1, 'ever;
# ': 1, 'balanced': 1, 'eel': 1, 'nose--
# ': 1, 'clever?'
#
# ': 1, 'questions,': 1, 'enough,'
# ': 1, 'father;': 1, 'yourself': 5, 'stuff?
# ': 1, 'be': 1, 'stairs!'
#
#
# 'that': 1, 'right,'': 3, 'caterpillar.
#
# 'not': 1, 'right,': 3, 'timidly;': 1, ''some': 1, 'words
# have': 1, 'wrong': 2, 'end,'': 1, 'decidedly,': 3, 'minutes.
#
# the': 1, 'speak.
#
# 'what': 1, 'particular': 1, 'size,'': 1, 'replied;': 2, ''only': 1, 'changing': 2, 'know.'
#
# 'i': 1, 'nothing:': 1, 'contradicted': 1, 'life
# before,': 1, 'losing': 1, 'temper.
#
# 'are': 1, 'content': 1, 'now?'': 2, 'mind,'
# said': 1, 'alice:': 1, ''three': 1, 'wretched': 2, 'rearing
# itself': 1, 'upright': 1, 'spoke': 4, 'high).
#
# 'but': 1, 'piteous': 1, 'and
# she': 1, 'creatures': 4, 'easily
# offended!'
#
# 'you'll': 1, 'time,'': 4, 'caterpillar;': 1, 'patiently': 1, 'chose': 1, 'in
# a': 1, 'mouth
# and': 1, 'yawned': 2, 'twice,': 3, 'itself.': 1, 'then': 1, 'crawled': 1, 'merely': 2, 'remarking': 2, 'went,
# 'one': 1, 'taller,': 1, 'you
# grow': 1, 'shorter.'
#
# 'one': 1, 'herself.
#
# 'of': 1, 'mushroom,'': 1, 'caterpillar,': 1, 'it
# aloud;': 1, 'sight.
#
# alice': 1, 'thoughtfully': 1, 'minute,': 2, 'perfectly
# round,': 1, 'difficult': 2, 'question.': 2, 'she
# stretched': 1, 'broke': 2, 'bit
# of': 1, 'hand.
#
# 'and': 1, 'which?'': 1, 'nibbled': 1, 'right-hand': 1, 'effect:': 1, 'violent
# blow': 1, 'underneath': 1, 'chin:': 1, 'foot!
#
# she': 1, 'felt
# that': 1, 'lost,': 1, 'rapidly;': 1, 'work': 7, 'bit.': 1, 'pressed
# so': 1, 'closely': 1, 'her
# mouth;': 1, 'swallow': 1, 'morsel': 1, 'bit.
#
#
# ': 1, '*
#
# 'come,': 1, 'head's': 1, 'free': 2, 'last!'': 1, 'which
# changed': 1, 'shoulders
# were': 1, 'nowhere': 1, 'found:': 1, 'was
# an': 1, 'immense': 1, 'length': 1, 'neck,': 1, 'rise': 1, 'stalk': 1, 'green': 3, 'leaves': 1, 'her.
#
# 'what': 1, 'stuff': 1, 'my
# shoulders': 1, 'you?'
# she': 1, 'spoke,': 5, 'result': 1, 'follow,
# except': 1, 'shaking': 3, 'distant': 2, 'leaves.
#
# as': 1, 'hands': 4, 'head,': 3, 'she
# tried': 1, 'her
# neck': 1, 'direction,': 1, 'serpent.': 1, 'had
# just': 1, 'succeeded': 2, 'curving': 1, 'graceful': 1, 'zigzag,': 1, 'going
# to': 2, 'dive': 1, 'trees': 5, 'wandering,': 1, 'hiss': 1, 'made
# her': 1, 'draw': 4, 'hurry:': 1, 'pigeon': 1, 'flown': 1, 'face,': 3, 'violently': 2, 'wings.
#
# 'serpent!'': 1, 'screamed': 4, 'pigeon.
#
# 'i'm': 1, 'serpent!'': 1, 'repeated': 6, 'pigeon,': 1, 'subdued': 1, 'kind': 4, 'sob,': 1, 'seems
# to': 1, 'alice.
#
# 'i've': 1, 'roots': 1, 'banks,': 1, 'tried
# hedges,'': 1, 'her;': 3, 'those
# serpents!': 1, 'there's': 1, 'pleasing': 1, 'puzzled,': 1, 'finished.
#
# 'as': 1, 'wasn't': 10, 'hatching': 1, 'eggs,'': 1, 'pigeon;
# 'but': 1, 'look-out': 1, 'serpents': 2, 'night': 1, 'day!': 1, 'i
# haven't': 1, 'sleep': 4, 'weeks!'
#
# 'i'm': 1, 'sorry': 1, 'you've': 3, 'meaning.
#
# 'and': 1, 'taken': 4, 'highest': 1, 'tree': 2, 'wood,'': 1, 'continued': 7, 'raising': 1, 'shriek,': 2, 'i
# should': 1, 'needs': 1, 'wriggling': 1, 'from
# the': 1, 'sky!': 1, 'ugh,': 1, 'serpent!'
#
# 'but': 1, 'serpent,': 2, 'pigeon.': 1, 'something!'
#
# 'i--i'm': 1, 'girl,'': 1, 'doubtfully,': 1, 'remembered
# the': 1, 'changes': 2, 'day.
#
# 'a': 1, 'story': 2, 'deepest
# contempt.': 1, 'girls': 3, 'one
# with': 1, 'no!': 2, 'serpent;': 1, 'use
# denying': 1, 'telling': 2, 'tasted': 2, 'eggs,': 3, 'truthful
# child;': 1, 'eggs': 1, 'you
# know.'
#
# 'i': 1, 'pigeon;': 1, 'say.'
#
# this': 1, 'silent': 3, ''you're
# looking': 1, 'does': 1, 'me
# whether': 1, 'serpent?'
#
# 'it': 1, 'matters': 2, 'hastily;': 1, 'looking
# for': 1, 'happens;': 1, 'yours:': 1, 'don't
# like': 1, 'raw.'
#
# 'well,': 1, 'sulky': 2, 'settled
# down': 1, 'nest.': 1, 'crouched': 1, 'entangled': 2, 'branches,': 1, 'untwist': 1, 'she
# remembered': 1, 'pieces': 2, 'carefully,': 2, 'nibbling': 3, 'taller': 1, 'shorter,': 1, 'had
# succeeded': 1, 'bringing': 2, 'usual': 1, 'height.
#
# it': 1, 'size,': 1, 'it
# felt': 1, 'strange': 4, 'first;': 2, 'minutes,
# and': 1, 'usual.': 1, ''come,': 1, 'plan': 1, 'done
# now!': 1, 'right
# size:': 1, 'garden--how': 1, 'done,': 1, 'open
# place,': 1, 'high.': 1, ''whoever': 1, 'lives
# there,'': 1, ''it'll': 1, 'size:': 1, 'why,
# i': 1, 'frighten': 1, 'wits!'': 1, 'high.
#
#
#
#
# chapter': 1, 'vi.': 1, 'pig': 1, 'pepper
#
# for': 1, 'what
# to': 1, 'next,': 2, 'footman': 1, 'livery': 1, 'considered': 3, 'livery:
# otherwise,': 1, 'judging': 1, 'face': 4, 'rapped': 1, 'loudly': 2, 'knuckles.': 1, 'opened
# by': 1, 'livery,': 1, 'footmen,': 1, 'noticed,': 1, 'powdered': 1, 'heads.': 1, 'crept': 1, 'wood': 1, 'listen.
#
# the': 1, 'fish-footman': 1, 'producing': 1, 'letter,
# nearly': 1, 'himself,': 1, 'other,
# saying,': 1, 'duchess.': 1, 'an': 1, 'queen
# to': 1, 'croquet.'': 1, 'frog-footman': 1, 'repeated,': 1, 'little,': 3, ''from': 1, 'queen.': 1, 'an
# invitation': 1, 'duchess': 1, 'croquet.'
#
# then': 1, 'bowed': 3, 'curls': 1, 'laughed': 1, 'gone,': 3, 'ground': 1, 'staring': 3, 'stupidly': 1, 'sky.
#
# alice': 1, 'timidly': 2, 'knocked.
#
# 'there's': 1, 'knocking,'': 2, 'footman,': 1, 'reasons.': 1, 'you
# are;': 1, 'secondly,': 2, 'could
# possibly': 1, 'you.'': 1, 'extraordinary': 2, 'noise
# going': 1, 'constant': 1, 'howling': 2, 'sneezing,': 1, 'crash,': 1, 'dish': 3, 'kettle': 1, 'pieces.
#
# 'please,': 1, 'sense': 1, 'we': 13, 'us.': 1, 'inside,': 1, 'knock,': 1, 'know.'
# he': 1, 'sky': 1, 'this
# alice': 1, 'decidedly': 1, 'uncivil.': 1, 'she
# said': 2, 'herself;': 3, ''his': 1, 'head.
# but': 1, 'questions.--how': 1, 'she
# repeated,': 1, 'remarked,': 1, ''till': 2, 'opened,': 1, 'plate': 1, 'came
# skimming': 1, 'footman's': 1, 'head:': 1, 'grazed': 1, 'nose,
# and': 1, 'him.
#
# '--or': 1, 'maybe,'': 1, 'exactly
# as': 1, 'happened.
#
# 'how': 1, 'louder': 1, 'footman.': 1, 'first
# question,': 1, 'know.'
#
# it': 1, 'doubt:': 1, 'so.': 1, 'really
# dreadful,'': 1, 'muttered': 2, 'drive': 1, 'crazy!'
#
# the': 1, 'repeating': 3, 'his
# remark,': 1, 'variations.': 1, ''on': 1, 'days.'
#
# 'but': 1, 'do?'': 1, 'alice.
#
# 'anything': 1, 'like,'': 3, 'whistling.
#
# 'oh,': 1, 'him,'': 2, 'desperately:': 1, ''he's
# perfectly': 1, 'idiotic!'': 1, 'kitchen,': 1, 'smoke': 1, 'from
# one': 1, 'stool': 1, 'nursing': 3, 'baby;': 1, 'cook': 8, 'leaning': 2, 'stirring
# a': 1, 'cauldron': 2, 'soup.
#
# 'there's': 1, 'pepper': 5, 'soup!'': 1, 'herself,
# as': 1, 'sneezing.
#
# there': 1, 'duchess
# sneezed': 1, 'occasionally;': 1, 'baby,': 2, 'sneezing': 4, 'howling
# alternately': 1, 'moment's': 2, 'pause.': 1, 'kitchen
# that': 1, 'sneeze,': 1, 'cook,': 2, 'hearth': 1, 'grinning': 1, 'ear': 1, 'ear.
#
# 'please': 1, 'timidly,': 3, 'manners': 1, ''why
# your': 1, 'grins': 1, 'cheshire': 1, 'cat,'': 1, 'why.': 1, 'pig!'
#
# she': 1, 'word': 7, 'violence': 1, 'quite
# jumped;': 1, 'baby,
# and': 1, 'courage,': 1, 'grinned;': 1, 'know
# that': 1, 'grin.'
#
# 'they': 1, 'can,'': 1, 'duchess;': 1, 'do.'
#
# 'i': 1, 'politely,': 2, 'quite
# pleased': 1, 'conversation.
#
# 'you': 1, 'much,'': 5, 'fact.'
#
# alice': 1, 'remark,': 2, 'would
# be': 1, 'fix': 1, 'soup': 1, 'throwing': 2, 'baby--the': 1, 'fire-irons': 1, 'saucepans,': 1, 'plates,': 1, 'dishes.': 1, 'baby': 6, 'impossible': 1, 'blows': 1, 'hurt': 1, 'not.
#
# 'oh,': 1, 'doing!'': 1, 'jumping': 2, 'terror.': 1, 'precious': 1, 'nose';': 1, 'unusually
# large': 1, 'saucepan': 1, 'flew': 1, 'carried': 3, 'everybody': 5, 'minded': 1, 'business,'': 1, 'hoarse
# growl,': 1, 'faster': 1, 'does.'
#
# 'which': 1, 'get
# an': 1, 'knowledge.': 1, ''just': 1, 'night!': 1, 'earth': 1, 'takes
# twenty-four': 1, 'hours': 3, ''chop': 1, 'head!'
#
# alice': 1, 'glanced': 1, 'meant': 4, 'take
# the': 1, 'hint;': 1, 'busily': 3, 'stirring': 1, 'soup,': 1, ''twenty-four': 1, 'hours,': 1, 'think;': 1, 'twelve?': 1, 'i--'
#
# 'oh,': 1, 'bother': 1, 'figures!'
# and': 1, 'singing': 2, 'violent': 1, 'shake': 1, 'line:
#
# ': 1, ''speak': 1, 'roughly': 1, 'boy,
# ': 2, 'sneezes:
# ': 1, 'because': 1, 'teases.'
#
# ': 1, 'chorus.
#
# ': 1, '(in': 1, 'joined):--
#
# ': 1, ''wow!': 1, 'wow!': 2, 'wow!'
#
# while': 1, 'sang': 2, 'second': 2, 'verse': 1, 'song,': 4, 'howled': 1, 'so,
# that': 1, 'words:--
#
# ': 2, 'sneezes;
# ': 1, 'thoroughly': 2, 'enjoy
# ': 1, 'pleases!'
#
# ': 1, 'wow!'
#
# 'here!': 1, 'nurse': 1, 'like!'': 1, 'alice,
# flinging': 1, 'spoke.': 2, 'play
# croquet': 1, 'queen,'': 1, 'room.': 1, 'threw
# a': 1, 'frying-pan': 1, 'missed': 2, 'her.
#
# alice': 1, 'caught': 3, 'difficulty,': 1, 'queer-shaped
# little': 1, 'creature,': 2, 'directions,': 2, ''just
# like': 1, 'star-fish,'': 1, 'snorting
# like': 1, 'steam-engine': 1, 'doubling': 1, 'minute
# or': 1, 'it.
#
# as': 1, 'proper': 3, 'knot,': 1, 'tight': 1, 'right
# ear': 1, 'prevent': 1, 'undoing': 1, 'itself,)': 1, 'carried
# it': 1, 'me,'
# thought': 1, ''they're': 1, 'kill': 1, 'two:': 1, 'loud,': 2, 'grunted': 3, 'reply': 1, 'time).
# 'don't': 1, 'grunt,'': 1, 'expressing
# yourself.'
#
# the': 1, 'doubt': 1, 'had
# a': 1, 'turn-up': 1, 'nose,': 2, 'snout': 1, 'real': 1, 'nose;': 1, 'its
# eyes': 1, 'extremely': 1, 'baby:': 1, 'not
# like': 1, 'sobbing,'
# she': 1, 'tears.': 1, 'pig,': 4, 'dear,'
# said': 1, 'seriously,': 1, 'you.': 1, 'mind
# now!'': 1, 'sobbed': 1, '(or': 1, 'grunted,': 1, 'impossible
# to': 1, 'which),': 1, 'creature': 2, 'home?'': 1, 'violently,
# that': 1, 'could
# be': 1, 'neither': 1, 'less': 2, 'carry': 1, 'further.
#
# so': 1, 'relieved': 1, 'see
# it': 1, 'trot': 1, 'wood.': 2, 'up,'': 2, 'dreadfully': 4, 'ugly': 1, 'child:': 1, 'makes
# rather': 1, 'handsome': 1, 'think.'': 1, 'other
# children': 1, 'knew,': 1, 'pigs,': 1, 'saying
# to': 1, 'startled': 1, 'seeing': 1, 'bough': 1, 'yards': 1, 'grinned': 2, 'good-natured,': 1, 'she
# thought:': 1, 'claws': 1, 'teeth,': 1, 'treated': 1, 'respect.
#
# 'cheshire': 1, 'puss,'': 1, 'know
# whether': 1, 'name:': 1, 'wider.
# 'come,': 1, 'pleased': 4, 'far,'': 2, ''would': 1, 'you
# tell': 1, 'here?'
#
# 'that': 1, 'depends': 1, 'cat.
#
# 'i': 1, 'where--'': 1, 'alice.
#
# 'then': 1, 'go,'': 2, 'cat.
#
# '--so': 1, 'somewhere,'': 1, 'explanation.
#
# 'oh,': 1, 'cat,': 1, 'long
# enough.'
#
# alice': 1, 'denied,': 1, 'question.
# 'what': 1, 'here?'
#
# 'in': 1, 'direction,'': 2, 'waving': 5, 'paw': 1, ''lives
# a': 1, 'hatter:': 1, ''lives': 1, 'march
# hare.': 1, 'visit': 1, 'like:': 1, 'mad.'
#
# 'but': 1, 'mad': 2, 'people,'': 1, 'remarked.
#
# 'oh,': 1, 'cat:': 1, ''we're': 1, 'here.': 2, 'mad.
# you're': 1, 'mad.'
#
# 'how': 1, 'mad?'': 1, 'alice.
#
# 'you': 1, 'here.'
#
# alice': 1, 'how
# do': 1, 'mad?'
#
# 'to': 1, 'dog's': 1, 'mad.': 1, 'grant': 1, 'so,'': 5, 'alice.
#
# 'well,': 1, 'growls': 1, 'wags': 1, 'tail': 2, 'pleased.': 1, 'growl': 1, 'pleased,': 1, 'therefore': 1, 'mad.'
#
# 'i': 1, 'purring,': 1, 'growling,'': 1, 'alice.
#
# 'call': 1, 'vanished.
#
# alice': 1, 'queer
# things': 1, 'happening.': 1, 'baby?'': 1, ''i'd': 1, 'nearly
# forgotten': 1, 'pig,'': 2, 'back
# in': 1, 'natural': 2, 'way.
#
# 'i': 1, 'would,'': 1, 'not
# appear,': 1, 'march': 1, 'hare': 1, 'live.': 1, 'hatters': 1, 'raving': 2, 'mad--at': 1, 'march.'': 1, 'cat
# again,': 1, 'branch': 1, 'tree.
#
# 'did': 1, 'fig?'': 1, 'suddenly:': 2, 'giddy.'
#
# 'all': 1, 'cat;': 1, 'slowly,
# beginning': 1, 'ending': 1, 'grin,': 2, 'which
# remained': 1, 'gone.
#
# 'well!': 1, 'grin,'': 1, 'grin
# without': 1, 'cat!': 1, 'life!'
#
# she': 1, 'farther': 1, 'sight': 2, 'house
# of': 1, 'hare:': 1, 'shaped': 2, 'fur.': 1, 'it
# was': 1, 'had
# nibbled': 1, 'lefthand': 1, 'mushroom,': 1, 'raised': 2, 'timidly,
# saying': 1, ''suppose': 1, 'hatter': 1, 'vii.': 1, 'tea-party
#
# there': 1, 'front': 2, 'tea': 5, 'dormouse': 1, 'sitting
# between': 1, 'fast': 4, 'using': 2, 'resting': 1, 'elbows': 1, 'head.': 2, ''very
# uncomfortable': 1, 'dormouse,'': 1, ''only,': 1, 'mind.'
#
# the': 1, 'corner': 1, ''no': 1, 'room!': 1, 'room!'': 2, 'alice
# coming.': 1, ''there's': 1, 'plenty': 1, 'sat
# down': 1, 'table.
#
# 'have': 1, 'wine,'': 2, 'tea.
# 'i': 1, 'remarked.
#
# 'there': 1, 'hare.
#
# 'then': 1, 'civil': 2, 'said
# the': 1, 'hare.
#
# 'i': 1, 'table,'': 1, 'laid': 2, 'great
# many': 1, 'three.'
#
# 'your': 1, 'wants': 2, 'cutting,'': 1, 'hatter.': 1, 'alice
# for': 1, 'speech.
#
# 'you': 1, 'learn': 3, 'personal': 2, 'remarks,'': 1, 'some
# severity;': 1, 'rude.'
#
# the': 1, 'wide': 1, 'said
# was,': 1, ''why': 1, 'raven': 1, 'writing-desk?'
#
# 'come,': 1, 'fun': 1, 'riddles.--i': 1, 'it?'': 8, 'hare.
#
# 'exactly': 1, 'mean,'': 2, 'least--at': 1, 'i
# say--that's': 1, 'know.'
#
# 'not': 1, 'bit!'': 1, 'say
# that': 1, '"i': 1, 'eat"': 1, 'see"!'
#
# 'you': 1, 'hare,': 1, 'i
# get"': 1, 'like"!'
#
# 'you': 1, 'dormouse,': 1, 'sleep,': 1, 'breathe': 1, 'sleep"': 1, 'thing
# as': 1, 'breathe"!'
#
# 'it': 1, 'you,'': 5, 'hatter,': 1, 'dropped,': 1, 'alice
# thought': 1, 'ravens': 1, 'writing-desks,
# which': 1, 'much.
#
# the': 1, 'break': 1, 'month
# is': 1, 'watch': 4, 'his
# pocket,': 1, 'uneasily,': 1, 'ear.
#
# alice': 1, 'fourth.'
#
# 'two': 1, 'days': 1, 'wrong!'': 1, 'butter': 1, 'suit
# the': 1, 'works!'': 1, 'hare.
#
# 'it': 1, 'best': 1, 'butter,'': 1, 'meekly': 1, 'replied.
#
# 'yes,': 1, 'crumbs': 1, 'well,'': 2, 'grumbled:
# 'you': 1, 'bread-knife.'
#
# the': 1, 'gloomily:': 1, 'dipped
# it': 1, 'cup': 1, 'tea,': 1, 'butter,
# you': 1, 'know.'
#
# alice': 1, 'shoulder': 3, 'curiosity.': 1, 'watch!'': 1, 'remarked.': 1, 'tells': 2, 'month,': 1, 'doesn't
# tell': 1, 'o'clock': 3, ''does': 1, 'what
# year': 1, 'readily:': 1, 'it
# stays': 1, 'year': 1, 'mine,'': 2, 'hatter.
#
# alice': 1, 'puzzled.': 2, 'hatter's': 1, 'remark': 2, 'no
# sort': 1, 'english.': 1, 'quite
# understand': 1, 'politely': 1, 'could.
#
# 'the': 1, 'poured': 1, 'little
# hot': 1, 'nose.
#
# the': 1, 'its
# eyes,': 1, 'course;': 1, 'myself.'
#
# 'have': 1, 'riddle': 1, 'yet?'': 1, 'alice
# again.
#
# 'no,': 1, 'replied:': 2, ''what's': 1, 'slightest': 1, 'idea,'': 1, 'hatter.
#
# 'nor': 1, 'i,'': 1, 'hare.
#
# alice': 1, 'wearily.': 1, ''than': 1, 'waste': 1, 'riddles': 1, 'talk
# about': 1, 'wasting': 1, 'him.'
#
# 'i': 1, 'alice.
#
# 'of': 1, 'don't!'': 1, 'contemptuously.
# 'i': 1, 'time!'
#
# 'perhaps': 1, 'cautiously': 2, 'time
# when': 1, 'music.'
#
# 'ah!': 1, ''he': 3, 'he'd': 1, 'clock.': 1, 'lessons:': 1, 'whisper': 1, 'clock': 1, 'twinkling!': 1, 'half-past': 1, 'dinner!'
#
# ...
# 'because': 1, 'lessen': 1, 'day.'
#
# this': 1, 'little
# before': 1, 'remark.': 1, 'eleventh': 1, 'turtle.
#
# 'and': 1, 'twelfth?'': 1, 'eagerly.
#
# 'that's': 1, 'decided
# tone:': 1, ''tell': 1, 'games': 1, 'now.'
#
#
#
#
# chapter': 1, 'x.': 1, 'lobster': 1, 'quadrille
#
# the': 1, 'deeply,': 2, 'flapper': 1, 'speak,': 1, 'sobs': 2, ''same': 1, 'bone': 1, 'throat,'
# said': 1, 'punching': 1, 'back.': 1, 'recovered': 2, 'tears
# running': 1, 'cheeks,': 1, 'sea--'': 1, '('i': 1, 'haven't,'': 1, 'said
# alice)--'and': 1, 'lobster--'
# (alice': 1, 'tasted--'': 1, 'never')': 1, ''--so': 1, 'delightful': 2, 'quadrille': 1, 'dance': 2, 'it?'
#
# 'why,'': 1, 'line': 1, 'lines!'': 1, ''seals,': 1, 'turtles,': 1, 'salmon,': 1, 'cleared': 1, 'jelly-fish': 1, 'way--'
#
# 'that': 1, 'takes': 1, 'gryphon.
#
# '--you': 1, 'twice--'
#
# 'each': 1, 'partner!'': 1, 'gryphon.
#
# 'of': 1, ''advance': 1, 'partners--'
#
# '--change': 1, 'lobsters,': 3, 'retire': 1, 'gryphon.
#
# 'then,': 1, 'lobsters!'': 1, 'bound': 1, 'sea': 1, 'can--'
#
# 'swim': 1, 'gryphon.
#
# 'turn': 1, 'somersault': 1, 'sea!'': 1, 'capering': 1, 'wildly
# about.
#
# 'change': 1, 'lobsters': 2, 'yelled': 1, 'voice.
#
# 'back': 1, 'land': 1, 'figure,'': 1, 'dropping': 1, 'creatures,': 1, 'sadly
# and': 1, 'quietly,': 1, 'pretty': 1, 'dance,'': 1, 'timidly.
#
# 'would': 1, 'turtle.
#
# 'very': 1, 'alice.
#
# 'come,': 1, 'figure!'': 1, 'gryphon.
# 'we': 1, 'sing?'
#
# 'oh,': 1, 'sing,'': 1, 'words.'
#
# so': 1, 'solemnly': 1, 'dancing': 1, 'treading': 2, 'close,': 1, 'mark': 2, 'slowly
# and': 1, 'sadly:--
#
# ': 1, ''"will': 1, 'faster?"': 1, 'whiting': 3, 'snail.
# ': 1, '"there's': 1, 'porpoise': 1, 'us,': 2, 'he's': 1, 'tail.
#
# ': 1, 'eagerly': 2, 'turtles': 1, 'shingle--will': 1, 'join': 9, 'dance?
#
# ': 2, 'dance?
# ': 2, 'sea!"
# ': 1, 'snail': 1, '"too': 1, 'far,': 1, 'far!"': 1, 'thanked': 1, 'kindly,': 1, 'dance.
#
# ': 3, 'dance.
# ': 1, ''"what': 1, 'go?"': 1, 'scaly': 1, 'replied.
# ': 1, '"there': 1, 'side.
# ': 1, 'further': 1, 'england': 1, 'france--
# ': 1, 'pale,': 2, 'snail,': 1, 'dance?"'
#
# 'thank': 1, 'watch,'': 1, 'feeling
# very': 1, 'last:': 1, 'song
# about': 1, 'whiting!'
#
# 'oh,': 1, 'whiting,'': 2, ''they--you've': 1, 'course?'
#
# 'yes,'': 1, 'dinn--'': 1, 'herself
# hastily.
#
# 'i': 1, 'dinn': 1, 'you've
# seen': 1, 'like.'
#
# 'i': 1, 'thoughtfully.': 2, 'tails': 3, 'mouths--and': 1, 'crumbs.'
#
# 'you're': 1, 'crumbs,'': 1, ''crumbs': 1, 'sea.': 2, 'mouths;': 1, 'eyes.--'tell': 1, 'her
# about': 1, 'gryphon.
#
# 'the': 1, 'lobsters
# to': 1, 'dance.': 1, 'thrown': 1, 'long
# way.': 1, 'mouths.': 1, 'get
# them': 1, 'much
# about': 1, 'you
# know': 1, 'whiting?'
#
# 'i': 1, ''why?'
#
# 'it': 1, 'shoes.'': 1, 'solemnly.
#
# alice': 1, 'shoes!'': 1, 'repeated
# in': 1, 'mean,': 1, 'what
# makes': 1, 'shiny?'
#
# alice': 1, 'her
# answer.': 1, 'blacking,': 1, 'sea,'': 1, 'voice,
# 'are': 1, 'whiting.': 1, 'know.'
#
# 'and': 1, 'curiosity.
#
# 'soles': 1, 'eels,': 1, 'impatiently:
# 'any': 1, 'shrimp': 1, 'thoughts': 2, 'running
# on': 1, 'porpoise,': 1, '"keep': 1, 'please:': 1, 'we
# don't': 1, 'us!"'
#
# 'they': 1, 'obliged': 2, ''no
# wise': 1, 'fish': 2, 'porpoise.'
#
# 'wouldn't': 1, 'really?'': 1, 'surprise.
#
# 'of': 1, 'journey,': 1, '"with': 1, 'porpoise?"'
#
# 'don't': 1, '"purpose"?'': 1, 'alice.
#
# 'i': 1, 'morning,'': 1, 'timidly:': 1, 'yesterday,
# because': 1, 'turtle.
#
# 'no,': 1, 'impatient': 1, 'dreadful': 1, 'time.'
#
# so': 1, 'first
# saw': 1, 'rabbit.': 1, 'first,
# the': 1, 'opened
# their': 1, 'mouths': 1, 'wide,': 1, 'gained': 1, 'courage': 1, 'went
# on.': 2, 'listeners': 1, 'quiet': 1, 'part': 1, 'different,': 1, 'breath,
# and': 1, 'curious.'
#
# 'it's': 1, 'gryphon.
#
# 'it': 1, 'different!'': 1, ''i
# should': 1, 'now.': 1, 'alice.
#
# 'stand': 1, '"'tis': 1, 'sluggard,"'': 1, 'lessons!'
# thought': 1, 'she
# got': 1, 'lobster
# quadrille,': 1, 'saying,': 1, 'came
# very': 1, '''tis': 1, 'lobster;': 1, 'declare,
# ': 1, 'baked': 1, 'brown,': 1, 'sugar': 1, 'hair."
# ': 1, 'eyelids,': 1, 'nose
# ': 1, 'trims': 1, 'buttons,': 1, 'turns': 1, '[later': 2, 'editions': 2, 'follows
# ': 2, 'sands': 1, 'dry,': 1, 'gay': 1, 'lark,
# ': 1, 'contemptuous': 1, 'shark,
# ': 1, 'tide': 1, 'rises': 1, 'sharks': 1, 'tremulous': 1, 'sound.]
#
# 'that's': 1, 'child,'': 1, 'turtle;': 1, 'sounds
# uncommon': 1, 'nonsense.'
#
# alice': 1, 'nothing;': 1, 'hands,
# wondering': 1, 'explained,'': 1, 'turtle.
#
# 'she': 1, 'hastily.': 2, ''go': 1, 'next
# verse.'
#
# 'but': 1, 'persisted.': 1, 'know?'
#
# 'it's': 1, 'dancing.'': 1, 'dreadfully
# puzzled': 1, 'subject.
#
# 'go': 1, 'impatiently:': 1, ''it
# begins': 1, 'garden."'
#
# alice': 1, 'disobey,': 1, 'come
# wrong,': 1, 'voice:--
#
# ': 1, 'marked,': 1, 'eye,
# ': 1, 'owl': 1, 'panther': 1, 'sharing': 1, 'pie--'
#
# ': 1, 'pie-crust,': 1, 'gravy,': 1, 'meat,
# ': 1, 'share': 1, 'treat.
# ': 1, 'pie': 1, 'finished,': 1, 'owl,': 1, 'boon,
# ': 1, 'kindly': 1, 'permitted': 1, 'pocket': 1, 'spoon:
# ': 1, 'received': 1, 'knife': 1, 'growl,
# ': 1, 'banquet--]
#
# 'what': 1, 'stuff,'': 1, 'turtle
# interrupted,': 1, 'most
# confusing': 1, 'heard!'
#
# 'yes,': 1, 'was
# only': 1, 'so.
#
# 'shall': 1, 'figure': 1, 'quadrille?'': 1, 'sing': 2, 'song?'
#
# 'oh,': 1, 'kind,'': 1, 'alice
# replied,': 1, 'tastes!': 1, '"turtle': 1, 'soup,"': 1, 'old
# fellow?'
#
# the': 1, 'choked
# with': 1, 'sobs,': 1, ''beautiful': 1, 'rich': 1, 'green,
# ': 1, 'hot': 1, 'tureen!
# ': 1, 'dainties': 1, 'stoop?
# ': 1, 'evening,': 2, 'soup!
# ': 1, 'beau--ootiful': 1, 'soo--oop!
# ': 1, 'soo--oop': 1, 'e--e--evening,
# ': 3, 'beautiful,': 1, 'soup!
#
# ': 1, 'soup!': 1, 'cares': 2, 'fish,
# ': 1, 'dish?
# ': 1, 'two
# ': 1, 'pennyworth': 1, 'soup?
# ': 1, 'soup!'
#
# 'chorus': 1, 'trial's': 3, 'hurried
# off,': 1, 'song.
#
# 'what': 1, 'trial': 2, 'panted': 1, 'ran;': 1, 'faster,': 1, 'faintly
# came,': 1, 'breeze': 1, ''soo--oop': 1, 'soup!'
#
#
#
#
# chapter': 1, 'xi.': 1, 'stole': 2, 'tarts?
#
# the': 1, 'hearts': 1, 'seated': 1, 'throne': 1, 'little
# birds': 1, 'cards:': 1, 'was
# standing': 1, 'chains,': 1, 'soldier': 1, 'guard
# him;': 1, 'trumpet': 1, 'hand,
# and': 1, 'scroll': 1, 'parchment': 2, 'other.': 2, 'court
# was': 1, 'tarts': 2, 'good,
# that': 1, 'done,'': 2, 'refreshments!'': 1, 'pass': 1, 'time.
#
# alice': 1, 'court': 3, 'justice': 1, 'read
# about': 1, 'books,': 1, 'knew
# the': 1, 'judge,'': 1, 'wig.'
#
# the': 1, 'king;': 1, 'wore': 1, 'crown': 1, '(look': 1, 'frontispiece': 1, 'it,)': 1, 'did
# not': 1, 'comfortable,': 1, 'jury-box,'': 1, 'twelve': 2, 'creatures,'
# (she': 1, ''creatures,'': 1, 'were
# animals,': 1, 'birds,)': 1, 'jurors.'': 1, 'said
# this': 1, 'proud': 1, 'rightly': 1, 'her
# age': 1, ''jury-men'': 1, 'done
# just': 1, 'well.
#
# the': 1, 'jurors': 3, 'writing': 4, 'slates.': 1, 'yet,': 3, 'names,'': 1, 'reply,': 1, ''for
# fear': 1, 'trial.'
#
# 'stupid': 1, 'stopped
# hastily,': 1, ''silence': 1, 'court!'': 1, 'spectacles': 1, 'who
# was': 1, 'talking.
#
# alice': 1, 'shoulders,
# that': 1, ''stupid': 1, 'slates,
# and': 1, 'spell
# 'stupid,'': 1, 'neighbour': 1, 'him.': 1, 'nice
# muddle': 1, 'slates'll': 1, 'alice.
#
# one': 1, 'pencil': 1, 'squeaked.': 1, 'alice
# could': 1, 'stand,': 1, 'quickly
# that': 1, 'juror': 1, 'lizard)': 1, 'out
# at': 1, 'was
# obliged': 1, 'day;': 1, 'was
# of': 1, 'slate.
#
# 'herald,': 1, 'king.
#
# on': 1, 'blew': 2, 'blasts': 1, 'trumpet,': 2, 'scroll,': 1, 'follows:--
#
# ': 1, 'tarts,
# ': 2, 'all': 1, 'summer': 2, 'day:
# ': 1, 'verdict,'': 2, 'jury.
#
# 'not': 1, 'yet!'': 1, 'great
# deal': 1, 'witness,'': 1, 'three
# blasts': 1, ''first': 1, 'witness!'
#
# the': 1, 'witness': 4, 'teacup': 3, 'bread-and-butter': 1, 'pardon,': 1, 'your
# majesty,'': 1, 'finished
# my': 1, 'sent': 2, 'finished,'': 1, 'king.': 1, 'dormouse.': 1, ''fourteenth': 1, 'it
# was,'': 1, 'said.
#
# 'fifteenth,'': 1, 'hare.
#
# 'sixteenth,'': 1, 'dormouse.
#
# 'write': 1, 'down,'': 3, 'jury,': 4, 'jury': 7, 'eagerly
# wrote': 1, 'dates': 1, 'slates,': 3, 'shillings': 1, 'pence.
#
# 'take': 1, 'hat,'': 1, 'hatter.
#
# 'it': 1, 'hatter.
#
# 'stolen!'': 1, 'exclaimed,': 1, 'fact.
#
# 'i': 1, 'sell,'': 1, 'explanation;': 1, 'own.': 1, 'hatter.'
#
# here': 1, 'spectacles,': 1, 'hatter,
# who': 1, 'fidgeted.
#
# 'give': 1, 'evidence,'': 3, 'nervous,': 1, 'have
# you': 1, 'executed': 1, 'spot.'
#
# this': 1, 'encourage': 1, 'shifting
# from': 1, 'uneasily': 1, 'sensation,': 1, 'puzzled
# her': 1, 'leave
# the': 1, 'court;': 1, 'remain': 1, 'her.
#
# 'i': 1, 'squeeze': 1, 'so.'': 1, 'sitting
# next': 1, 'breathe.'
#
# 'i': 1, 'meekly:': 1, 'growing.'
#
# 'you've': 1, 'dormouse.
#
# 'don't': 1, 'nonsense,'': 1, 'boldly:': 1, 'growing
# too.'
#
# 'yes,': 1, 'reasonable': 1, 'pace,'': 1, 'dormouse:': 1, 'fashion.'': 1, 'sulkily': 1, 'court.
#
# all': 1, 'court,': 2, ''bring': 1, 'list': 2, 'singers': 1, 'concert!'': 1, 'you
# executed,': 1, 'not.'
#
# 'i'm': 1, 'man,': 2, 'voice,
# '--and': 1, 'tea--not': 1, 'week': 2, 'so--and': 1, 'thin--and': 1, 'twinkling': 3, 'tea--'
#
# 'the': 1, 'king.
#
# 'it': 1, 'replied.
#
# 'of': 1, 't!'': 1, 'sharply.': 1, 'you
# take': 1, 'dunce?': 1, 'man,'': 1, 'twinkled': 1, 'said--'
#
# 'i': 1, 'hurry.
#
# 'you': 1, 'did!'': 1, 'hatter.
#
# 'i': 1, 'deny': 2, 'hare.
#
# 'he': 1, 'denies': 1, ''leave': 1, 'part.'
#
# 'well,': 1, 'said--'': 1, 'denied
# nothing,': 1, 'bread-and-butter--'
#
# 'but': 1, 'say?'': 1, 'remember,'': 2, 'hatter.
#
# 'you': 1, 'remarked': 1, 'executed.'
#
# the': 1, 'miserable': 2, 'went
# down': 1, 'knee.': 1, 'speaker,'': 1, 'king.
#
# here': 1, 'guinea-pigs': 1, 'cheered,': 2, 'suppressed': 3, 'court.': 1, 'just
# explain': 1, 'done.': 1, 'canvas': 1, 'bag,': 1, 'tied
# up': 1, 'strings:': 1, 'slipped': 1, 'guinea-pig,
# head': 1, 'it.)
#
# 'i'm': 1, 'read
# in': 1, 'newspapers,': 1, 'trials,': 1, 'understood': 1, 'now.'
#
# 'if': 1, 'lower,'': 1, 'replied.
#
# here': 1, 'guinea-pig': 1, 'suppressed.
#
# 'come,': 1, 'guinea-pigs!'': 1, 'get
# on': 1, 'reading': 2, 'singers.
#
# 'you': 1, 'court,
# without': 1, 'outside,'': 1, 'get
# to': 1, 'door.
#
# 'call': 1, 'witness!'': 1, 'king.
#
# the': 1, 'cook.': 1, 'pepper-box': 1, 'king.
#
# 'shan't,'': 1, 'cook.
#
# the': 1, 'voice,
# 'your': 1, 'majesty': 1, 'cross-examine': 2, 'witness.'
#
# 'well,': 1, 'must,': 1, 'must,'': 1, 'folding': 1, 'were
# nearly': 1, 'mostly,'': 1, 'cook.
#
# 'treacle,'': 1, 'her.
#
# 'collar': 1, 'shrieked': 1, ''behead': 1, 'dormouse!
# turn': 1, 'court!': 1, 'suppress': 1, 'him!': 2, 'pinch': 1, 'his
# whiskers!'
#
# for': 1, 'confusion,': 1, 'dormouse
# turned': 1, 'had
# disappeared.
#
# 'never': 1, 'mind!'': 1, ''call': 1, 'next
# witness.'': 1, 'undertone': 1, ''really,': 1, 'dear,
# you': 1, 'witness.': 1, 'fumbled': 1, 'list,': 1, 'very
# curious': 1, ''--for': 1, 'haven't
# got': 1, 'evidence': 3, 'when
# the': 1, 'shrill': 2, ''alice!'
#
#
#
#
# chapter': 1, 'xii.': 1, 'evidence
#
#
# 'here!'': 1, 'flurry': 1, 'how
# large': 1, 'minutes,': 1, 'such
# a': 1, 'tipped': 1, 'jury-box': 1, 'skirt,
# upsetting': 1, 'jurymen': 2, 'sprawling': 1, 'reminding': 1, 'globe': 1, 'goldfish
# she': 1, 'beg': 1, 'dismay,': 1, 'picking': 1, 'quickly': 1, 'goldfish': 1, 'vague': 1, 'idea
# that': 1, 'jury-box,': 2, 'die.
#
# 'the': 1, 'cannot': 1, 'proceed,'': 1, ''until
# all': 1, 'places--all,'': 1, 'emphasis,': 1, 'do.
#
# alice': 1, 'haste,': 1, 'put
# the': 1, 'lizard': 1, 'downwards,': 1, 'its
# tail': 1, 'unable': 1, 'move.': 1, 'got
# it': 1, 'right;': 1, 'signifies': 1, 'trial
# one': 1, 'other.'
#
# as': 1, 'shock': 1, 'slates': 1, 'pencils': 1, 'diligently': 1, 'history': 1, 'overcome': 1, 'do
# anything': 1, 'open,': 1, 'gazing': 1, 'business?'': 1, 'alice.
#
# 'nothing,'': 1, 'alice.
#
# 'nothing': 1, 'whatever?'': 1, 'persisted': 1, 'king.
#
# 'nothing': 1, 'whatever,'': 1, 'important,'': 1, 'jury.': 1, 'were
# just': 1, 'rabbit
# interrupted:': 1, ''unimportant,': 1, 'means,': 1, 'respectful': 1, 'spoke.
#
# 'unimportant,': 1, 'meant,'': 1, 'undertone,
#
# 'important--unimportant--unimportant--important--'': 1, 'trying
# which': 1, 'wrote': 2, ''important,'': 1, ''unimportant.'
# alice': 1, 'slates;
# 'but': 1, 'herself.
#
# at': 1, 'note-book,': 1, 'cackled': 1, ''silence!'': 1, 'book,': 1, ''rule
# forty-two.': 1, 'persons': 1, 'mile': 2, 'to': 1, 'court.'
#
# everybody': 1, 'alice.
#
# 'i'm': 1, 'high,'': 2, 'king.
#
# 'nearly': 1, 'queen.
#
# 'well,': 1, 'rate,'': 1, ''besides,': 1, 'rule:': 1, 'now.'
#
# 'it's': 1, 'oldest': 1, 'king.
#
# 'then': 1, 'one,'': 1, 'alice.
#
# the': 1, 'note-book': 1, ''consider': 1, 'your
# verdict,'': 1, 'voice.
#
# 'there's': 1, 'white
# rabbit,': 1, 'paper': 2, 'picked
# up.'
#
# 'what's': 1, 'prisoner': 1, 'somebody.'
#
# 'it': 1, ''unless': 1, 'usual,': 1, 'know.'
#
# 'who': 1, 'directed': 2, 'jurymen.
#
# 'it': 1, 'rabbit;': 1, 'outside.'': 1, 'letter,': 1, 'verses.'
#
# 'are': 1, 'prisoner's': 1, 'handwriting?'': 1, 'jurymen.
#
# 'no,': 1, 'queerest': 1, 'thing
# about': 1, '(the': 1, 'puzzled.)
#
# 'he': 1, 'imitated': 1, 'else's': 1, 'hand,'': 1, 'jury
# all': 1, 'brightened': 1, 'knave,': 1, 'prove': 1, 'did:': 1, 'signed': 2, 'end.'
#
# 'if': 1, 'sign': 1, 'matter
# worse.': 1, 'mischief,': 1, 'your
# name': 1, 'honest': 1, 'man.'
#
# there': 1, 'clapping': 1, 'really
# clever': 1, 'day.
#
# 'that': 1, 'proves': 2, 'guilt,'': 1, 'queen.
#
# 'it': 1, 'sort!'': 1, 'know
# what': 1, 'spectacles.': 1, ''where': 1, 'please
# your': 1, 'majesty?'': 1, 'you
# come': 1, 'end:': 1, 'stop.'
#
# these': 1, 'verses': 3, 'read:--
#
# ': 1, 'her,
# ': 1, 'him:
# ': 1, 'character,
# ': 1, 'swim.
#
# ': 1, 'gone
# ': 1, '(we': 1, 'true):
# ': 1, 'push': 1, 'you?
#
# ': 1, 'two,
# ': 1, 'more;
# ': 1, 'returned': 1, 'you,
# ': 1, 'involved': 1, 'trusts': 1, 'free,
# ': 1, 'were.
#
# ': 1, '(before': 1, 'fit)
# ': 1, 'obstacle': 1, 'ourselves,': 1, 'it.
#
# ': 1, 'secret,': 1, 'rest,
# ': 1, 'between': 1, 'me.'
#
# 'that's': 1, 'rubbing': 1, 'hands;': 1, 'jury--'
#
# 'if': 1, 'large
# in': 1, 'sixpence.': 1, '_i_': 1, 'it.'
#
# the': 1, 'paper.
#
# 'if': 1, 'saves': 1, 'know,'
# he': 1, 'spreading': 1, 'knee,': 3, '"--said
# i': 1, 'swim--"': 1, 'swim,': 1, 'sadly.': 1, 'said.': 1, 'he
# certainly': 1, 'entirely': 1, 'cardboard.)
#
# 'all': 1, 'over
# the': 1, 'himself:': 1, ''"we': 1, 'true--"': 1, 'one,': 1, 'two--"': 1, 'he
# did': 1, 'tarts,': 1, 'know--'
#
# 'but,': 1, '"they': 1, 'you,"'': 1, 'triumphantly,': 1, 'tarts
# on': 1, ''nothing': 1, 'clearer': 1, 'that.': 1, 'fit--"': 1, 'fits,': 1, 'think?'': 1, 'furiously,': 1, 'lizard
# as': 1, 'bill': 1, 'his
# slate': 1, 'finger,': 1, 'mark;': 1, 'hastily
# began': 1, 'trickling': 1, 'lasted.)
#
# 'then': 1, 'fit': 1, 'court
# with': 1, 'smile.': 1, 'silence.
#
# 'it's': 1, 'pun!'': 1, 'laughed,
# 'let': 1, 'consider': 1, 'day.
#
# 'no,': 1, 'no!'': 1, ''sentence': 1, 'first--verdict': 1, 'nonsense!'': 1, 'loudly.': 1, 'first!'
#
# 'hold': 1, 'purple.
#
# 'i': 1, 'won't!'': 1, 'alice.
#
# 'off': 1, 'nobody
# moved.
#
# 'who': 1, 'this
# time.)': 1, 'cards!'
#
# at': 1, 'rose': 1, 'flying': 1, 'upon
# her:': 1, 'scream,': 1, 'fright': 1, 'bank,': 1, 'her
# head': 1, 'sister,': 1, 'brushing': 1, 'dead
# leaves': 1, 'fluttered': 1, 'face.
#
# 'wake': 1, 'sister;': 1, 'you've
# had!'
#
# 'oh,': 1, 'dream!'': 1, 'her
# sister,': 1, 'adventures
# of': 1, 'had
# finished,': 1, 'kissed': 1, 'dream,
# dear,': 1, 'tea;': 1, 'late.'': 1, 'so
# alice': 1, 'ran,': 1, 'might,
# what': 1, 'wonderful': 1, 'setting': 1, 'sun,': 1, 'her
# wonderful': 1, 'adventures,': 1, 'dreaming': 1, 'fashion,': 1, 'dream:--
#
# first,': 1, 'dreamed': 1, 'tiny
# hands': 1, 'clasped': 1, 'looking
# up': 1, 'hers--she': 1, 'wandering': 1, 'eyes--and': 1, 'listened,': 1, 'creatures
# of': 1, 'sister's': 1, 'dream.
#
# the': 1, 'grass': 2, 'rustled': 1, 'splashed': 1, 'neighbouring': 1, 'pool--she
# could': 1, 'rattle': 1, 'teacups': 1, 'friends
# shared': 1, 'never-ending': 1, 'meal,': 1, 'queen
# ordering': 1, 'execution--once': 1, 'pig-baby
# was': 1, 'plates': 1, 'dishes': 1, 'crashed
# around': 1, 'it--once': 1, 'slate-pencil,': 1, 'choking': 1, 'guinea-pigs,
# filled': 1, 'mock
# turtle.
#
# so': 1, 'reality--the': 1, 'rustling': 1, 'rippling': 1, 'reeds--the': 1, 'rattling
# teacups': 1, 'tinkling': 1, 'sheep-bells,': 1, 'shrill
# cries': 1, 'shepherd': 1, 'boy--and': 1, 'sneeze': 1, 'noises,': 1, '(she
# knew)': 1, 'clamour': 1, 'farm-yard--while': 1, 'lowing
# of': 1, 'cattle': 1, 'distance': 1, 'turtle's
# heavy': 1, 'sobs.
#
# lastly,': 1, 'pictured': 1, 'hers
# would,': 1, 'woman;': 1, 'would
# keep,': 1, 'riper': 1, 'years,': 1, 'loving': 1, 'her
# childhood:': 1, 'gather': 1, 'their': 1, 'tale,': 1, 'even
# with': 1, 'sorrows,': 1, 'pleasure': 1, 'joys,
# remembering': 1, 'child-life,': 1, 'happy': 1, 'days.
#
# ': 1, 'end
#
#
#
#
#
# end': 1, 'carroll
#
# ***': 1, '***
#
# ': 1)>

# %%
from pprint import pprint

# %%
pprint(dict(a))
# Out:
# {'': 881,
#  '"\'tis': 1,
#  '"--said\ni': 1,
#  '"come': 2,
#  '"coming': 1,
#  '"edwin': 1,
#  '"he\'s': 1,
#  '"how': 1,
#  '"i': 1,
#  '"i\'ll': 1,
#  '"i\'ll\n': 1,
#  '"it"': 1,
#  '"keep': 1,
#  '"let': 1,
#  '"much': 1,
#  '"poison"': 1,
#  '"purpose"?\'': 1,
#  '"such\n': 1,
#  '"there': 1,
#  '"there\'s': 1,
#  '"they': 1,
#  '"too': 1,
#  '"turtle': 1,
#  '"twinkle,': 1,
#  '"uglification,"\'': 1,
#  '"up': 1,
#  '"what': 1,
#  '"who': 1,
#  '"william\nthe': 1,
#  '"with': 1,
#  '"you': 1,
#  '#11]\nrelease': 1,
#  '\'"--found\nit': 1,
#  '\'"miss': 1,
#  '\'"we': 1,
#  '\'"what': 1,
#  '\'"will': 1,
#  "''tis": 1,
#  "'--but": 1,
#  "'--for": 1,
#  "'--i": 1,
#  "'--it": 1,
#  "'--mystery,": 1,
#  "'--so": 1,
#  "'--that": 1,
#  "'--well": 1,
#  "'--where's": 1,
#  "'a": 1,
#  "'advance": 1,
#  "'after": 1,
#  "'ah,": 1,
#  "'alice!'\n\n\n\n\nchapter": 1,
#  "'all": 1,
#  "'allow": 1,
#  "'and": 20,
#  "'and\nnow": 1,
#  "'and\nsee": 1,
#  "'are": 2,
#  "'arrum.')\n\n'an": 1,
#  "'as": 5,
#  "'at": 2,
#  "'beautiful": 1,
#  "'because": 2,
#  "'behead": 1,
#  "'besides,": 1,
#  "'bring": 1,
#  "'but": 6,
#  "'but\neverything's": 1,
#  "'but\nwhy": 1,
#  "'call": 1,
#  "'can": 1,
#  "'chop": 1,
#  "'come": 1,
#  "'come,": 1,
#  "'consider": 1,
#  "'consider,": 1,
#  "'creatures,'": 1,
#  "'crumbs": 1,
#  "'dear,": 1,
#  "'did\nyou": 1,
#  "'dinah'll": 1,
#  "'do": 1,
#  "'do\nbats": 1,
#  "'does": 1,
#  "'don't": 2,
#  "'drink": 1,
#  "'drive": 1,
#  "'either": 1,
#  "'em": 2,
#  "'em\ntogether": 1,
#  "'everything's": 1,
#  "'explain\nyourself!'\n\n'i": 1,
#  "'fetch": 2,
#  "'first": 1,
#  "'flamingoes": 1,
#  "'for": 2,
#  "'for\nfear": 1,
#  "'fourteenth": 1,
#  "'from": 1,
#  "'fury": 1,
#  "'go": 1,
#  "'have\nyou": 1,
#  "'he": 3,
#  "'he's\nperfectly": 1,
#  "'here!": 1,
#  "'his": 1,
#  "'hjckrrh!'": 1,
#  "'hold": 1,
#  "'how": 1,
#  "'how\nsurprised": 1,
#  "'however,": 1,
#  "'i": 1,
#  "'i\nonly": 1,
#  "'i\nshould": 1,
#  "'i\nwonder": 1,
#  "'i'd": 1,
#  "'i'll": 1,
#  "'i'm": 1,
#  "'i've": 1,
#  "'i--i": 1,
#  "'if": 4,
#  "'if\ni": 1,
#  "'important,'": 1,
#  "'in": 3,
#  "'is": 1,
#  "'it": 1,
#  "'it\nbegins": 1,
#  "'it\nwould": 1,
#  "'it'll": 1,
#  "'it's": 2,
#  "'jury-men'": 1,
#  "'just": 1,
#  "'just\nlike": 1,
#  "'leave": 1,
#  "'let": 1,
#  "'let's": 1,
#  "'lives": 1,
#  "'lives\na": 1,
#  "'living": 1,
#  "'look": 1,
#  "'moral,'": 1,
#  "'mouse": 1,
#  "'my": 1,
#  "'nine": 1,
#  "'no": 1,
#  "'no\nwise": 1,
#  "'no,": 1,
#  "'nobody": 1,
#  "'not": 3,
#  "'nothing": 1,
#  "'now": 1,
#  "'now,": 1,
#  "'o": 1,
#  "'of": 1,
#  "'off": 1,
#  "'oh": 1,
#  "'oh!": 1,
#  "'oh,": 1,
#  "'on": 1,
#  "'one": 1,
#  "'one,": 1,
#  "'only": 1,
#  "'only,": 1,
#  "'or": 3,
#  "'orange": 1,
#  "'ou": 1,
#  "'poison,'": 2,
#  "'poor": 1,
#  "'prizes!": 1,
#  "'really": 1,
#  "'really,": 1,
#  "'rule\nforty-two.": 1,
#  "'same": 1,
#  "'seals,": 1,
#  "'sentence": 1,
#  "'seven": 1,
#  "'sh!": 1,
#  "'shall": 1,
#  "'she": 1,
#  "'she'd": 1,
#  "'she's": 2,
#  "'shy,": 1,
#  "'silence": 1,
#  "'silence!'": 1,
#  "'sit": 1,
#  "'sit\ndown,": 1,
#  "'so": 4,
#  "'some": 1,
#  "'soo--oop": 1,
#  "'speak": 1,
#  "'stupid": 1,
#  "'suppose": 1,
#  "'sure": 1,
#  "'sure,": 1,
#  "'tell": 1,
#  "'than": 1,
#  "'thank": 1,
#  "'that": 7,
#  "'that's": 1,
#  "'the": 1,
#  "'then": 1,
#  "'there": 1,
#  "'there's": 1,
#  "'they": 1,
#  "'they'd\nhave": 1,
#  "'they're": 1,
#  "'they--you've": 1,
#  "'this": 2,
#  "'three": 1,
#  "'till": 2,
#  "'tis": 1,
#  "'to": 4,
#  "'turn": 1,
#  "'twenty-four": 1,
#  "'twinkle,\ntwinkle,": 1,
#  "'unimportant,": 1,
#  "'unimportant.'\nalice": 1,
#  "'unless": 1,
#  "'until\nall": 1,
#  "'up,": 1,
#  "'very": 1,
#  "'very\nuncomfortable": 1,
#  "'w.": 1,
#  "'wake": 1,
#  "'was,": 1,
#  "'we": 4,
#  "'we\nquarrelled": 1,
#  "'we're": 1,
#  "'well,": 1,
#  "'what": 1,
#  "'what!": 1,
#  "'what's": 1,
#  "'when": 1,
#  "'whenever": 1,
#  "'where": 1,
#  "'where's": 1,
#  "'which": 1,
#  "'who": 1,
#  "'whoever": 1,
#  "'why": 1,
#  "'why\nyour": 1,
#  "'why,": 1,
#  "'why?'\n\n'it": 1,
#  "'without": 1,
#  "'would": 1,
#  "'would\nyou": 1,
#  "'wow!": 1,
#  "'yes,": 1,
#  "'you": 2,
#  "'you'd": 1,
#  "'you're": 1,
#  "'you're\nlooking": 1,
#  "('i": 1,
#  "('that's": 1,
#  "('the": 1,
#  "('which": 1,
#  '(a': 1,
#  '(alice': 1,
#  '(and\nshe': 1,
#  '(and,': 1,
#  '(as': 1,
#  '(before': 1,
#  '(for,': 1,
#  '(he': 1,
#  '(in': 1,
#  '(it': 2,
#  '(look': 1,
#  '(luckily': 1,
#  '(not': 1,
#  '(or': 1,
#  '(pointing\nwith': 1,
#  '(she': 6,
#  '(she\nhad': 1,
#  '(she\nknew)': 1,
#  '(sounds': 1,
#  '(the': 1,
#  '(though': 1,
#  '(we': 1,
#  '(when': 1,
#  '(which': 1,
#  '(with': 2,
#  '*': 51,
#  '*\n\n': 6,
#  '*\n\n\n\n\nchapter': 1,
#  "*\n\n'come,": 1,
#  "*\n\n'what": 1,
#  '***\n\n': 1,
#  "***\n\n\n\n\n\n\n\n\n\n\nalice's": 1,
#  '1994\n[last': 1,
#  '20,': 1,
#  '2008': 1,
#  '2011]\n\nlanguage:': 1,
#  '25,': 1,
#  '3.0\n\n\n\n\nchapter': 1,
#  '[ebook': 1,
#  '[later': 2,
#  '_i_': 1,
#  'a': 1,
#  "ada,'": 1,
#  'adventures': 1,
#  'adventures\nof': 1,
#  'adventures,': 1,
#  'advice': 1,
#  'after': 1,
#  'ah,': 1,
#  'alice': 1,
#  "alice\nagain.\n\n'no,": 1,
#  'alice\nbegan': 1,
#  'alice\ncoming.': 1,
#  'alice\ncould': 1,
#  'alice\nfor': 1,
#  'alice\nhad': 1,
#  'alice\nreplied,': 1,
#  'alice\nthought': 1,
#  'alice!': 1,
#  "alice!'": 1,
#  "alice's": 1,
#  "alice's\nfirst": 1,
#  "alice's,": 1,
#  'alice,': 1,
#  'alice,\nflinging': 1,
#  'alice,)': 1,
#  'alice.': 1,
#  "alice.\n\n'and": 1,
#  "alice.\n\n'anything": 1,
#  "alice.\n\n'call": 1,
#  "alice.\n\n'come": 1,
#  "alice.\n\n'come,": 1,
#  "alice.\n\n'did": 1,
#  "alice.\n\n'exactly": 1,
#  "alice.\n\n'i": 1,
#  "alice.\n\n'i'm": 1,
#  "alice.\n\n'i've": 1,
#  "alice.\n\n'it": 1,
#  "alice.\n\n'nothing": 1,
#  "alice.\n\n'nothing,'": 1,
#  "alice.\n\n'of": 1,
#  "alice.\n\n'off": 1,
#  "alice.\n\n'only": 1,
#  "alice.\n\n'reeling": 1,
#  "alice.\n\n'stand": 1,
#  "alice.\n\n'that's": 1,
#  "alice.\n\n'then": 1,
#  "alice.\n\n'well,": 1,
#  "alice.\n\n'what": 1,
#  "alice.\n\n'who's": 1,
#  "alice.\n\n'why": 1,
#  "alice.\n\n'why,": 1,
#  "alice.\n\n'you": 1,
#  'alice.\n\none': 1,
#  'alice.\n\nthe': 1,
#  'alice:': 1,
#  'alice;': 1,
#  'all': 1,
#  'all.': 1,
#  'allow': 1,
#  'always': 1,
#  'an': 1,
#  'an\ninvitation': 1,
#  'and': 1,
#  'and\nshe': 1,
#  'and\nthe': 1,
#  'and\nthen': 1,
#  'and\nthey': 1,
#  'ann!': 1,
#  "ann!'": 1,
#  'ann,': 1,
#  'antipathies,': 1,
#  'are': 1,
#  'arithmetic--ambition,\ndistraction,': 1,
#  'as': 1,
#  'at': 1,
#  'atheling': 1,
#  "australia?'": 1,
#  'baby': 6,
#  'baby,': 2,
#  'baby,\nand': 1,
#  'baby--the': 1,
#  'baby:': 1,
#  'baby;': 1,
#  "baby?'": 1,
#  'back': 25,
#  'back\nin': 1,
#  "back!'": 1,
#  "back!'\n\n'and": 1,
#  'back,': 4,
#  'back-somersault': 1,
#  'back.': 1,
#  'back.\nhowever,': 1,
#  'backs': 1,
#  'bad': 1,
#  'bad,': 1,
#  'bag,': 1,
#  'baked': 1,
#  'balanced': 1,
#  'balls': 1,
#  'bank,': 1,
#  'bank--the\nbirds': 1,
#  'banks,': 1,
#  "banquet--]\n\n'what": 1,
#  'bark': 2,
#  'barking': 1,
#  'barley-sugar': 1,
#  'barrowful': 2,
#  'bat!\n': 1,
#  'bat,': 1,
#  "bat?'": 1,
#  'bathing': 1,
#  'bats,': 1,
#  'bats?': 1,
#  "bats?'": 1,
#  'bawled': 1,
#  'be': 1,
#  'beau--ootiful': 1,
#  'beautiful,': 1,
#  'because': 1,
#  'bee,"': 1,
#  'beg': 1,
#  'besides,': 1,
#  'best': 1,
#  'between': 1,
#  'bill': 1,
#  'bill\n\nit': 1,
#  'bill!': 1,
#  "bill!'\nthen": 1,
#  "bill's": 1,
#  'bill,': 1,
#  'bill,\n"french,': 1,
#  "bill,'": 1,
#  'bird': 1,
#  "bird,'": 1,
#  'birds': 2,
#  'birds\ntittered': 1,
#  'birds!': 1,
#  'birds,)': 1,
#  'bit': 7,
#  'bit\nof': 1,
#  "bit!'": 1,
#  'bit,': 2,
#  "bit,'": 2,
#  'bit.': 1,
#  'bit.\n\n\n': 1,
#  "bit.'\n\n'perhaps": 1,
#  "bite,'": 1,
#  'bite.': 1,
#  'bitter--and--and': 1,
#  'blacking,': 1,
#  'blades': 1,
#  'blasts': 1,
#  'bleeds;': 1,
#  'blew': 2,
#  'blown': 1,
#  'blows': 1,
#  'body': 2,
#  'boldly:': 1,
#  'bone': 1,
#  'bones': 1,
#  'book': 2,
#  'book,': 1,
#  'book,\nbut': 1,
#  "book,'": 2,
#  'book-shelves;': 1,
#  'books,': 1,
#  'boon,\n': 1,
#  'boots': 2,
#  'both': 13,
#  'both\ncreatures': 1,
#  'bother': 1,
#  'bottle': 6,
#  'bottle,': 2,
#  'bottle.': 1,
#  'bottom': 4,
#  'bough': 1,
#  'bound': 1,
#  'bowed': 3,
#  'bowed,': 1,
#  'bowing': 1,
#  'box': 3,
#  'box--\n': 1,
#  'boxed': 1,
#  'boy,\n': 2,
#  'boy--and': 1,
#  'brain;\n': 1,
#  'branch': 1,
#  'branches': 1,
#  'branches,': 1,
#  'brass\nplate': 1,
#  'brave': 1,
#  'bread-and-butter': 1,
#  'bread-and-butter,': 2,
#  "bread-and-butter--'\n\n'but": 1,
#  "bread-knife.'\n\nthe": 1,
#  'break': 1,
#  'break.': 1,
#  'breath,': 2,
#  'breath,\nand': 1,
#  'breath."\n': 1,
#  'breathe': 1,
#  'breathe"!\'\n\n\'it': 1,
#  "breathe.'\n\n'i": 1,
#  'breeze': 1,
#  'bright': 7,
#  'bright-eyed': 1,
#  'brightened': 1,
#  'bring': 2,
#  'bringing': 2,
#  'bristling': 1,
#  'broke': 2,
#  'broken': 5,
#  'broken.': 1,
#  "brother's": 1,
#  'brought': 3,
#  'brown': 1,
#  'brown,': 1,
#  'brush,': 1,
#  'brushing': 1,
#  'burn': 2,
#  'burning': 1,
#  'burnt,': 1,
#  'burst\nof': 1,
#  'bursting': 1,
#  'busily': 3,
#  'busily\npainting': 1,
#  'business': 1,
#  "business!'": 1,
#  "business!'\n\n'ah,": 1,
#  'business,': 1,
#  "business,'": 1,
#  "business?'": 1,
#  'busy': 2,
#  'but': 6,
#  'but\ni': 1,
#  'but\nshe': 1,
#  'but,': 1,
#  'butter': 1,
#  'butter,\nyou': 1,
#  "butter,'": 1,
#  'buttercup': 1,
#  'butterfly,': 1,
#  'buttons,': 1,
#  'by': 1,
#  'cackled': 1,
#  'cake,': 2,
#  'cake.\n\n': 1,
#  'cakes': 1,
#  'cakes,': 1,
#  "cakes,'": 1,
#  'call': 5,
#  'called': 10,
#  'called\nout': 2,
#  'called\nthe': 1,
#  'calling': 1,
#  'calmly,\nthough': 1,
#  'came': 30,
#  "came\ndifferent!'": 1,
#  'came\njumping': 1,
#  'came\nnearer,': 1,
#  'came\nskimming': 1,
#  'came\nthe': 1,
#  'came\nvery': 1,
#  'came,': 1,
#  'camomile': 1,
#  'can': 18,
#  "can't": 22,
#  "can't\nbe": 1,
#  "can't\ntake": 1,
#  "can't\ntell": 1,
#  "can,'": 1,
#  "can--'\n\n'swim": 1,
#  'can;--but': 1,
#  'canary': 1,
#  'candle': 1,
#  'candle.': 1,
#  'cannot': 1,
#  'canterbury,': 1,
#  'canvas': 1,
#  'capering': 1,
#  'capital': 4,
#  "cardboard.)\n\n'all": 1,
#  "cards!'\n\nat": 1,
#  'cards,': 1,
#  'cards:': 1,
#  'care': 4,
#  'carefully,': 2,
#  'cares': 2,
#  'carried': 3,
#  'carried\nit': 1,
#  "carrier,'": 1,
#  'carroll\n\n***': 1,
#  'carroll\n\nposting': 1,
#  'carroll\n\nthe': 1,
#  'carroll\n\nthis': 1,
#  'carry': 1,
#  'carrying': 2,
#  'cart-horse,': 1,
#  'cartwheels,': 1,
#  'case': 4,
#  "case,'": 1,
#  'cat': 3,
#  'cat\nagain,': 1,
#  'cat!': 1,
#  "cat's": 1,
#  'cat,': 1,
#  "cat,'": 1,
#  'cat.': 1,
#  "cat.\n\n'--so": 1,
#  "cat.\n\n'i": 1,
#  'cat.)': 1,
#  'cat:': 1,
#  'cat;': 1,
#  'catch': 3,
#  'catching': 2,
#  'caterpillar': 1,
#  'caterpillar\n\nthe': 1,
#  "caterpillar's": 1,
#  'caterpillar,': 1,
#  'caterpillar,\nthat': 1,
#  "caterpillar.\n\n'i'm": 1,
#  "caterpillar.\n\n'is": 1,
#  "caterpillar.\n\n'not": 1,
#  "caterpillar.\n\n'well,": 1,
#  'caterpillar.\n\nalice': 1,
#  'caterpillar.\n\nhere': 1,
#  'caterpillar.\n\nthis': 1,
#  'caterpillar;': 1,
#  'cats': 9,
#  "cats!'": 1,
#  "cats.'\n\n'not": 1,
#  "cats?'": 1,
#  'cattle': 1,
#  'caucus-race': 1,
#  "caucus-race.'\n\n'what": 1,
#  "caucus-race?'": 1,
#  'caught': 3,
#  'cauldron': 2,
#  'cause': 2,
#  'cause,\n': 1,
#  'caused': 2,
#  'cautiously': 2,
#  'ceiling,\nand': 1,
#  'centre': 1,
#  'certain': 2,
#  'certain!': 1,
#  'certainly': 7,
#  "certainly,'": 3,
#  'certainly:': 2,
#  'chains,': 1,
#  'chance': 4,
#  'chanced': 1,
#  'change': 8,
#  'change,': 2,
#  'change:': 1,
#  'changed': 5,
#  'changed,': 1,
#  'changes': 2,
#  'changing': 2,
#  'character,\n': 1,
#  'charges': 1,
#  "chatte?'": 1,
#  'cheap': 1,
#  'checked': 3,
#  'cheeks,': 1,
#  'cheered,': 2,
#  'cheered.\n\nalice': 1,
#  'cheerfully': 1,
#  'cherry-tart,': 1,
#  'cheshire': 1,
#  'chief': 1,
#  'child': 3,
#  "child!'": 1,
#  "child!'\n\nthe": 1,
#  'child,': 1,
#  "child,'": 1,
#  'child-life,': 1,
#  'child:': 1,
#  "child?'\n\n'my": 1,
#  'children': 3,
#  'children\nsweet-tempered.': 1,
#  'children,': 3,
#  "children.\n\n'how": 1,
#  'children;': 1,
#  'chimney': 2,
#  "chimney!'\n\n'oh!": 1,
#  'chimney,': 2,
#  'chimney?--nay,': 1,
#  'chin': 4,
#  'chin.': 1,
#  "chin.\n\n'i've": 1,
#  'chin:': 1,
#  "choice!'\n\nthe": 1,
#  'choice,': 1,
#  'choke': 1,
#  'choked': 2,
#  'choked\nwith': 1,
#  'choking': 1,
#  'choosing': 1,
#  'chorus': 2,
#  'chorus,': 1,
#  'chorus.\n\n': 1,
#  'chose': 1,
#  "chose,'": 1,
#  "christmas.'\n\nand": 1,
#  'chrysalis--you': 1,
#  'chuckled.': 1,
#  'circle,': 1,
#  'circumstances.\nthere': 1,
#  'civil': 2,
#  'civil,': 1,
#  'clamour': 1,
#  'clapping': 1,
#  'clasped': 1,
#  'classics': 1,
#  'claws': 1,
#  'claws,\n': 1,
#  'clean': 1,
#  'clear': 2,
#  'cleared': 1,
#  'clearer': 1,
#  "clearly,'": 1,
#  "clever?'\n\n": 1,
#  'climb': 1,
#  'clinging': 1,
#  'clock': 1,
#  'clock.': 1,
#  'close': 10,
#  'close\nto': 1,
#  'close,': 1,
#  'closed': 2,
#  'closely': 1,
#  'closer': 1,
#  'clubs;': 1,
#  'coast': 1,
#  'coaxing': 1,
#  'coaxing.\n\nhardly': 1,
#  "coils.'\n\n'what": 1,
#  'cold': 1,
#  'collected': 2,
#  'come': 6,
#  'come\nhere': 1,
#  'come\nwrong,': 1,
#  'come,': 2,
#  'comes': 1,
#  'comes,': 1,
#  'comfits,': 1,
#  'comfits:': 1,
#  'comfort,': 1,
#  'comfortable,': 1,
#  'comfortably': 1,
#  'coming': 3,
#  'coming\nback': 1,
#  'coming\ndown!': 1,
#  "coming!'\n\n'how": 1,
#  'coming.': 1,
#  'common': 1,
#  'commotion': 1,
#  'company': 1,
#  'complained': 1,
#  'completely.\n\nvery': 1,
#  'concert\ngiven': 1,
#  "concert!'": 1,
#  'concluded': 2,
#  'conclusion,': 1,
#  'condemn\n': 1,
#  'conduct': 1,
#  'confused': 2,
#  'confused\nway,': 1,
#  'confused,': 1,
#  "confusing.'\n\n'it": 1,
#  'confusion': 3,
#  'confusion,': 1,
#  'conger-eel,\nthat': 1,
#  'conqueror,': 1,
#  "conqueror.'": 1,
#  'conquest.': 1,
#  'consented': 1,
#  'consider': 1,
#  'considered': 3,
#  'considering': 3,
#  'constant': 1,
#  'constant\nheavy': 1,
#  'contemptuous': 1,
#  'contemptuously.': 1,
#  "contemptuously.\n'i": 1,
#  'content': 1,
#  'continued': 7,
#  'continued,': 2,
#  'contradicted': 1,
#  'conversation': 3,
#  'conversation.': 2,
#  "conversation.\n\n'you": 1,
#  'conversation.\nalice': 1,
#  'conversations': 1,
#  'cook': 8,
#  'cook,': 2,
#  'cook.': 1,
#  "cook.\n\n'treacle,'": 1,
#  'cook.\n\nthe': 1,
#  'cool': 1,
#  'cool\nfountains.\n\n\n\n\nchapter': 1,
#  'copy': 1,
#  'corner': 1,
#  'corner,': 2,
#  'corner--no,': 1,
#  'cost': 1,
#  'could': 3,
#  'could\nbe': 1,
#  'could\nnot': 1,
#  'could\npossibly': 1,
#  'could\nshut': 1,
#  'could!': 1,
#  'could,': 7,
#  "could.\n\n'the": 1,
#  "couldn't": 9,
#  'counting': 1,
#  'country\nis,': 1,
#  "couple?'\n\n": 1,
#  'couples:': 1,
#  'courage': 1,
#  'courage,': 1,
#  'courage.': 1,
#  'course': 11,
#  'course,': 5,
#  "course,'": 5,
#  "course.'\n\n'what": 1,
#  'course;': 1,
#  "course?'\n\n'yes,'": 1,
#  'court': 3,
#  'court\nwas': 1,
#  'court\nwith': 1,
#  'court!': 1,
#  "court!'": 1,
#  'court,': 2,
#  'court,\nwithout': 1,
#  'court.': 1,
#  'court.\n\nall': 1,
#  "court.'\n\neverybody": 1,
#  'court;': 1,
#  'courtiers;': 1,
#  "coward!'": 1,
#  'crab': 1,
#  'crab,': 2,
#  'crash': 1,
#  "crash)--'now,": 1,
#  'crash,': 1,
#  'crashed\naround': 1,
#  'crawled': 1,
#  'crawling': 1,
#  "crazy!'\n\nthe": 1,
#  'creature': 2,
#  'creature,': 2,
#  'creatures': 4,
#  'creatures\nof': 1,
#  'creatures,': 1,
#  "creatures,'\n(she": 1,
#  'creatures.': 1,
#  'creep': 1,
#  'crept': 1,
#  'cried': 17,
#  'cried\nalice': 1,
#  'cried.': 1,
#  "cried.\n\n'come,": 1,
#  'crimson': 2,
#  'crocodile\n': 1,
#  'croquet': 2,
#  'croquet-ground': 1,
#  'croquet-ground\n\na': 1,
#  "croquet.'": 1,
#  "croquet.'\n\nthen": 1,
#  "croquet?'\n\nthe": 1,
#  'croqueted': 1,
#  'croqueting': 1,
#  'cross,': 1,
#  'cross-examine': 2,
#  'crossed': 3,
#  'crossly:': 1,
#  'crouched': 1,
#  'crowd': 4,
#  'crowded': 4,
#  'crowded\nround': 1,
#  'crown': 1,
#  'crumbs': 1,
#  "crumbs,'": 1,
#  "crumbs.'\n\n'you're": 1,
#  'cry': 3,
#  'crying': 2,
#  'cunning\n': 1,
#  'cup': 1,
#  "cup,'": 1,
#  'cupboards': 1,
#  'cur,': 1,
#  'curiosity,': 2,
#  'curiosity.': 1,
#  "curiosity.\n\n'it's": 1,
#  "curiosity.\n\n'soles": 1,
#  'curious': 15,
#  "curious!'": 1,
#  'curious,': 1,
#  "curious.'\n\n'it's": 1,
#  "curiouser!'": 1,
#  'curled': 2,
#  'curls': 1,
#  'curly': 1,
#  'currants.': 1,
#  'curtain': 1,
#  'curtsey': 1,
#  'curtseying': 1,
#  'curving': 1,
#  'cushion;': 1,
#  'custard,': 1,
#  'custody': 2,
#  'cut': 5,
#  "cutting,'": 1,
#  "d,'": 1,
#  'dainties': 1,
#  'daisies,': 1,
#  'daisy-chain': 1,
#  'dance': 2,
#  "dance,'": 1,
#  'dance.': 1,
#  'dance.\n': 1,
#  'dance.\n\n': 3,
#  'dance?\n': 2,
#  'dance?\n\n': 2,
#  'dance?"\'\n\n\'thank': 1,
#  'dancing': 1,
#  "dancing.'": 1,
#  'dare': 4,
#  'daresay': 1,
#  'dark': 3,
#  'darkness': 1,
#  'date:': 1,
#  'dates': 1,
#  'day': 11,
#  'day!': 1,
#  "day!'": 1,
#  'day,': 4,
#  "day,'": 1,
#  "day--'\n\n'i've": 1,
#  'day-school,': 1,
#  "day.\n\n'a": 1,
#  "day.\n\n'no,": 1,
#  "day.\n\n'that": 1,
#  "day.'\n\nthis": 1,
#  'day:\n': 1,
#  'day;': 1,
#  'days': 1,
#  'days.\n\n': 1,
#  "days.'\n\n'but": 1,
#  'dead': 3,
#  'dead\nleaves': 1,
#  'deal': 10,
#  'deal:': 1,
#  'dear': 6,
#  'dear!': 8,
#  'dear!\noh': 1,
#  'dear!"': 1,
#  "dear!'": 3,
#  'dear,': 4,
#  'dear,\nyou': 1,
#  "dear,'\nsaid": 1,
#  "dear?'": 1,
#  'dears': 1,
#  'dears!': 1,
#  'dears?': 1,
#  'death."\'\n\n\n\'you': 1,
#  'december': 1,
#  'decided': 2,
#  'decided\ntone:': 1,
#  'decidedly': 1,
#  'decidedly,': 3,
#  'declare': 1,
#  'declare,\n': 1,
#  'declared': 1,
#  'deep': 3,
#  'deep\nwell.\n\neither': 1,
#  'deep,': 2,
#  'deepest\ncontempt.': 1,
#  'deeply': 1,
#  'deeply,': 2,
#  'deeply.': 1,
#  'delay': 1,
#  'delight': 1,
#  'delight,': 2,
#  'delighted': 2,
#  'delightful': 2,
#  'denial;': 1,
#  'denied\nnothing,': 1,
#  'denied,': 1,
#  'denies': 1,
#  'deny': 2,
#  'depends': 1,
#  "derision.'\n\n'i": 1,
#  'deserved': 1,
#  'despair': 1,
#  'desperately:': 1,
#  'did': 47,
#  'did\nnot': 1,
#  "did!'": 1,
#  'did,': 3,
#  "did,'": 3,
#  'did.': 1,
#  'did:': 1,
#  "didn't": 11,
#  "didn't!'": 2,
#  "didn't,'": 1,
#  "die.\n\n'the": 1,
#  'died': 1,
#  'different': 3,
#  "different!'": 1,
#  'different,': 1,
#  "different,'": 1,
#  'different.': 1,
#  'difficult': 2,
#  'difficulties,': 1,
#  'difficulty': 3,
#  'difficulty,': 1,
#  'dig': 1,
#  'digging': 2,
#  'digging\nfor': 1,
#  'diligently': 1,
#  'dinah': 1,
#  'dinah!': 1,
#  "dinah!'": 1,
#  "dinah'll": 1,
#  'dinah,': 1,
#  'dinah:': 1,
#  'dinn': 1,
#  "dinn--'": 1,
#  "dinner!'\n\n('i": 1,
#  'dinner,': 1,
#  'dipped\nit': 1,
#  'directed': 2,
#  'direction': 2,
#  'direction,': 1,
#  "direction,'": 2,
#  'directions': 1,
#  'directions,': 2,
#  'directly,': 1,
#  'directly.': 1,
#  'disagree': 1,
#  'disgust,': 1,
#  'dish': 3,
#  'dish?\n': 1,
#  'dishes': 1,
#  'dishes.': 1,
#  'dismay,': 1,
#  'disobey,': 1,
#  'dispute': 1,
#  'distance': 1,
#  'distance,': 3,
#  'distance,\nsitting': 1,
#  'distance--but': 1,
#  "distance.\n\n'and": 1,
#  'distant': 2,
#  'dive': 1,
#  'do': 20,
#  'do\nanything': 1,
#  'do\nnext!': 1,
#  "do!'": 3,
#  'do,': 7,
#  "do,'": 4,
#  'do.': 1,
#  'do.\n\nalice': 1,
#  'do."\n': 1,
#  "do.'\n\n'i": 1,
#  "do.'\n\n'i'll": 1,
#  'do:': 1,
#  'do:--\n\n': 1,
#  "do?'": 1,
#  'dodged': 1,
#  'dodo': 1,
#  'dodo,': 1,
#  'dodo,\na': 1,
#  'dodo.\n\nthen': 1,
#  'does': 1,
#  'does,': 1,
#  'does.': 1,
#  "does.'\n\n'which": 1,
#  "doesn't": 12,
#  "doesn't\nmatter": 1,
#  "doesn't\ntell": 1,
#  'dog': 2,
#  "dog's": 1,
#  'dogs': 1,
#  "dogs.'\n\nit": 1,
#  "dogs?'": 1,
#  'doing': 2,
#  'doing\nout': 1,
#  "doing!'": 1,
#  "don't": 4,
#  "don't\nlike": 1,
#  "don't\nthink,'": 1,
#  "don't\nthink--'\n\n'then": 1,
#  "don't!'": 1,
#  'done': 8,
#  'done\njust': 1,
#  'done\nnow!': 1,
#  'done,': 1,
#  "done,'": 2,
#  'done.': 1,
#  "done.'\n\n'once": 1,
#  'door': 14,
#  'door\nleading': 1,
#  'door,': 5,
#  'door,\nhad': 1,
#  'door--\n': 1,
#  'door--i': 1,
#  "door.\n\n'call": 1,
#  'door.\n\npoor': 1,
#  'door:\nbut,': 1,
#  'door;': 1,
#  'doors': 2,
#  'dormouse': 1,
#  'dormouse\nturned': 1,
#  'dormouse!\nturn': 1,
#  "dormouse!'": 1,
#  "dormouse's": 1,
#  'dormouse,': 1,
#  "dormouse,'": 1,
#  'dormouse.': 1,
#  "dormouse.\n\n'don't": 1,
#  "dormouse.\n\n'write": 1,
#  'dormouse:': 1,
#  'dormouse;': 1,
#  'doth': 1,
#  'double': 1,
#  'doubled-up': 1,
#  'doubling': 1,
#  'doubt': 1,
#  'doubt,': 1,
#  'doubt,\nfor': 1,
#  'doubt:': 1,
#  'doubtful': 2,
#  'doubtfully,': 1,
#  'doubtfully:': 1,
#  'down': 70,
#  'down\nlooking': 1,
#  'down!': 1,
#  "down!'": 1,
#  'down,': 11,
#  "down,'": 3,
#  'down--here,': 1,
#  'down.': 2,
#  'down:': 1,
#  'downward!': 1,
#  'downwards,': 1,
#  'doze;': 1,
#  'dozing\noff,': 1,
#  'draggled': 1,
#  'draw': 4,
#  'draw,\nyou': 1,
#  "draw,'": 1,
#  "draw?'": 1,
#  'drawling,': 1,
#  'drawling--the': 1,
#  'drawling-master': 1,
#  'dreadful': 1,
#  'dreadfully': 4,
#  'dreadfully\nfond': 1,
#  'dreadfully\npuzzled': 1,
#  'dream': 3,
#  "dream!'": 1,
#  'dream,\ndear,': 1,
#  'dream.\n\nthe': 1,
#  'dream:--\n\nfirst,': 1,
#  'dreamed': 1,
#  'dreaming': 1,
#  'dreamy\nsort': 1,
#  'dressed,': 1,
#  'drew': 5,
#  'dried': 1,
#  'driest': 1,
#  'drink': 4,
#  "drinking.\n\n'they": 1,
#  'dripping': 1,
#  'drive': 1,
#  'drop': 1,
#  'dropped': 3,
#  'dropped\nit': 1,
#  'dropped,': 1,
#  'dropping': 1,
#  'drowned': 1,
#  'dry': 5,
#  'dry,': 1,
#  'duchess': 1,
#  'duchess\nsneezed': 1,
#  'duchess!': 1,
#  'duchess!\noh!': 1,
#  "duchess's": 1,
#  'duchess,': 1,
#  "duchess,'": 1,
#  'duchess.': 1,
#  'duchess:': 1,
#  "duchess:\nyou'd": 1,
#  'duchess;': 1,
#  "duchess?'\n\n'hush!": 1,
#  'duck': 2,
#  "duck.\n\n'found": 1,
#  'dull': 2,
#  "dull!'\n\n'you": 1,
#  'dunce?': 1,
#  'e--e--evening,\n': 3,
#  'each': 6,
#  'each\nother;': 1,
#  'eager': 3,
#  'eagerly': 2,
#  'eagerly\nwrote': 1,
#  'eagerly,': 2,
#  "eagerly.\n\n'that's": 1,
#  'eagerly:': 1,
#  'eaglet': 1,
#  'eaglet,': 1,
#  'eaglet.': 1,
#  'ear': 1,
#  'ear,': 1,
#  'ear.': 1,
#  "ear.\n\n'please": 1,
#  'ear.\n\nalice': 1,
#  'earls': 2,
#  'earnestly,': 1,
#  "earnestly.\n\n'i've": 1,
#  'ears': 3,
#  'ears\nand': 1,
#  "ears--'": 1,
#  'earth': 1,
#  'earth.': 2,
#  'easily': 2,
#  "easily\noffended!'\n\n'you'll": 1,
#  'easy': 2,
#  'eat': 16,
#  'eat"': 1,
#  'eaten': 1,
#  'eating': 1,
#  'eats': 1,
#  'ebook': 1,
#  'edgar': 1,
#  'edge': 3,
#  'edition': 1,
#  'editions': 2,
#  'educations--in': 1,
#  'edwin': 1,
#  'eel': 1,
#  'eels,': 1,
#  'effect': 1,
#  'effect,\nand': 1,
#  'effect:': 1,
#  'eggs': 1,
#  'eggs,': 3,
#  "eggs,'": 1,
#  'either': 5,
#  "either!'": 1,
#  'either,': 2,
#  'elbow': 2,
#  'elbows': 1,
#  "elegant\nthimble';": 1,
#  'eleventh': 1,
#  'else': 8,
#  'else"--but,': 1,
#  "else's": 1,
#  'else.\n\n\n\n\nchapter': 1,
#  "else.\n\n'leave": 1,
#  'elsie,': 1,
#  'emphasis,': 1,
#  'empty:': 1,
#  'encourage': 1,
#  'encouraged': 1,
#  'encouraging': 2,
#  'end': 1,
#  'end\n\n\n\n\n\nend': 1,
#  'end!': 1,
#  'end,': 1,
#  "end,'": 1,
#  "end.'\n\n'if": 1,
#  'end:': 1,
#  'ending': 1,
#  "energetic\nremedies--'\n\n'speak": 1,
#  'engaged': 1,
#  'england': 1,
#  'english': 1,
#  'english\n\n\n***': 1,
#  "english!'": 1,
#  'english);': 1,
#  'english,': 1,
#  "english,'": 1,
#  'english.': 1,
#  'engraved': 1,
#  'enjoy\n': 1,
#  'enormous': 1,
#  'enough': 8,
#  "enough!'": 1,
#  'enough,': 2,
#  "enough,'\n": 1,
#  'enough--i': 1,
#  'enough;': 2,
#  'entangled': 2,
#  'entirely': 1,
#  'entirely\ndisappeared;': 1,
#  'entrance': 1,
#  "escape!'": 1,
#  'escape,': 1,
#  'escape;': 1,
#  'esq.\n': 1,
#  'est': 1,
#  'even': 6,
#  'even\nin': 1,
#  'even\nwith': 1,
#  'evening,': 2,
#  'ever': 3,
#  "ever,'": 1,
#  "ever,'\nthought": 1,
#  'ever:': 1,
#  'ever;\n': 1,
#  'every': 8,
#  'every\ndoor,': 1,
#  'every\nmoment': 1,
#  'everybody': 5,
#  'everything': 8,
#  'evidence': 3,
#  "evidence\n\n\n'here!'": 1,
#  "evidence,'": 3,
#  'exact\nshape': 1,
#  'exactly': 1,
#  'exactly\nas': 1,
#  'exactly\nwhat': 1,
#  'examining': 1,
#  'excellent': 2,
#  'except': 3,
#  'exclaimed': 4,
#  'exclaimed,': 1,
#  'exclaimed.': 1,
#  'exclamation': 1,
#  'execute': 1,
#  'executed': 1,
#  'executed,': 2,
#  "executed.'\n\nthe": 1,
#  'execution--once': 1,
#  'execution.\n\nthen': 1,
#  "execution.'\n\n'what": 1,
#  'executioner': 3,
#  "executioner's": 1,
#  'executioner,': 1,
#  'executioner:': 1,
#  'executions': 1,
#  'existence;': 1,
#  'expected:': 1,
#  'expecting': 3,
#  'experiment': 1,
#  "experiment?'\n\n'he": 1,
#  'explain': 7,
#  "explained,'": 1,
#  "explanation.\n\n'oh,": 1,
#  'explanation;': 1,
#  "expressing\nyourself.'\n\nthe": 1,
#  'expression': 1,
#  'extraordinary': 2,
#  "extras?'": 1,
#  'extremely': 1,
#  "extremely--'": 1,
#  'eye': 4,
#  'eye,\n': 1,
#  'eye;': 2,
#  'eyelids,': 1,
#  'eyes': 15,
#  'eyes\nfilled': 1,
#  'eyes\nfull': 1,
#  'eyes,': 3,
#  'eyes,\nbut': 1,
#  'eyes--and': 1,
#  'eyes.': 2,
#  "eyes.--'tell": 1,
#  'eyes:': 1,
#  'eyes;': 1,
#  'face': 4,
#  'face\nbrightened': 1,
#  'face\nlike': 1,
#  'face,': 3,
#  'face,\nwith': 1,
#  'face--and': 1,
#  'face.': 1,
#  "face.\n\n'very,'": 1,
#  "face.\n\n'wake": 1,
#  'faces': 2,
#  'faces.': 1,
#  'fact': 2,
#  'fact,': 4,
#  "fact.\n\n'i": 1,
#  "fact.'\n\nalice": 1,
#  'fading': 1,
#  'failure.': 1,
#  'faint': 1,
#  'faintly\ncame,': 1,
#  'fair': 1,
#  "fairly,'": 1,
#  'fairy-tales,': 1,
#  'fall': 6,
#  'fall,': 1,
#  'fallen': 4,
#  'falling': 1,
#  'falling\nthrough': 1,
#  'familiarly': 1,
#  'family': 1,
#  'fan': 7,
#  'fan!\nquick,': 1,
#  'fan,\nand': 1,
#  'fancied': 1,
#  'fancied\nshe': 1,
#  'fancy': 3,
#  'fancy,': 1,
#  'fancying': 1,
#  'fanned': 1,
#  'fanning': 1,
#  'far': 9,
#  'far!"': 1,
#  'far,': 1,
#  "far,'": 2,
#  'farm-yard--while': 1,
#  'farmer,\nyou': 1,
#  'farther': 1,
#  'fashion,': 1,
#  "fashion.'": 1,
#  'fast': 4,
#  'faster': 1,
#  'faster,': 1,
#  'faster?"': 1,
#  'fat;\n': 1,
#  'father': 1,
#  'father,': 1,
#  'father;': 1,
#  'favoured': 1,
#  'favourite': 1,
#  'fear': 2,
#  'fear\nof': 1,
#  'feared': 1,
#  'feather': 1,
#  'feathers,': 1,
#  'feeble': 1,
#  'feeble,': 1,
#  'feel': 7,
#  'feeling': 5,
#  'feeling\nvery': 1,
#  "feeling!'": 1,
#  'feelings': 1,
#  'feelings.': 1,
#  'feet': 11,
#  'feet!': 1,
#  "feet!'\n(for": 1,
#  'feet,': 6,
#  'fell': 6,
#  'fellow!': 1,
#  "fellow!'": 1,
#  'fellow?': 1,
#  'fellows': 1,
#  'felt': 17,
#  'felt\nsure': 1,
#  'felt\nthat': 1,
#  'fender,\n': 1,
#  'ferrets': 1,
#  'fetch': 4,
#  'few': 9,
#  "fidgeted.\n\n'give": 1,
#  'field\nafter': 1,
#  'fifteen': 1,
#  'fifth\nbend,': 1,
#  "fig?'": 1,
#  'fight': 1,
#  'fight\nwas': 1,
#  'fighting': 1,
#  'figure': 1,
#  "figure!'": 1,
#  "figure,'": 1,
#  "figures!'\nand": 1,
#  'filled': 1,
#  'fills': 1,
#  'find': 20,
#  "find?'\n\nthe": 1,
#  'finding': 3,
#  'finds': 1,
#  'fine': 2,
#  'finger': 2,
#  'finger,': 1,
#  'finger;\nand': 1,
#  'finish': 4,
#  'finish,': 1,
#  'finished': 6,
#  'finished\nmy': 1,
#  'finished,': 1,
#  "finished,'": 1,
#  "finished.\n\n'as": 1,
#  "finished.'\n\nso": 1,
#  'finishing': 1,
#  'fire,': 2,
#  'fire-irons': 1,
#  'fireplace': 1,
#  'first': 25,
#  'first\nquestion,': 1,
#  'first\nsaw': 1,
#  "first!'\n\n'hold": 1,
#  'first,': 6,
#  'first,\nthe': 1,
#  "first,'": 2,
#  'first--they': 1,
#  'first--verdict': 1,
#  "first.\n\n'that's": 1,
#  "first.'\n\n'why?'": 1,
#  'first;': 2,
#  'fish': 2,
#  'fish,\n': 1,
#  'fish-footman': 1,
#  'fishes': 1,
#  'fit': 1,
#  'fit)\n': 1,
#  'fit--"': 1,
#  'fits,': 1,
#  'fitted!\n\nalice': 1,
#  'five': 1,
#  'five!': 1,
#  'five,': 1,
#  'five.': 1,
#  'fix': 1,
#  'fixed': 1,
#  'flame': 1,
#  'flamingo': 2,
#  'flamingo,': 1,
#  'flamingo.': 1,
#  'flamingo:\nshe': 1,
#  'flamingoes,': 1,
#  'flapper': 1,
#  'flappers,': 1,
#  'flashed': 1,
#  'flat': 1,
#  'flat,': 1,
#  'flavour\nof': 1,
#  'flew': 1,
#  'flock': 1,
#  'floor,': 2,
#  'floor:': 1,
#  'flower-beds': 1,
#  'flowers': 2,
#  'flown': 1,
#  'flung': 1,
#  'flurry': 1,
#  'flustered': 1,
#  'fluttered': 1,
#  'fly': 1,
#  'fly,\n': 1,
#  'fly;': 1,
#  'flying': 1,
#  'folded': 1,
#  'folded,': 2,
#  'folding': 1,
#  'follow': 1,
#  'follow,\nexcept': 1,
#  'followed': 8,
#  'follows\n': 2,
#  'follows:--\n\n': 1,
#  'fond': 2,
#  'fond--of--of': 1,
#  'foolish': 1,
#  'foot': 5,
#  'foot!\n\nshe': 1,
#  'foot,': 3,
#  "foot.\n\n'get": 1,
#  'footman': 1,
#  "footman's": 1,
#  'footman,': 1,
#  'footman.': 1,
#  'footmen,': 1,
#  'footsteps': 1,
#  'footsteps,\nand': 1,
#  'for': 1,
#  'for\n': 1,
#  'found': 26,
#  'found\nherself': 1,
#  'found\nout': 1,
#  'found:': 1,
#  'fountains,': 1,
#  'four': 4,
#  'four\nthousand': 1,
#  "fourth.'\n\n'two": 1,
#  'france--\n': 1,
#  'free': 2,
#  'free,\n': 1,
#  'french': 1,
#  'friend': 2,
#  'friends': 1,
#  'friends\nshared': 1,
#  'fright': 1,
#  "fright.\n'oh,": 1,
#  'frighten': 1,
#  'frightened': 5,
#  'frightened\ntone.': 1,
#  'frog': 1,
#  'frog-footman': 1,
#  'from': 2,
#  'from\none': 1,
#  'from\nthe': 1,
#  "from,'": 1,
#  'from:': 1,
#  'front': 2,
#  'frontispiece': 1,
#  'frowning': 3,
#  'frowning,': 1,
#  'frying-pan': 1,
#  'fulcrum': 1,
#  'full': 5,
#  'fumbled': 1,
#  'fun': 1,
#  "fun!'": 1,
#  "fun?'": 1,
#  'funny': 2,
#  'fur': 2,
#  'fur.': 1,
#  'furious': 1,
#  'furiously,': 1,
#  'furrow': 1,
#  'furrows;': 1,
#  'further': 1,
#  'further.\n\nso': 1,
#  'further:\nshe': 1,
#  'fury,': 1,
#  'fury:\n': 1,
#  'gained': 1,
#  'gallons': 1,
#  'game': 5,
#  'game\nbegan.': 1,
#  "game's": 1,
#  'game,': 1,
#  "game,'": 1,
#  'game.\n\n\n\n\nchapter': 1,
#  "game.'\n\nthe": 1,
#  'games': 1,
#  'garden': 4,
#  "garden!'": 1,
#  'garden,': 5,
#  'garden--how': 1,
#  'garden.': 3,
#  'garden."\'\n\nalice': 1,
#  'garden:': 1,
#  'gardeners': 3,
#  'gardeners,': 4,
#  'gather': 1,
#  'gave': 2,
#  'gay': 1,
#  'gazing': 1,
#  'general': 3,
#  'generally': 3,
#  'generally\ngave': 1,
#  'generally,': 2,
#  'gently': 3,
#  'geography.\nlondon': 1,
#  'get': 37,
#  'get\nan': 1,
#  'get\non': 1,
#  'get\nthem': 1,
#  'get\nto': 1,
#  'getting': 20,
#  'getting\nsomewhere': 1,
#  "getting!'": 1,
#  "giddy.'": 1,
#  "giddy.'\n\n'all": 1,
#  'girl': 3,
#  "girl,'": 1,
#  'girls': 3,
#  'give': 9,
#  'give\nbirthday': 1,
#  'giving': 2,
#  'glad': 9,
#  'glad\nshe': 1,
#  'glad\nthere': 1,
#  'glanced': 1,
#  'glaring': 1,
#  'glass': 3,
#  'glass,': 1,
#  'glass,\nfrom': 1,
#  'glass.': 1,
#  "glass.)\n\n'now": 1,
#  'globe': 1,
#  'gloomily:': 1,
#  'gloves': 5,
#  'gloves,': 1,
#  'gloves,\nand': 2,
#  'gloves--that': 1,
#  "gloves.\n\n'how": 1,
#  'gloves:': 1,
#  'go': 3,
#  'go\nafter': 1,
#  'go\nto': 1,
#  'go!': 1,
#  'go,': 4,
#  "go,'": 2,
#  'go.\n\nalice': 1,
#  'go?"': 1,
#  'goes': 7,
#  'going': 18,
#  'going\ndown': 1,
#  'going\ninto': 1,
#  'going\non,': 1,
#  'going\nthrough': 1,
#  'going\nto': 2,
#  'going,': 1,
#  'golden': 6,
#  'golden\nkey': 1,
#  'goldfish': 1,
#  'goldfish\nshe': 1,
#  'gone': 8,
#  'gone\n': 1,
#  'gone,': 3,
#  "gone.\n\n'well!": 1,
#  'good': 21,
#  "good\nthing!'": 1,
#  'good,\nthat': 1,
#  'good-bye,': 1,
#  'good-natured,': 1,
#  'good-naturedly': 1,
#  'goose!': 1,
#  'goose,': 1,
#  'got': 41,
#  'got\nit': 1,
#  'got\nits': 1,
#  'graceful': 1,
#  'grammar,': 1,
#  'grand': 1,
#  'grand\nprocession,': 1,
#  'grand,': 1,
#  'grant': 1,
#  'grass': 2,
#  'grass,': 2,
#  'grave': 2,
#  'grave\nthat': 1,
#  'gravely,': 2,
#  'gravely.': 1,
#  'gravy,': 1,
#  'grazed': 1,
#  'great': 31,
#  'great\ndeal': 1,
#  'great\ndisappointment': 1,
#  'great\nhurry,': 1,
#  'great\nmany': 1,
#  'great\nquestion': 1,
#  'green': 3,
#  'green,\n': 1,
#  'grew': 1,
#  'grey': 1,
#  'grief,': 1,
#  'grin\nwithout': 1,
#  'grin,': 2,
#  'grin,\n': 1,
#  "grin,'": 1,
#  "grin.'\n\n'they": 1,
#  'grinned': 2,
#  'grinned;': 1,
#  'grinning': 1,
#  'grins': 1,
#  'ground': 1,
#  'ground,': 1,
#  "ground.'": 1,
#  'grow': 9,
#  'growing': 4,
#  "growing\ntoo.'\n\n'yes,": 1,
#  'growing,': 2,
#  'growing,\nand': 1,
#  "growing.'\n\n'you've": 1,
#  'growl': 1,
#  'growl,\n': 1,
#  'growled': 1,
#  "growling,'": 1,
#  'growls': 1,
#  'grown': 7,
#  "grumbled:\n'you": 1,
#  "grunt,'": 1,
#  'grunted': 3,
#  'grunted,': 1,
#  'gryphon': 1,
#  'gryphon,': 1,
#  'gryphon,\nhalf': 1,
#  'gryphon.': 1,
#  "gryphon.\n\n'--you": 1,
#  "gryphon.\n\n'it": 1,
#  "gryphon.\n\n'of": 1,
#  "gryphon.\n\n'the": 1,
#  "gryphon.\n\n'then,": 1,
#  "gryphon.\n\n'turn": 1,
#  "gryphon.\n'we": 1,
#  'gryphon:': 1,
#  'gryphon;': 1,
#  'guard\nhim;': 1,
#  'guess': 2,
#  'guess,': 1,
#  'guessed': 3,
#  'guests': 2,
#  'guests,': 1,
#  "guilt,'": 1,
#  'guinea-pig': 1,
#  'guinea-pig,\nhead': 1,
#  'guinea-pigs': 1,
#  "guinea-pigs!'": 1,
#  'guinea-pigs,': 1,
#  'guinea-pigs,\nfilled': 1,
#  'gutenberg': 1,
#  "gutenberg's": 1,
#  'had': 157,
#  'had\na': 1,
#  "had\ndisappeared.\n\n'never": 1,
#  'had\ndrunk': 1,
#  'had\nfinished,': 1,
#  'had\njust': 1,
#  'had\nknown': 1,
#  'had\nnever': 1,
#  'had\nnibbled': 1,
#  'had\nnot': 1,
#  'had\nplenty': 1,
#  'had\nslipped': 1,
#  'had\nsucceeded': 1,
#  'had,': 1,
#  "hadn't": 6,
#  "hadn't\ndrunk": 1,
#  'hair': 5,
#  'hair!': 1,
#  'hair."\n': 1,
#  'half': 19,
#  'half\nthose': 1,
#  'half-past': 1,
#  'hall': 1,
#  'hall,': 5,
#  'hall.\n\nafter': 1,
#  'hall:': 1,
#  'hall;\nbut,': 1,
#  'hand': 9,
#  'hand,': 3,
#  'hand,\nand': 1,
#  "hand,'": 1,
#  "hand.\n\n'and": 1,
#  'handed': 3,
#  'hands': 4,
#  'hands,': 4,
#  'hands,\nwondering': 1,
#  'hands;': 1,
#  'handsome': 1,
#  "handwriting?'": 1,
#  'hanging': 2,
#  'hanging\nfrom': 1,
#  'happen': 5,
#  'happen,': 1,
#  "happen,'": 1,
#  'happen:': 1,
#  'happened': 3,
#  'happened,': 2,
#  "happened.\n\n'how": 1,
#  'happened.)': 1,
#  'happening.': 1,
#  'happens': 2,
#  "happens!'\n\nshe": 1,
#  'happens.': 1,
#  'happens;': 1,
#  'happy': 1,
#  'hard': 8,
#  'hardly': 11,
#  'hare': 1,
#  'hare\nmoved': 1,
#  'hare,': 1,
#  'hare,)': 1,
#  'hare.': 1,
#  "hare.\n\n'exactly": 1,
#  "hare.\n\n'he": 1,
#  "hare.\n\n'i": 1,
#  "hare.\n\n'it": 1,
#  "hare.\n\n'sixteenth,'": 1,
#  "hare.\n\n'then": 1,
#  "hare.\n\n'yes,": 1,
#  'hare.\n\nalice': 1,
#  'hare:': 1,
#  'harm': 1,
#  'has': 3,
#  "hasn't": 2,
#  'haste,': 1,
#  'hastily': 6,
#  'hastily\nbegan': 1,
#  'hastily,': 3,
#  'hastily.': 2,
#  "hastily.\n\n'i": 1,
#  'hastily;': 1,
#  "hat,'": 1,
#  'hatching': 1,
#  'hate': 1,
#  'hate--c': 1,
#  'hated\ncats:': 1,
#  'hatter': 1,
#  "hatter's": 1,
#  'hatter,': 1,
#  'hatter,\nwho': 1,
#  'hatter.': 1,
#  "hatter.\n\n'i": 1,
#  "hatter.\n\n'it": 1,
#  "hatter.\n\n'nor": 1,
#  "hatter.\n\n'stolen!'": 1,
#  "hatter.\n\n'you": 1,
#  'hatter.\n\nalice': 1,
#  'hatter.\n\nthis': 1,
#  "hatter.'\n\nhere": 1,
#  'hatter:': 1,
#  'hatter;': 1,
#  'hatters': 1,
#  'have': 16,
#  'have\nyou': 1,
#  "haven't": 5,
#  "haven't\ngot": 1,
#  "haven't,'": 1,
#  'having': 9,
#  'having\ncheated': 1,
#  'he': 7,
#  'he\n': 1,
#  'he\ncertainly': 1,
#  'he\ndid': 1,
#  'he\nhurried': 1,
#  'he\nsays': 1,
#  "he'd": 1,
#  "he'll": 1,
#  "he's": 1,
#  "he?'": 1,
#  'head': 26,
#  'head\nover': 1,
#  'head!': 1,
#  "head!'": 5,
#  "head!'\n\nalice": 1,
#  "head's": 1,
#  'head,': 3,
#  'head--\n': 1,
#  "head--brandy\nnow--don't": 1,
#  'head.': 2,
#  'head.\nbut': 1,
#  'head.\nstill': 1,
#  'head:': 1,
#  'heads': 5,
#  "heads!'": 1,
#  'heads.': 1,
#  'heap': 1,
#  'hear': 13,
#  'hear\noneself': 1,
#  'heard': 25,
#  'heard\na': 2,
#  'heard\nit': 1,
#  'heard\nof': 1,
#  "heard!'\n\n'yes,": 1,
#  'hearing': 3,
#  'hearing.': 1,
#  'heart': 2,
#  'hearth': 1,
#  'hearthrug,\n': 1,
#  'hearts': 1,
#  'hearts,': 1,
#  'hearts.': 1,
#  'hearts.\n\nalice': 1,
#  "hedge!'": 1,
#  'hedge.\n\nin': 1,
#  'hedgehog': 4,
#  'hedgehog,': 1,
#  'hedgehog.\n\nthe': 1,
#  'hedgehogs': 1,
#  'hedgehogs,\nthe': 1,
#  'hedgehogs;': 1,
#  'heels': 1,
#  'height': 4,
#  'height.\n\nit': 1,
#  'held': 3,
#  'help': 8,
#  'helped': 1,
#  'helpless\nsort': 1,
#  'her': 22,
#  'her\nabout': 1,
#  'her\nage': 1,
#  'her\nanswer.': 1,
#  'her\nbest': 1,
#  'her\nchildhood:': 1,
#  'her\ndaughter': 1,
#  'her\nfriend.\n\nwhen': 1,
#  'her\nhand': 1,
#  'her\nhand,': 2,
#  'her\nhands': 1,
#  'her\nhead': 1,
#  "her\nhead!'": 1,
#  'her\nhead.': 1,
#  'her\nmouth;': 1,
#  'her\nneck': 1,
#  'her\npocket,': 1,
#  'her\nsharp': 1,
#  'her\nsister,': 1,
#  'her\nway': 1,
#  'her\nwonderful': 1,
#  'her,': 16,
#  'her,\n': 1,
#  "her,'": 1,
#  'her.': 7,
#  "her.\n\n'collar": 1,
#  "her.\n\n'i": 1,
#  "her.\n\n'what": 1,
#  "her.\n\n'yes!'": 1,
#  'her.\n\nalice': 1,
#  'her.\n\nthere': 1,
#  'her:': 3,
#  'her:\nthe': 1,
#  'her;': 3,
#  'here': 11,
#  "here\nbefore,'": 1,
#  'here\ntill': 1,
#  'here!': 2,
#  "here!'\n\nas": 1,
#  'here,': 6,
#  "here,'": 5,
#  'here.': 2,
#  "here.'\n\n'but": 1,
#  "here.'\n\nalice": 1,
#  "here.'\nand": 1,
#  'here;': 1,
#  'here?': 2,
#  "here?'": 1,
#  "here?'\n\n'in": 1,
#  "here?'\n\n'may": 1,
#  "here?'\n\n'that": 1,
#  'hers': 2,
#  'hers\nwould,': 1,
#  'hers--she': 1,
#  'herself': 34,
#  "herself\n'it's": 1,
#  "herself\nhastily.\n\n'i": 1,
#  'herself\nsafe': 1,
#  'herself\nto': 1,
#  'herself,': 25,
#  'herself,\nand': 1,
#  'herself,\nas': 1,
#  'herself,\nfor': 1,
#  'herself,\nrather': 1,
#  'herself.': 3,
#  "herself.\n\n'i": 1,
#  "herself.\n\n'of": 1,
#  "herself.\n\n'would": 1,
#  'herself.\n\nat': 1,
#  'herself;': 3,
#  'hid': 1,
#  'hide': 1,
#  'high': 1,
#  "high).\n\n'but": 1,
#  'high,': 3,
#  "high,'": 2,
#  'high.': 1,
#  'high.\n\n\n\n\nchapter': 1,
#  "high.\n\n'i": 1,
#  'high:': 2,
#  'high:\nthen': 1,
#  'highest': 1,
#  'him': 1,
#  'him\nhis': 1,
#  'him!': 2,
#  'him),': 1,
#  'him,': 1,
#  "him,'": 2,
#  'him--how': 1,
#  'him--it': 1,
#  'him.': 1,
#  "him.\n\n'--or": 1,
#  "him.'\n\n'i": 1,
#  'him:': 2,
#  'him:\n': 1,
#  'himself': 4,
#  'himself,': 1,
#  'himself:': 1,
#  'hint;': 1,
#  'hippopotamus,': 1,
#  'his': 27,
#  'his\nfancy,': 1,
#  'his\nhead!"\'\n\n\'how': 1,
#  'his\nnormans--"': 1,
#  'his\npocket,': 1,
#  'his\nremark,': 1,
#  'his\nslate': 1,
#  'his\ntail.': 1,
#  "his\nwhiskers!'\n\nfor": 1,
#  'hiss': 1,
#  'histories': 1,
#  'history': 1,
#  'history,': 2,
#  "history,'\n\nas": 1,
#  'history.': 1,
#  'hit': 2,
#  'hoarse': 1,
#  'hoarse\ngrowl,': 1,
#  'hoarsely\nall': 1,
#  'hold': 6,
#  'holding': 2,
#  'holding,': 1,
#  'hollow': 1,
#  'home': 1,
#  "home,'": 1,
#  'home;': 1,
#  "home?'": 1,
#  'honest': 1,
#  "honour!'": 1,
#  "honour!'\n\n'digging": 1,
#  'honour,': 1,
#  'honour:': 1,
#  'hookah': 3,
#  'hope': 3,
#  'hoped)': 1,
#  'hopeful': 1,
#  'hoping': 3,
#  'hot': 1,
#  'hot\nbuttered': 1,
#  'hot,': 1,
#  "hot-tempered,'\nshe": 1,
#  'hour': 2,
#  'hours': 3,
#  'hours,': 1,
#  'house': 7,
#  'house\nof': 1,
#  "house!'": 1,
#  'house,': 7,
#  'house,\n': 1,
#  "housemaid,'": 1,
#  'houses,': 1,
#  'how': 8,
#  'how\nconfusing': 1,
#  'how\ndo': 1,
#  'how\nin': 1,
#  'how\nlarge': 1,
#  'how\nmany': 1,
#  'how\nqueer': 1,
#  'however,': 1,
#  'however,\nwhen': 1,
#  'howled': 1,
#  'howling': 2,
#  'howling\nalternately': 1,
#  'humble': 1,
#  'humbly:': 1,
#  'humbly;': 1,
#  'hundred': 1,
#  'hungry': 2,
#  'hunting': 3,
#  'hurried': 7,
#  'hurried\nback': 1,
#  'hurried\nnervous': 1,
#  'hurried\noff,': 1,
#  'hurriedly': 2,
#  'hurry': 4,
#  'hurry.': 1,
#  "hurry.\n\n'you": 1,
#  'hurry.\n\nan': 1,
#  'hurry:': 1,
#  'hurry;': 2,
#  'hurrying': 1,
#  'hurt': 1,
#  'hurt\nthe': 1,
#  'hurt,': 1,
#  "hush!'": 2,
#  'i': 1,
#  'i\ncan': 1,
#  'i\ndare': 1,
#  "i\nfancy--who's": 1,
#  'i\nget"': 1,
#  'i\ngrow': 1,
#  "i\nhaven't": 1,
#  "i\nsay--that's": 1,
#  'i\nshall': 1,
#  'i\nshould': 1,
#  'i\nsuppose': 1,
#  'i\nused--and': 1,
#  "i\nwon't,": 1,
#  "i!'": 1,
#  "i'd": 1,
#  "i'd\nonly": 1,
#  "i'll": 1,
#  "i'll\n": 1,
#  "i'll\nget": 1,
#  "i'll\ngo": 1,
#  "i'm": 1,
#  "i'm\na": 1,
#  "i'm\nopening": 1,
#  "i'm\nsure": 1,
#  "i've": 1,
#  "i've\n": 1,
#  "i've\nmade": 1,
#  'i,': 1,
#  "i,'": 1,
#  "i--'\n\n'oh,": 1,
#  'i.': 1,
#  'i?': 1,
#  'idea': 12,
#  'idea\nhow': 1,
#  'idea\nthat': 1,
#  "idea,'": 1,
#  "idiotic!'": 1,
#  'if': 1,
#  'if--if': 1,
#  'ii.': 1,
#  'iii.': 1,
#  "ill.'\n\n'so": 1,
#  "ill.'\n\nalice": 1,
#  'imagine': 1,
#  'imitated': 1,
#  'immediate': 1,
#  'immediately': 3,
#  'immense': 1,
#  'impatient': 1,
#  'impatiently,': 2,
#  'impatiently:': 1,
#  "impatiently:\n'any": 1,
#  'impatiently;': 1,
#  "impertinent,'": 1,
#  'important': 2,
#  'important\nto': 1,
#  "important,'": 1,
#  'impossible': 1,
#  'impossible\nto': 1,
#  'improve': 1,
#  'in': 1,
#  'in\na': 1,
#  'indeed,': 1,
#  'inside,': 1,
#  'involved': 1,
#  'irritated': 1,
#  'is': 1,
#  'it': 4,
#  'it\na': 1,
#  'it\naloud;': 1,
#  'it\nbegan': 1,
#  'it\nfelt': 1,
#  'it\nhad': 1,
#  'it\nmakes': 1,
#  'it\noccurred': 1,
#  'it\nsomething': 1,
#  'it\nstays': 1,
#  'it\nto': 1,
#  'it\nwas': 1,
#  "it\nwas,'": 1,
#  'it\nwould': 1,
#  'it!': 1,
#  "it!'": 3,
#  "it!'\n\n'i": 1,
#  "it!'\n\nlast": 1,
#  "it!'\n\nthis": 1,
#  "it!'\nand": 1,
#  'it!--that': 1,
#  "it'll": 4,
#  "it's": 3,
#  "it's\na": 1,
#  'it),': 1,
#  'it),\nand': 1,
#  'it,': 35,
#  'it,\nbut': 1,
#  'it,\nthat': 1,
#  "it,'": 18,
#  'it,)': 1,
#  "it--'\n\n'i": 1,
#  'it--once': 1,
#  'it.': 2,
#  'it.\n\n': 1,
#  "it.\n\n'they": 1,
#  "it.\n\n'well!'": 1,
#  'it.\n\nas': 1,
#  'it.\n\npresently': 1,
#  'it.\n\nshe': 1,
#  'it.\nthere': 1,
#  "it.'": 4,
#  "it.'\n\n'hadn't": 1,
#  "it.'\n\n'i": 1,
#  "it.'\n\n'she's": 1,
#  "it.'\n\n'that's": 1,
#  "it.'\n\nthe": 1,
#  "it.)\n\n'i'm": 1,
#  'it.)\n\nfirst': 1,
#  'it:': 7,
#  'it;': 9,
#  "it?'": 8,
#  "it?'\n\n": 1,
#  "it?'\n\n'why,'": 1,
#  "it?'\n\nthe": 1,
#  'it?)': 1,
#  'its': 46,
#  'its\nage,': 1,
#  'its\narms,': 1,
#  'its\neyes': 1,
#  'its\neyes,': 1,
#  'its\nface': 1,
#  'its\ntail': 1,
#  'itself': 7,
#  'itself,': 3,
#  'itself,)': 1,
#  'itself.': 1,
#  'iv.': 1,
#  'ix.': 1,
#  'jack-in-the-box,': 1,
#  'jar': 2,
#  'jaw,\n': 1,
#  'jaws': 1,
#  "jaws!'\n\n'i'm": 1,
#  'jelly-fish': 1,
#  'jogged': 1,
#  'join': 9,
#  'joined': 2,
#  'joined):--\n\n': 1,
#  'journey,': 1,
#  'joys,\nremembering': 1,
#  'judge,': 2,
#  'judge,\n': 1,
#  "judge,'": 1,
#  'judging': 1,
#  'jumped': 5,
#  'jumping': 2,
#  'june': 1,
#  'juror': 1,
#  'jurors': 3,
#  "jurors.'": 1,
#  'jury': 7,
#  'jury\n': 1,
#  'jury\nall': 1,
#  'jury,': 4,
#  'jury,"\n': 1,
#  "jury--'\n\n'if": 1,
#  'jury-box': 1,
#  'jury-box,': 2,
#  "jury-box,'": 1,
#  'jury.': 1,
#  "jury.\n\n'not": 1,
#  'jurymen': 2,
#  "jurymen.\n\n'it": 1,
#  "jurymen.\n\n'no,": 1,
#  'just': 9,
#  'just\nexplain': 1,
#  'justice': 1,
#  'keep': 8,
#  'keeping': 2,
#  'kept': 12,
#  'kettle': 1,
#  'key': 4,
#  'key,': 3,
#  'key;': 1,
#  'kick': 2,
#  'kick,': 1,
#  'kid': 5,
#  'kill': 1,
#  'killing': 1,
#  'kills': 1,
#  'kind': 4,
#  "kind,'": 1,
#  'kindly': 1,
#  'kindly,': 1,
#  'king': 1,
#  "king's": 1,
#  "king's\ncrown": 1,
#  'king,': 1,
#  "king,'": 1,
#  'king.': 1,
#  "king.\n\n'it": 1,
#  "king.\n\n'nearly": 1,
#  "king.\n\n'nothing": 1,
#  "king.\n\n'shan't,'": 1,
#  "king.\n\n'then": 1,
#  'king.\n\nhere': 1,
#  'king.\n\non': 1,
#  'king.\n\nthe': 1,
#  'king:': 1,
#  'king;': 1,
#  'kings': 1,
#  'kissed': 1,
#  'kitchen': 1,
#  'kitchen\nthat': 1,
#  'kitchen,': 1,
#  "kitchen.\n\n'when": 1,
#  'knave': 1,
#  'knave,': 1,
#  'knee': 1,
#  'knee,': 3,
#  'knee.': 1,
#  'kneel': 1,
#  'knelt': 1,
#  'knew': 10,
#  'knew\nthe': 1,
#  'knew\nwhether': 1,
#  'knew,': 1,
#  'knife': 1,
#  'knife,': 1,
#  'knock,': 1,
#  "knocked.\n\n'there's": 1,
#  "knocking,'": 2,
#  "knot!'": 1,
#  'knot,': 1,
#  'know': 1,
#  'know\nis,': 1,
#  'know\nthat': 1,
#  'know\nwhat': 1,
#  'know\nwhether': 1,
#  'know\nwho': 1,
#  "know!'": 1,
#  "know!'\n\nthe": 1,
#  'know,': 5,
#  'know,\nbut': 1,
#  "know,'": 7,
#  "know,'\nhe": 1,
#  "know--'": 1,
#  "know--'\n\n'but,": 1,
#  "know--'\n\n'what": 1,
#  "know--'\n\nshe": 1,
#  'know--and': 1,
#  'know--no': 1,
#  'know.': 7,
#  'know.\nso': 1,
#  "know.'\n\n'and": 1,
#  "know.'\n\n'i": 1,
#  "know.'\n\n'not": 1,
#  "know.'\n\n'who": 1,
#  "know.'\n\nalice": 1,
#  "know.'\n\nit": 1,
#  "know.'\nhe": 1,
#  "know?'": 1,
#  "know?'\n\n'it's": 1,
#  'knowing': 1,
#  'knowledge': 1,
#  'knowledge,': 1,
#  'knowledge.': 1,
#  'knows': 2,
#  'knuckles.': 1,
#  'label': 1,
#  'labelled': 1,
#  'lacie,': 1,
#  'lad!--here,': 1,
#  'lady': 2,
#  "lady,'": 1,
#  'laid': 2,
#  'lamps': 1,
#  'land': 1,
#  'languid,': 1,
#  'lap': 2,
#  'large': 24,
#  'large\nas': 1,
#  'large\nflower-pot': 1,
#  'large\nin': 1,
#  'large\nletters.\n\nit': 1,
#  'large\nrabbit-hole': 1,
#  'large,': 1,
#  'larger': 3,
#  'larger,': 3,
#  'larger:': 1,
#  'largest': 1,
#  'lark,\n': 1,
#  'last': 23,
#  'last\nremark': 1,
#  "last!'": 1,
#  'last,': 5,
#  'last:': 1,
#  'lasted': 1,
#  "lasted.)\n\n'then": 1,
#  'late': 3,
#  "late!'": 1,
#  'late,': 1,
#  "late.'": 1,
#  'lately,\nthat': 1,
#  'later.\n\nhowever,': 1,
#  'latin': 1,
#  'latitude': 1,
#  'latitude\nor': 1,
#  'laugh;': 1,
#  'laughed': 1,
#  "laughed,\n'let": 1,
#  'laughter.': 1,
#  'law,\n': 1,
#  'law:': 1,
#  'lay': 4,
#  'lazily': 1,
#  "lazy\nthing!'": 1,
#  'leaders,': 1,
#  'leaning': 2,
#  'leant\nagainst': 1,
#  'leap': 1,
#  'learn': 3,
#  'learn\nlessons': 1,
#  'learn!': 2,
#  "learn?'\n\n'well,": 1,
#  'learned': 1,
#  'learning': 2,
#  'learnt': 2,
#  'least': 7,
#  'least,': 1,
#  'least--at': 1,
#  'leave': 1,
#  'leave\nthe': 1,
#  'leaves': 1,
#  'leaves,': 2,
#  'leaves.\n\nas': 1,
#  'leaving': 1,
#  'led': 3,
#  'ledge': 1,
#  'left': 12,
#  'left,': 1,
#  'lefthand': 1,
#  'legs': 3,
#  'length': 1,
#  'less': 2,
#  'less\nthan': 1,
#  "less,'": 1,
#  'lessen': 1,
#  'lesson': 1,
#  'lesson-book.': 1,
#  "lesson-books!'\n\nand": 1,
#  'lessons': 3,
#  "lessons!'\nthought": 1,
#  'lessons,': 1,
#  "lessons,'": 2,
#  'lessons:': 1,
#  "lessons?'": 1,
#  'lest': 1,
#  'let': 5,
#  "let's": 3,
#  'letter,': 1,
#  'letter,\nnearly': 1,
#  'lewis': 1,
#  'license': 1,
#  'licking': 1,
#  'lie': 2,
#  'life': 1,
#  'life\nbefore,': 1,
#  'life!': 1,
#  "life!'\n\njust": 1,
#  "life!'\n\nshe": 1,
#  'life,': 2,
#  'life.': 1,
#  'life.\n\nthe': 1,
#  "life.'\n\n": 1,
#  'life;': 1,
#  'lifted': 1,
#  'like': 22,
#  "like\nthat!'\n\n'i": 1,
#  'like\nthe': 1,
#  "like\nyou,'": 1,
#  "like!'": 1,
#  'like"!\'\n\n\'you': 1,
#  'like,': 2,
#  "like,'": 3,
#  "like.'\n\n'i": 1,
#  'like:': 1,
#  "like?'": 1,
#  'liked': 3,
#  'liked,': 1,
#  "liked.'\n\n'is": 1,
#  'likely': 3,
#  "likes.'\n\n'i'd": 1,
#  'limbs': 1,
#  'line': 1,
#  'line:\n\n': 1,
#  "lines!'": 1,
#  'linked\ninto': 1,
#  'lips.': 1,
#  'list': 2,
#  'list,': 1,
#  'listen': 4,
#  "listen.\n\n'mary": 1,
#  'listen.\n\nthe': 1,
#  'listened,': 1,
#  'listeners': 1,
#  'listening,': 2,
#  'listening:': 1,
#  'lit': 1,
#  'little': 51,
#  'little\nanimals': 1,
#  'little\nbefore': 1,
#  'little\nbirds': 1,
#  'little\nbottle': 1,
#  'little\nglass': 1,
#  'little\nhot': 1,
#  'little\nqueer,': 1,
#  'little\nscream': 1,
#  'little\nsnappishly.': 1,
#  'little\nstartled': 1,
#  'little!': 1,
#  "little!'\n\nshe": 1,
#  'little,': 3,
#  "little,'": 1,
#  'little--"\'': 1,
#  "little.\n\n''tis": 1,
#  'live': 7,
#  'live.': 1,
#  'lived': 3,
#  'livery': 1,
#  'livery,': 1,
#  'livery:\notherwise,': 1,
#  "lives\nthere,'": 1,
#  'lives.\n\nall': 1,
#  'lizard': 1,
#  'lizard\nas': 1,
#  'lizard)': 1,
#  'lizard,': 1,
#  'lobster': 1,
#  'lobster\nquadrille,': 1,
#  "lobster--'\n(alice": 1,
#  'lobster;': 1,
#  'lobsters': 2,
#  'lobsters\nto': 1,
#  "lobsters!'": 1,
#  'lobsters,': 3,
#  'lock,': 1,
#  'locked;': 1,
#  'locks': 1,
#  'locks,\n': 1,
#  'lodging': 1,
#  'lonely': 1,
#  'long': 22,
#  "long\nenough.'\n\nalice": 1,
#  'long\nhookah,': 1,
#  'long\nringlets,': 1,
#  'long\nway.': 1,
#  'long,': 1,
#  'long;': 1,
#  'longed': 2,
#  'longer': 2,
#  "longer!'\n\nshe": 1,
#  'longitude': 1,
#  'look': 23,
#  'look\nof': 1,
#  'look!\n\n': 1,
#  'look-out': 1,
#  'looked': 40,
#  'looked\nanxiously': 1,
#  'looked\nat': 1,
#  'looking': 22,
#  'looking\nanxiously': 3,
#  'looking\nat': 1,
#  'looking\nfor': 1,
#  'looking\nup': 1,
#  'looking-glass.': 1,
#  'loose': 1,
#  'lory': 1,
#  'lory,': 1,
#  'lose\nyour': 1,
#  'losing': 1,
#  'lost': 1,
#  'lost,': 1,
#  'lost:': 1,
#  'loud': 3,
#  'loud,': 2,
#  'louder': 1,
#  'loudly': 2,
#  'loudly.': 1,
#  'love).\n\noh': 1,
#  'love,': 1,
#  "love,\n'tis": 1,
#  'loveliest': 1,
#  'lovely': 2,
#  'loving': 1,
#  'low': 5,
#  'low\ntrembling': 1,
#  'low\nvoice,': 1,
#  'low,': 6,
#  'low-spirited.': 1,
#  "low.\n\n'would": 1,
#  "lower,'": 1,
#  'lowing\nof': 1,
#  'lying': 7,
#  'm,': 1,
#  "m--'\n\n'why": 1,
#  "m--'\n\nbut": 1,
#  "m?'": 1,
#  'ma': 1,
#  "ma!'": 1,
#  "ma'am,": 1,
#  'mabel': 1,
#  'mabel,': 1,
#  'machines': 1,
#  'mad': 2,
#  'mad,': 1,
#  'mad--at': 1,
#  'mad.': 1,
#  "mad.\nyou're": 1,
#  "mad.'\n\n'but": 1,
#  "mad.'\n\n'how": 1,
#  "mad.'\n\n'i": 1,
#  "mad?'": 1,
#  "mad?'\n\n'to": 1,
#  'made': 26,
#  'made\nher': 1,
#  "made.\n\n'he": 1,
#  'magic': 1,
#  'magpie': 1,
#  'majesty': 1,
#  "majesty!'": 1,
#  "majesty,'": 1,
#  "majesty?'": 1,
#  'make': 23,
#  'make\nsome': 1,
#  'makes': 7,
#  'makes\nrather': 1,
#  'makes\nthem': 1,
#  'making': 7,
#  'making\nquite': 1,
#  'mallets': 1,
#  'man': 1,
#  'man,': 2,
#  "man,'": 1,
#  "man.'\n\nthere": 1,
#  'manage': 6,
#  "manage?'": 1,
#  'managed': 3,
#  'managed?': 1,
#  'managing': 1,
#  'manner': 1,
#  'manner,': 1,
#  'manners': 1,
#  'many': 8,
#  'many\ndifferent': 1,
#  'many\ntea-things': 1,
#  'maps': 1,
#  'march': 1,
#  'march\nhare.': 1,
#  'march,': 1,
#  'march--just': 1,
#  "march.'": 1,
#  'marched': 1,
#  'mark': 2,
#  'mark;': 1,
#  'marked': 5,
#  'marked,': 1,
#  "marmalade',": 1,
#  'mary': 1,
#  'master': 2,
#  'master,': 1,
#  'matter': 6,
#  'matter\nworse.': 1,
#  "matter,'": 1,
#  'matters': 2,
#  'may': 9,
#  'may\nkiss': 1,
#  "maybe,'": 1,
#  "mayn't": 1,
#  'me': 43,
#  'me\nlike': 1,
#  'me\nsee:': 1,
#  'me\nwhether': 1,
#  'me!': 3,
#  "me'": 1,
#  'me,': 1,
#  "me,'": 3,
#  "me,'\nthought": 1,
#  "me.'\n\n'that's": 1,
#  "me.'\n\n'you!'": 1,
#  'me?': 1,
#  "me?'\n\n'well,": 1,
#  "me?'\n\nluckily": 1,
#  'meal,': 1,
#  'mean': 7,
#  'mean,': 1,
#  "mean,'": 2,
#  'meaning': 6,
#  "meaning.\n\n'and": 1,
#  'means': 2,
#  'means,': 1,
#  "means--to--make--anything--prettier.'\n\n'well,": 1,
#  "means.'\n\n'i": 1,
#  'meant': 4,
#  "meant,'": 1,
#  'meanwhile': 1,
#  'measure\nherself': 1,
#  'meat,\n': 1,
#  'meekly': 1,
#  'meekly:': 1,
#  'meet': 2,
#  'meeting': 1,
#  'melancholy': 5,
#  'melancholy\ntone.': 1,
#  'memory,': 1,
#  'mentioned': 3,
#  'mercia': 1,
#  'merely': 2,
#  'merrily': 1,
#  'messages': 2,
#  'met': 3,
#  'mice': 2,
#  'mice--oh,': 1,
#  'middle': 3,
#  'middle,': 3,
#  'middle.': 1,
#  'might': 26,
#  'might\nappear': 1,
#  'might,\nwhat': 1,
#  'mile': 2,
#  'miles': 3,
#  'milk': 1,
#  'milk-jug': 1,
#  'millennium': 1,
#  'mind': 4,
#  "mind\nnow!'": 1,
#  "mind!'": 1,
#  'mind,': 2,
#  "mind,'\nsaid": 1,
#  "mind.'\n\nthe": 1,
#  'minded': 1,
#  'minding\ntheir': 1,
#  'mine': 3,
#  'mine,': 1,
#  "mine,'": 2,
#  'mine--a': 1,
#  "mine.'\n\nthe": 1,
#  'mineral,': 1,
#  'minute': 12,
#  'minute\nor': 1,
#  "minute!'": 1,
#  'minute,': 2,
#  "minute,\n'and": 1,
#  'minute,\nnurse!': 1,
#  'minutes': 6,
#  'minutes,': 1,
#  'minutes,\nand': 1,
#  'minutes.': 1,
#  'minutes.\n\nthe': 1,
#  'mischief,': 1,
#  'miserable': 2,
#  'miss': 1,
#  'miss,': 1,
#  'missed': 2,
#  'mistake': 2,
#  'mistake;': 1,
#  'mixed': 2,
#  'mock': 1,
#  'mock\nturtle,': 1,
#  'mock\nturtle.\n\nso': 1,
#  'moderate.': 1,
#  'modern,': 1,
#  'moment': 17,
#  "moment!'\nthen": 1,
#  "moment's": 2,
#  'moment,': 4,
#  "moment.\n\n'let's": 1,
#  'moment:\nshe': 1,
#  'month\nis': 1,
#  'month,': 1,
#  'moon,': 1,
#  'moral': 5,
#  'moral\nof': 1,
#  'moral,': 1,
#  'morals': 1,
#  'morcar,': 1,
#  'morcar,\nthe': 1,
#  'more': 4,
#  'more\nhopeless': 1,
#  'more\nsimply--"never': 1,
#  "more!'": 1,
#  'more,': 4,
#  'more--as': 1,
#  "more.\n\n'you": 1,
#  "more.'\n\n'you": 1,
#  'more:': 1,
#  'more;\n': 1,
#  'morning': 1,
#  'morning,': 2,
#  "morning,'": 1,
#  'morning?': 1,
#  'morsel': 1,
#  'most': 7,
#  'most\nconfusing': 1,
#  'mostly': 1,
#  "mostly,'": 1,
#  'mournful': 1,
#  'mournfully.': 1,
#  'mouse': 1,
#  'mouse\nin': 1,
#  "mouse!'": 1,
#  "mouse!')": 1,
#  "mouse's": 1,
#  'mouse,': 1,
#  'mouse--a': 1,
#  'mouse--o': 1,
#  'mouse--of\na': 1,
#  'mouse--to': 1,
#  'mouse.': 1,
#  "mouse.\n\n'of": 1,
#  'mouse:': 1,
#  'mouse?\neverything': 1,
#  'mouth': 5,
#  'mouth\nand': 1,
#  'mouth\nenough': 1,
#  'mouth,': 2,
#  'mouths': 1,
#  'mouths--and': 1,
#  'mouths.': 1,
#  'mouths;': 1,
#  'move': 1,
#  'move\nthat': 1,
#  'move.': 1,
#  'moved': 3,
#  'moving': 3,
#  'much': 37,
#  'much\nabout': 1,
#  'much\naccustomed': 1,
#  "much!'": 1,
#  "much!'\n\nalas!": 1,
#  'much,': 2,
#  "much,'": 5,
#  'much.\n\nthe': 1,
#  'muchness"--did': 1,
#  'muchness--you': 1,
#  "muchness?'\n\n'really,": 1,
#  'multiplication': 1,
#  'murdering': 1,
#  'muscular': 1,
#  'mushroom': 4,
#  'mushroom,': 1,
#  "mushroom,'": 1,
# ...
#  "subject.\n\n'ten": 1,
#  'subjects': 1,
#  'submitted\nto': 1,
#  'succeeded': 2,
#  'such': 38,
#  'such\na': 1,
#  'sudden': 3,
#  'suddenly': 9,
#  'suddenly,': 1,
#  'suddenly:': 2,
#  'suet;\n': 1,
#  'sugar': 1,
#  'suit': 2,
#  'suit\nthe': 1,
#  'sulkily': 1,
#  'sulkily\nremarked,': 1,
#  'sulky': 2,
#  'sulky,': 1,
#  'summer': 2,
#  'sun,': 1,
#  'sun.\n(if': 1,
#  'supple\n': 1,
#  'suppose': 5,
#  'suppose\n': 1,
#  'suppose,': 1,
#  "suppose.'\n\nso": 1,
#  "suppose?'": 1,
#  "suppose?'\n\n'yes,'": 1,
#  'suppress': 1,
#  'suppressed': 3,
#  "suppressed.\n\n'come,": 1,
#  'sure': 13,
#  'sure\n_i_': 1,
#  'sure!\nhowever,': 1,
#  'sure,': 2,
#  'sure;': 1,
#  'surprise': 1,
#  'surprise,': 2,
#  'surprise.': 1,
#  "surprise.\n\n'of": 1,
#  'surprised': 5,
#  'surprised,': 1,
#  'swallow': 1,
#  'swallowed': 1,
#  'swallowing': 1,
#  'swam': 5,
#  'swim': 1,
#  'swim,': 1,
#  'swim--"': 1,
#  'swim.\n\n': 1,
#  'swimming': 1,
#  'swimming\naway': 1,
#  "t!'": 1,
#  'table': 6,
#  'table\nin': 1,
#  'table,': 5,
#  "table,'": 1,
#  'table.': 2,
#  "table.\n\n'have": 1,
#  'table:\nshe': 1,
#  'tail': 2,
#  'tail,': 2,
#  'tail,\n': 1,
#  'tail.\n\n': 1,
#  'tail;': 1,
#  'tails': 3,
#  'take': 6,
#  'take\nmore': 1,
#  'take\nthe': 1,
#  'taken': 4,
#  'takes': 1,
#  'takes\ntwenty-four': 1,
#  'taking': 5,
#  'tale': 1,
#  'tale\n\nthey': 1,
#  "tale!'": 1,
#  'tale,': 1,
#  'talk': 9,
#  'talk\nabout': 1,
#  "talk!'": 1,
#  "talk,'": 1,
#  'talk.': 1,
#  'talk:': 1,
#  'talking': 10,
#  "talking!'\n\njust": 1,
#  'talking.': 1,
#  'talking.\n\nalice': 1,
#  'talking:': 1,
#  'taller': 1,
#  'taller,': 1,
#  'tarts': 2,
#  'tarts\non': 1,
#  'tarts,': 1,
#  'tarts,\n': 2,
#  'tarts?\n\nthe': 1,
#  'taste\nit,': 1,
#  'taste\ntheirs,': 1,
#  'tasted': 2,
#  "tasted--'": 1,
#  'tastes!': 1,
#  'taught': 3,
#  'taught\nlaughing': 1,
#  'tea': 5,
#  'tea,': 1,
#  "tea,'": 3,
#  "tea--'\n\n'the": 1,
#  'tea--not': 1,
#  'tea-party': 1,
#  'tea-party\n\nthere': 1,
#  'tea-time,\nand': 1,
#  'tea-tray': 1,
#  "tea.\n'i": 1,
#  'tea;': 1,
#  'teaching': 1,
#  'teacup': 3,
#  'teacups': 1,
#  "teapot.\n\n'at": 1,
#  'tears': 3,
#  "tears\n\n'curiouser": 1,
#  'tears\nrunning': 1,
#  'tears!': 1,
#  'tears,': 2,
#  'tears.': 1,
#  "teases.'\n\n": 1,
#  'teeth,': 1,
#  'telescope': 1,
#  'telescope!': 1,
#  'telescopes:': 1,
#  'tell': 2,
#  'tell\nus': 1,
#  'tell\nyou': 1,
#  'telling': 2,
#  'tells': 2,
#  'temper': 1,
#  "temper!'": 1,
#  'temper,': 1,
#  "temper,'": 1,
#  "temper.\n\n'are": 1,
#  'ten': 5,
#  'terms': 2,
#  'terribly': 1,
#  'terrier,': 1,
#  'terror.': 1,
#  'than': 2,
#  'than\nbefore,': 1,
#  'than\nyou,': 1,
#  'thank': 1,
#  'thanked': 1,
#  'that': 1,
#  "that!'\n\n'oh,": 1,
#  "that'll": 1,
#  "that's": 1,
#  'that.': 1,
#  'the': 1,
#  'their': 1,
#  'then': 1,
#  'then--she': 1,
#  'there': 1,
#  "there's": 1,
#  'therefore': 1,
#  "these?'": 1,
#  'they': 1,
#  "they're": 1,
#  'thick': 1,
#  'thimble,': 2,
#  "thimble,'": 1,
#  'thin--and': 1,
#  'thing': 30,
#  'thing\nabout': 1,
#  'thing\nas': 1,
#  'thing\nsat': 1,
#  "thing!'": 1,
#  "thing!'\n\nit": 1,
#  "thing!'\nsaid": 2,
#  'thing,': 4,
#  "thing,'": 2,
#  'thing.\n\nafter': 1,
#  'things': 15,
#  'things!': 1,
#  "things!'": 3,
#  "things!'\n\n'it's": 1,
#  'things,': 2,
#  'things--i': 1,
#  "things?'": 1,
#  'think': 24,
#  'think\nabout': 1,
#  "think\nyou're": 1,
#  'think!': 1,
#  "think!'\n(dinah": 1,
#  'think,': 1,
#  'think,\nyou': 1,
#  "think,'": 2,
#  "think--'": 2,
#  "think.'": 1,
#  'think:': 1,
#  'think;': 1,
#  "think?'": 1,
#  "think?'\n\n'i": 1,
#  'thinking': 7,
#  'thinking\nabout': 1,
#  'thinking\nover': 1,
#  'thirteen,': 1,
#  'this': 1,
#  'this\n': 1,
#  'this\nalice': 1,
#  'this\nis': 1,
#  'this\nmoment': 1,
#  'this\nmoment,': 1,
#  'this\nrope--will': 1,
#  'this\ntime': 1,
#  'this\ntime.)': 1,
#  'this\nwas': 1,
#  "this!'": 1,
#  'this),': 1,
#  'this,': 17,
#  "this,'\nshe": 1,
#  'this.': 1,
#  'this:': 2,
#  'this:--\n\n': 2,
#  'this;': 2,
#  "this?'": 1,
#  'thistle': 1,
#  'thistle,\nto': 1,
#  'thoroughly': 2,
#  'those': 3,
#  'those\nserpents!': 1,
#  'though': 2,
#  'though,': 1,
#  'though.\nhe': 1,
#  'thought': 56,
#  'thought\nalice,)': 1,
#  'thought\nit': 1,
#  'thought\nto': 1,
#  'thought),': 1,
#  'thought,': 5,
#  'thought,\nand': 1,
#  'thought.': 2,
#  'thought;': 1,
#  'thoughtfully': 1,
#  'thoughtfully.': 2,
#  'thoughtfully:': 1,
#  'thoughts': 2,
#  'thousand': 1,
#  'three': 21,
#  'three\nblasts': 1,
#  'three\ngardeners': 1,
#  'three,': 1,
#  'three-legged': 2,
#  "three.'\n\n'your": 1,
#  'threw\na': 1,
#  'threw\nthemselves': 1,
#  "throat!'": 1,
#  "throat,'\nsaid": 1,
#  'throne': 1,
#  'through': 10,
#  'through\nthe': 1,
#  "through,'": 1,
#  'throw': 3,
#  'throwing': 2,
#  'thrown': 1,
#  'thump!': 2,
#  'thunder,': 1,
#  "thunderstorm.\n\n'a": 1,
#  'tide': 1,
#  'tidy': 1,
#  'tie': 1,
#  'tied\nup': 1,
#  'tight': 1,
#  'till': 15,
#  'till\nshe': 1,
#  'tillie;': 1,
#  'time': 16,
#  'time\nit': 1,
#  'time\nwhen': 1,
#  'time\nwith': 1,
#  'time!': 2,
#  "time!'\n\n'perhaps": 1,
#  "time).\n'don't": 1,
#  'time,': 5,
#  "time,'": 4,
#  "time.\n\n'i": 1,
#  'time.\n\nalice': 1,
#  "time.'\n\nso": 1,
#  "time?'": 1,
#  'times': 6,
#  'timid': 3,
#  'timidly': 2,
#  'timidly,': 3,
#  'timidly,\nsaying': 1,
#  "timidly.\n\n'would": 1,
#  'timidly:': 1,
#  'timidly;': 1,
#  'tinkling': 1,
#  'tiny': 3,
#  'tiny\nhands': 1,
#  'tipped': 1,
#  'tiptoe,': 1,
#  'tired': 5,
#  'tired\nof': 2,
#  'to': 1,
#  'took': 1,
#  'tortoise': 1,
#  'tortoise,': 1,
#  "tortoise--'\n\n'why": 1,
#  'trampled': 1,
#  'treacle': 1,
#  "treacle\nfrom?'\n\n'you": 1,
#  "treacle,'": 1,
#  'treacle-well--eh,': 1,
#  "treacle-well.'\n\n'there's": 1,
#  'treading': 2,
#  'treat.\n': 1,
#  'treated': 1,
#  'tree': 2,
#  "tree.\n\n'did": 1,
#  'tree.\n\nby': 1,
#  'trees': 5,
#  'trees,': 2,
#  'tremble.': 1,
#  'trembled': 2,
#  'trembling': 5,
#  'tremulous': 1,
#  'trial': 2,
#  'trial\none': 1,
#  "trial's": 3,
#  'trial,\n': 1,
#  "trial.'\n\n'stupid": 1,
#  'trial:': 1,
#  'trials,': 1,
#  'trickling': 1,
#  'tricks': 1,
#  'tried': 15,
#  "tried\nhedges,'": 1,
#  "tried.\n\n'very": 1,
#  'trims': 1,
#  'triumphantly,': 1,
#  'triumphantly.\n\nalice': 1,
#  'trot': 1,
#  'trotting': 2,
#  'trouble': 3,
#  'trouble\nmyself': 1,
#  "trouble!'": 1,
#  'true):\n': 1,
#  "true,'": 1,
#  'true--"': 1,
#  'true.)\n\ndown,': 1,
#  'trumpet': 1,
#  'trumpet,': 2,
#  'trusts': 1,
#  'truth:\ndid': 1,
#  'truthful\nchild;': 1,
#  'try': 12,
#  'trying': 8,
#  'trying\nto': 2,
#  'trying\nwhich': 1,
#  'trying,': 1,
#  "trying--'\n\n'i": 1,
#  "trying.'": 1,
#  'tucked': 3,
#  'tulip-roots': 1,
#  'tumbled': 1,
#  'tumbling': 2,
#  'tunnel': 1,
#  'tureen!\n': 1,
#  'turkey,': 1,
#  'turn': 6,
#  'turn-up': 1,
#  'turn;': 1,
#  'turned': 13,
#  'turning': 10,
#  'turning\nto': 1,
#  'turns': 1,
#  'turns,': 2,
#  'turtle': 1,
#  'turtle\nangrily:': 1,
#  'turtle\ninterrupted,': 1,
#  'turtle\nreplied;': 1,
#  "turtle's": 1,
#  "turtle's\nheavy": 1,
#  'turtle,': 1,
#  'turtle--we': 1,
#  'turtle.': 1,
#  "turtle.\n\n'and": 1,
#  "turtle.\n\n'certainly": 1,
#  "turtle.\n\n'hold": 1,
#  "turtle.\n\n'no,": 1,
#  "turtle.\n\n'she": 1,
#  "turtle.\n\n'very": 1,
#  'turtle:': 1,
#  'turtle;': 1,
#  'turtles': 1,
#  'turtles,': 1,
#  'tut,': 1,
#  "twelfth?'": 1,
#  'twelve': 2,
#  'twelve,': 1,
#  'twelve?': 1,
#  'twenty': 1,
#  'twice': 1,
#  'twice,': 3,
#  "twice--'\n\n'each": 1,
#  'twinkle,': 2,
#  'twinkle--"\'\n\nhere': 1,
#  "twinkle--'": 1,
#  'twinkled': 1,
#  'twinkling': 3,
#  'twinkling!': 1,
#  'twist': 1,
#  'two': 6,
#  'two\n': 1,
#  "two!'": 1,
#  'two,': 4,
#  'two,\n': 1,
#  'two--"': 1,
#  'two.': 1,
#  'two:': 1,
#  'ugh,': 1,
#  'uglification,': 1,
#  'uglify': 1,
#  'ugly': 1,
#  'ugly;': 1,
#  'unable': 1,
#  'uncivil.': 1,
#  'uncomfortable,': 1,
#  'uncomfortable.\n\nthe': 1,
#  'uncommonly': 1,
#  'uncorked': 1,
#  'under': 14,
#  'under\nher': 1,
#  'under\nsentence': 1,
#  'underneath': 1,
#  'understand': 4,
#  'understand.': 1,
#  'understood': 1,
#  'undertone': 1,
#  "undertone,\n\n'important--unimportant--unimportant--important--'": 1,
#  'undo': 1,
#  'undoing': 1,
#  'uneasily': 1,
#  'uneasily,': 1,
#  'uneasy:': 1,
#  'unfolded': 2,
#  'unfortunate': 3,
#  'unhappy': 1,
#  "unhappy.\n\n'it": 1,
#  "unjust\nthings--'": 1,
#  'unless\nthere': 1,
#  'unlocking': 1,
#  'unpleasant': 1,
#  'unpleasant\nstate': 1,
#  'unrolled\nitself,': 1,
#  'until': 4,
#  'untwist': 1,
#  'unusually\nlarge': 1,
#  'unwillingly': 1,
#  'up': 75,
#  'up\nand': 1,
#  'up\neagerly,': 1,
#  'up\nthe': 1,
#  "up!'": 1,
#  'up,': 9,
#  "up,'": 2,
#  "up.'\n\n'but": 1,
#  'up:': 1,
#  'updated:': 1,
#  'upon': 23,
#  'upon\na': 1,
#  'upon\nher:': 1,
#  'upon\ntiptoe,': 1,
#  'upright': 1,
#  'upset': 2,
#  'upstairs,': 1,
#  'us': 7,
#  'us\n': 1,
#  'us!"\'\n\n\'they': 1,
#  'us,': 2,
#  "us,'": 1,
#  'us.': 1,
#  'use': 14,
#  'use\ndenying': 1,
#  'use\nspeaking': 1,
#  'use,': 2,
#  'used': 12,
#  'useful,': 2,
#  'using': 2,
#  'usual': 1,
#  'usual,': 1,
#  "usual,'": 1,
#  'usual.': 1,
#  'usual.\ni': 1,
#  'usually': 2,
#  'usurpation': 1,
#  'v.': 1,
#  'vague': 1,
#  'vanished': 3,
#  'vanished.\n\nalice': 1,
#  'variations.': 1,
#  'various': 1,
#  'vegetable.': 1,
#  'velvet': 1,
#  'venture': 3,
#  'ventured': 3,
#  'ventured\nto': 1,
#  "verdict,'": 2,
#  'verse': 1,
#  "verse,'": 2,
#  'verses': 3,
#  "verses.'\n\n'are": 1,
#  'very': 15,
#  'very\ncarefully,': 1,
#  'very\ncautiously:': 1,
#  'very\ncurious': 1,
#  'very\nlike': 1,
#  'very\nlikely': 1,
#  'very\nlittle': 1,
#  'very\nlonely': 1,
#  'very\nshort': 1,
#  'very\nwell': 1,
#  'vi.': 1,
#  'vii.': 1,
#  'viii.': 1,
#  'vinegar': 1,
#  'violence': 1,
#  'violent': 1,
#  'violent\nblow': 1,
#  'violently': 2,
#  'violently,': 1,
#  'violently,\nthat': 1,
#  'visit': 1,
#  'voice': 7,
#  'voice,': 10,
#  "voice,\n'--and": 1,
#  "voice,\n'are": 1,
#  "voice,\n'your": 1,
#  'voice,\nto': 1,
#  'voice--the': 1,
#  'voice.': 4,
#  "voice.\n\n'back": 1,
#  "voice.\n\n'not": 1,
#  "voice.\n\n'now,": 1,
#  "voice.\n\n'repeat,": 1,
#  "voice.\n\n'there's": 1,
#  "voice.\n\n'who": 1,
#  'voice:': 1,
#  'voice:--\n\n': 1,
#  'voice;': 2,
#  'voices': 1,
#  'voices\nall': 1,
#  "voices--'hold": 1,
#  'vote': 1,
#  'vulgar': 1,
#  'wags': 1,
#  "waist,'\nthe": 1,
#  'waistcoat-pocket,': 2,
#  'wait,': 1,
#  'waited': 7,
#  'waited\ntill': 1,
#  'waited.\n\nthe': 1,
#  'waited.\n\nwhen': 1,
#  'waiting': 3,
#  "waiting!'": 1,
#  'walk': 4,
#  'walk!"': 1,
#  'walked': 10,
#  'walking': 3,
#  'walking\naway.': 1,
#  'walrus': 1,
#  'wander': 1,
#  'wandered': 1,
#  'wandered\nabout': 1,
#  'wandering': 1,
#  'wandering,': 1,
#  'want': 8,
#  'want\nto': 1,
#  'wanted': 4,
#  'wants': 2,
#  "warning,'": 1,
#  'was': 2,
#  'was\nan': 1,
#  'was\nenough': 1,
#  'was\nevidently': 1,
#  'was\ngenerally': 1,
#  'was\ngoing': 1,
#  'was\ngrowing,': 1,
#  'was\nin': 1,
#  'was\nlying': 1,
#  'was\nnot': 2,
#  'was\nnow': 1,
#  'was\nobliged': 1,
#  'was\nof': 1,
#  'was\nonly': 1,
#  'was\nsilent.\n\nthe': 1,
#  'was\nsomething': 1,
#  'was\nstanding': 1,
#  'was\nthe': 1,
#  'was\ntoo': 1,
#  'was\nvery': 1,
#  'was\nwalking': 1,
#  'was!': 1,
#  "was!'": 1,
#  'was)\nscratching': 1,
#  'was,': 12,
#  'was,\nand': 1,
#  "was,'": 2,
#  "was.'\n\n'i": 1,
#  'was:': 2,
#  'wash': 1,
#  'washing--extra."\'\n\n\'you': 1,
#  "washing?'": 1,
#  "wasn't": 10,
#  "wasn't\nalways": 1,
#  'waste': 1,
#  'wasting': 1,
#  'wasting\n': 1,
#  'watch': 4,
#  'watch\nout': 1,
#  'watch\nto': 1,
#  "watch!'": 1,
#  "watch,'": 1,
#  'watched': 2,
#  'watching': 2,
#  'watching\nthem,': 1,
#  'water': 2,
#  'water,': 1,
#  "water-well,'": 1,
#  'water.': 1,
#  'waters': 1,
#  'waving': 5,
#  'way': 34,
#  'way\noff,': 1,
#  'way!': 1,
#  'way,': 5,
#  "way--'\n\n'that": 1,
#  'way--never': 1,
#  "way.\n\n'i": 1,
#  'way.\n\nso': 1,
#  'way:--\n\n': 1,
#  'way?': 1,
#  'ways': 1,
#  'we': 13,
#  'we\n': 1,
#  "we\ndon't": 1,
#  "we\nwon't": 1,
#  "we're": 1,
#  "we've": 2,
#  'weak': 1,
#  'weak\n': 1,
#  'wearily.': 1,
#  'week': 2,
#  'week:': 1,
#  "weeks!'\n\n'i'm": 1,
#  'welcome': 1,
#  'well': 26,
#  'well!': 1,
#  'well,': 1,
#  "well,'": 2,
#  "well--'\n\n'what": 1,
#  'well.\n\nthe': 1,
#  "well?'\n\n'take": 1,
#  "well?'\n\nthe": 1,
#  'went': 73,
#  'went\nback': 1,
#  'went\ndown': 1,
#  'went\nnearer': 1,
#  'went\non.': 2,
#  'went,': 1,
#  "went,\n'one": 1,
#  'went.\n\nonce': 1,
#  'went.\n\nso': 1,
#  'wept': 1,
#  'were': 74,
#  'were\nanimals,': 1,
#  'were\njust': 1,
#  'were\nnearly': 1,
#  'were\nnowhere': 1,
#  'were\nresting': 1,
#  'were\ntwo': 1,
#  "were',": 1,
#  "were,'": 1,
#  'were.\n\n': 1,
#  "weren't": 1,
#  'wet': 1,
#  'wet,': 1,
#  'what': 3,
#  'what\n"it"': 1,
#  'what\ncan': 1,
#  'what\nmakes': 1,
#  'what\nshe': 1,
#  'what\nthis': 1,
#  'what\nto': 1,
#  'what\nwas': 1,
#  'what\nyear': 1,
#  "what's": 2,
#  'what?': 1,
#  "what?'": 2,
#  "what?'\n\nthe": 1,
#  'whatever': 1,
#  "whatever,'": 1,
#  "whatever?'": 1,
#  'whatsoever.': 1,
#  'when': 6,
#  'when\nalice': 1,
#  'when\nthe': 1,
#  'when\nyou': 1,
#  'where': 5,
#  "where--'": 1,
#  "where.'\n\n'well,": 1,
#  'whereupon': 1,
#  'wherever': 2,
#  'whether': 8,
#  'which': 5,
#  'which\nchanged': 1,
#  'which\nremained': 1,
#  'which\nwas': 1,
#  "which\nway?',": 1,
#  'which),': 1,
#  "which?'": 1,
#  'while': 4,
#  'while\nshe': 1,
#  'while,': 4,
#  "whiles.'\n\n'then": 1,
#  'whiskers!': 1,
#  'whiskers,': 1,
#  'whisper': 1,
#  'whisper,': 1,
#  "whisper.)\n\n'that": 1,
#  'whispered': 4,
#  'whispered,': 1,
#  'whispers\nnow': 1,
#  'whistle': 1,
#  "whistling.\n\n'oh,": 1,
#  'white': 1,
#  'white\nrabbit': 1,
#  'white\nrabbit,': 1,
#  'white,': 1,
#  'white;\n': 1,
#  'whiting': 3,
#  "whiting!'\n\n'oh,": 1,
#  "whiting,'": 2,
#  'whiting.': 1,
#  "whiting?'\n\n'i": 1,
#  'who': 10,
#  'who\nin': 1,
#  'who\nwas': 1,
#  'who\nwere': 1,
#  'whole': 11,
#  'whole\n': 1,
#  "whole\nwindow!'\n\n'sure,": 1,
#  'whom': 1,
#  'whose': 2,
#  'why': 5,
#  'why\nit': 1,
#  'why,': 2,
#  'why,\ni': 1,
#  "why,\nshe'll": 1,
#  'why.': 1,
#  'wide': 1,
#  'wide,': 1,
#  "wider.\n'come,": 1,
#  'wife;\n': 1,
#  "wig.'\n\nthe": 1,
#  'wild': 1,
#  'wild\nbeasts': 1,
#  'wildly': 1,
#  "wildly\nabout.\n\n'change": 1,
#  'will': 5,
#  'will\n': 1,
#  'william': 1,
#  "william's": 1,
#  'william,"\'': 1,
#  "william,'": 1,
#  'win,': 1,
#  'wind,': 1,
#  'window,': 4,
#  "window.'\n\n'that": 1,
#  "window?'\n\n'sure,": 1,
#  "wine,'": 2,
#  "wings.\n\n'serpent!'": 1,
#  'wink': 2,
#  'winter': 1,
#  'wise': 1,
#  'wish': 20,
#  'with': 1,
#  'with\n': 1,
#  'witness': 4,
#  "witness!'": 1,
#  "witness!'\n\nthe": 1,
#  "witness,'": 1,
#  'witness.': 1,
#  "witness.'\n\n'well,": 1,
#  "wits!'": 1,
#  'woke': 1,
#  'woman--but\nthen--always': 1,
#  'woman;': 1,
#  "won't": 19,
#  "won't\ndo": 1,
#  "won't!'": 1,
#  "won't'": 1,
#  'won,': 1,
#  "won?'\n\nthis": 1,
#  'wonder': 12,
#  'wonder\nwhat': 1,
#  'wonder\nwho': 1,
#  "wonder?'": 3,
#  'wondered': 1,
#  'wonderful': 1,
#  'wondering': 5,
#  'wonderland': 1,
#  'wonderland\n\nauthor:': 1,
#  'wonderland\n\nlewis': 1,
#  'wonderland,': 1,
#  'wood': 1,
#  'wood,': 1,
#  "wood,'": 1,
#  'wood.': 2,
#  "wood.\n\n'the": 1,
#  'wooden': 1,
#  'word': 7,
#  'word)': 1,
#  'word,': 2,
#  'words': 11,
#  "words\n'eat": 1,
#  'words\nhave': 1,
#  'words,': 1,
#  "words,'": 1,
#  "words.'\n\nso": 1,
#  'words:': 1,
#  "words:\n\n'yes,": 1,
#  'words:--\n\n': 2,
#  'wore': 1,
#  'work': 7,
#  'work,': 1,
#  "works!'": 1,
#  'world': 6,
#  'world!': 1,
#  'worm.': 1,
#  "worried.\n\n'just": 1,
#  'worry': 1,
#  'worse': 2,
#  'worth': 4,
#  'would': 21,
#  'would\nbe': 1,
#  'would\ncost': 1,
#  'would\nhave': 1,
#  'would\nkeep,': 1,
#  "would,'": 1,
#  "wouldn't": 12,
#  'wow!': 2,
#  "wow!'\n\n'here!": 1,
#  "wow!'\n\nwhile": 1,
#  'wrapping': 1,
#  'wretched': 2,
#  'wriggling': 1,
#  'write': 5,
#  'writhing,': 1,
#  'writing': 4,
#  "writing-desk?'\n\n'come,": 1,
#  'writing-desks,\nwhich': 1,
#  'written': 6,
#  'wrong': 2,
#  "wrong!'": 1,
#  'wrong,': 1,
#  'wrote': 2,
#  'www.gutenberg.org\n\n\ntitle:': 1,
#  'x.': 1,
#  'xi.': 1,
#  'xii.': 1,
#  'yards': 1,
#  'yawned': 2,
#  'yawning': 1,
#  "yawning.\n'i'm": 1,
#  'ye;': 1,
#  'year': 1,
#  'years,': 1,
#  'yelled': 1,
#  'yelp': 1,
#  'yer': 4,
#  'yesterday': 1,
#  'yesterday,\nbecause': 1,
#  'yet': 4,
#  "yet!'": 1,
#  'yet,': 3,
#  "yet,'": 3,
#  "yet--and\nyet--it's": 1,
#  'yet--oh!': 1,
#  "yet.'\n\n'a": 1,
#  "yet?'": 1,
#  "yet?'\n\n'no,'": 1,
#  'you': 8,
#  'you\n': 1,
#  'you\nany': 1,
#  'you\nare;': 1,
#  "you\ncan't": 1,
#  'you\ncome': 1,
#  'you\ndry': 1,
#  'you\nexecuted,': 1,
#  'you\ngrow': 1,
#  'you\nhave': 1,
#  'you\nknow': 1,
#  'you\nknow,': 1,
#  "you\nknow.'\n\n'i": 1,
#  'you\ntake': 1,
#  'you\ntell': 1,
#  'you\nthinking': 1,
#  'you!': 2,
#  "you!'": 2,
#  "you!'\n\nthere": 1,
#  "you'd": 6,
#  "you'd\ntake": 1,
#  "you'll": 4,
#  "you're": 10,
#  "you've": 3,
#  "you've\nhad!'\n\n'oh,": 1,
#  "you've\nseen": 1,
#  'you,': 22,
#  'you,\n': 1,
#  'you,"\'': 1,
#  "you,'": 5,
#  'you--all': 1,
#  'you--are': 1,
#  'you.': 1,
#  "you.'": 1,
#  'you.--come,\n': 1,
#  'you:': 1,
#  'you?': 1,
#  'you?\n\n': 1,
#  "you?'": 4,
#  "you?'\n\n'i'm": 1,
#  "you?'\n\n'not": 1,
#  "you?'\n\nwhich": 1,
#  "you?'\nshe": 1,
#  'young': 5,
#  'your': 14,
#  'your\nfinger': 1,
#  'your\nhistory,': 1,
#  "your\nmajesty,'": 1,
#  'your\nname': 1,
#  "your\nverdict,'": 1,
#  'yours': 1,
#  'yours:': 1,
#  'yourself': 5,
#  'yourself,': 1,
#  "yourself,'": 1,
#  'youth,': 3,
#  "youth,'": 3,
#  'zealand': 1,
#  'zigzag,': 1,
#  '\ufeffproject': 1}
